# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#using 2 antennas
dataset1 = pd.read_csv('human_walking_direction_amir_421.csv').drop('Unnamed: 0',axis=1)
dataset2 = pd.read_csv('human_walking_direction_irina_421.csv').drop('Unnamed: 0',axis=1)
dataset3 = pd.read_csv('human_walking_direction_mohamed_421.csv').drop('Unnamed: 0',axis=1)
dataset4 = pd.read_csv('human_walking_direction_alaa_421.csv').drop('Unnamed: 0',axis=1)
dataset5 = pd.read_csv('human_walking_direction_abdelrahman_421.csv').drop('Unnamed: 0',axis=1)
dataset6 = pd.read_csv('human_walking_direction_elbatanony_421.csv').drop('Unnamed: 0',axis=1)
dataset7 = pd.read_csv('human_walking_direction_fahima_421.csv').drop('Unnamed: 0',axis=1)
dataset8 = pd.read_csv('human_walking_direction_belal_421.csv').drop('Unnamed: 0',axis=1)
dataset9 = pd.read_csv('human_walking_direction_odilbek_421.csv').drop('Unnamed: 0',axis=1)

# %%
#using 2 antennas
dataset12 = pd.read_csv('human_walking_direction_amir_422.csv').drop('Unnamed: 0',axis=1)
dataset22 = pd.read_csv('human_walking_direction_irina_422.csv').drop('Unnamed: 0',axis=1)
dataset32 = pd.read_csv('human_walking_direction_mohamed_422.csv').drop('Unnamed: 0',axis=1)
dataset42 = pd.read_csv('human_walking_direction_alaa_422.csv').drop('Unnamed: 0',axis=1)
dataset52 = pd.read_csv('human_walking_direction_abdelrahman_422.csv').drop('Unnamed: 0',axis=1)
dataset62 = pd.read_csv('human_walking_direction_elbatanony_422.csv').drop('Unnamed: 0',axis=1)
dataset72 = pd.read_csv('human_walking_direction_fahima_422.csv').drop('Unnamed: 0',axis=1)
dataset82 = pd.read_csv('human_walking_direction_belal_422.csv').drop('Unnamed: 0',axis=1)
dataset92 = pd.read_csv('human_walking_direction_odilbek_422.csv').drop('Unnamed: 0',axis=1)

# %%
dataset1.shape,dataset2.shape,dataset3.shape,dataset4.shape,dataset5.shape,dataset6.shape,dataset7.shape,dataset8.shape,dataset9.shape
# Out:
# ((42, 3201),
#  (40, 3201),
#  (40, 3201),
#  (40, 3201),
#  (40, 3201),
#  (42, 3201),
#  (41, 3201),
#  (41, 3201),
#  (40, 3201))

# %%
dataset12.shape,dataset22.shape,dataset32.shape,dataset42.shape,dataset52.shape,dataset62.shape,dataset72.shape,dataset82.shape,dataset92.shape
# Out:
# ((40, 3201),
#  (40, 3201),
#  (40, 3201),
#  (40, 3201),
#  (40, 3201),
#  (42, 3201),
#  (40, 3201),
#  (40, 3201),
#  (40, 3201))

# %%
datasets1=[]
datasets1.append(dataset1)
datasets1.append(dataset2)
datasets1.append(dataset3)
datasets1.append(dataset4)
datasets1.append(dataset5)
datasets1.append(dataset6)
datasets1.append(dataset7)
datasets1.append(dataset8)
datasets1.append(dataset9)

# %%
datasets2=[]
datasets2.append(dataset12)
datasets2.append(dataset22)
datasets2.append(dataset32)
datasets2.append(dataset42)
datasets2.append(dataset52)
datasets2.append(dataset62)
datasets2.append(dataset72)
datasets2.append(dataset82)
datasets2.append(dataset92)

# %%
label = 'No_person'
for i in range(len(datasets1)):
    selected_rows_no_person1 = datasets1[i].loc[datasets1[i]['label'] == label]
    if i==0:
        selected_rows_no_person1.to_csv(f"No_person_data_421_amplitudes_phases.csv", index=False)
    datasets1[i] = datasets1[i].drop(selected_rows_no_person1.index)
    print(datasets1[i].shape)
# Out:
# (22, 3201)
# (20, 3201)
# (20, 3201)
# (20, 3201)
# (20, 3201)
# (22, 3201)
# (21, 3201)
# (21, 3201)
# (20, 3201)

# %%
label = 'No_person'
for i in range(len(datasets2)):
    selected_rows_no_person2 = datasets2[i].loc[datasets2[i]['label'] == label]
    if i==0:
        selected_rows_no_person2.to_csv(f"No_person_data_422_amplitudes_phases.csv", index=False)
    datasets2[i] = datasets2[i].drop(selected_rows_no_person2.index)
    print(datasets2[i].shape)
# Out:
# (20, 3201)
# (20, 3201)
# (20, 3201)
# (20, 3201)
# (20, 3201)
# (22, 3201)
# (20, 3201)
# (20, 3201)
# (20, 3201)

# %%
no_activity1 = pd.read_csv('No_person_data_421_amplitudes_phases.csv')
no_activity1
# Out:
#     amplitude antenna1_1:0  amplitude antenna1_1:1  amplitude antenna1_1:2  \
# 0               169.807449              167.697563              163.167068
# 1               156.608358              167.925743              144.281351
# 2               153.845851              153.956437              159.831766
# 3               159.048246              155.892607              155.093766
# 4               148.583782              181.044455              154.058066
# 5               164.549052              144.257100              154.765438
# 6               131.714200              135.445130              139.074644
# 7               125.306956              124.276932              121.198427
# 8               121.369769              121.943878              127.655757
# 9               120.095463              120.817488              120.507466
# 10              127.995375              120.635038              125.563837
# 11              106.700950              109.835588              123.927446
# 12              126.353318              126.980540              128.439486
# 13              131.347634              124.362446              125.209176
# 14              117.208199              118.989827              118.552303
# 15              119.822745              115.848086              107.103210
# 16              130.822551              130.467753              131.474847
# 17              129.830570              145.995953              122.149555
# 18              108.180462              111.231152              122.680022
# 19              124.585471              126.516226              124.650383
#
#     amplitude antenna1_1:3  amplitude antenna1_1:4  amplitude antenna1_1:5  \
# 0               160.810072              154.183679              162.632910
# 1               185.113177              163.377467              156.495741
# 2               152.241638              155.240067              155.855757
# 3               158.385252              165.113856              172.721456
# 4               147.680436              153.238412              159.640241
# 5               149.325946              147.122308              145.451081
# 6               136.180640              127.120382              125.781242
# 7               123.611229              126.694483              134.479296
# 8               130.986439              116.050190              131.947971
# 9               121.008924              121.634882              122.286924
# 10              125.171683              117.176013              116.196142
# 11              127.154050              139.431336              115.092621
# 12              124.640097              111.997191              111.443156
# 13              123.550437              120.276415              118.959577
# 14              120.326247              133.776761              124.268188
# 15              114.114483              122.588401              143.257543
# 16              130.660140              121.165138              126.764349
# 17              104.717766              124.318335              124.755619
# 18              126.003870              119.249934              115.904951
# 19              132.167936              129.719064              129.014249
#
#     amplitude antenna1_1:6  amplitude antenna1_1:7  amplitude antenna1_1:8  \
# 0               172.496874              153.055216              166.591478
# 1               161.747939              158.173184              153.667819
# 2               155.024208              156.982782              163.521048
# 3               175.821530              179.163438              179.369883
# 4               140.978913              162.618354              164.962797
# 5               143.365498              140.814044              144.680027
# 6               133.674857              137.811957              137.734338
# 7               132.935074              123.660968              100.703172
# 8               124.957874              123.661889              126.737871
# 9               125.086067              121.242381              120.780165
# 10              125.165608              120.085890              103.091788
# 11              125.810763              134.388436              112.446741
# 12              101.852637              132.321781              122.444938
# 13              119.580349              121.131218              131.911985
# 14              121.860925              120.124770              116.524097
# 15              107.270344              104.065145              105.983889
# 16              121.598982              129.358944              110.458527
# 17              117.504266              127.015677              134.890825
# 18              115.122357              115.881879              116.787715
# 19              129.452649              127.351632              123.480417
#
#     amplitude antenna1_1:9  ...  phase antenna2_2:391  phase antenna2_2:392  \
# 0               143.557448  ...             -0.320279             -0.230672
# 1               149.161291  ...             -0.859222              0.745325
# 2               163.165573  ...             -0.289572              0.163823
# 3               182.716081  ...              0.079871             -0.507618
# 4               142.340128  ...             -1.439936             -0.126590
# 5               135.098626  ...              0.024360              0.821002
# 6               138.061187  ...             -0.033316              0.649497
# 7               106.733622  ...              0.984915              0.296066
# 8               126.748851  ...              0.343900              0.349408
# 9               108.539095  ...              0.354229              1.034660
# 10              108.592972  ...              0.800153              1.068595
# 11              110.816400  ...              0.787305              1.032310
# 12              127.940054  ...              0.907045             -0.040933
# 13              123.539188  ...              0.005175             -0.131929
# 14              119.769928  ...             -0.690541              0.279775
# 15              113.021336  ...             -0.365291             -0.044464
# 16              132.946514  ...              0.283221             -0.410994
# 17              108.816994  ...             -0.179250              0.295153
# 18              117.548732  ...              0.318028              0.771467
# 19              120.674202  ...              0.937781              0.377561
#
#     phase antenna2_2:393  phase antenna2_2:394  phase antenna2_2:395  \
# 0              -0.346809             -0.027293              0.493355
# 1              -0.734972             -0.078414              0.668982
# 2               0.660737             -0.076887             -1.255819
# 3               0.591377              0.403453              0.127490
# 4              -0.494261             -0.472938             -0.893271
# 5               0.220974              0.743454              0.336317
# 6              -0.522002             -0.723522              0.193572
# 7               0.121256              0.182824              0.008533
# 8              -0.051746             -0.629792             -0.937591
# 9              -0.421164              0.473948             -0.222162
# 10              0.236784             -0.239137             -0.131891
# 11              0.098523             -0.458038              0.065578
# 12              0.994191              0.681901             -0.090240
# 13              0.014535              1.008486              0.252453
# 14              0.615678              0.947652              0.706559
# 15              0.341703              0.579487              0.186221
# 16              0.177939              0.519889              1.045032
# 17              0.214762              0.633537              1.632786
# 18              0.636562              0.990444             -0.451011
# 19              1.072371              0.376938             -0.303171
#
#     phase antenna2_2:396  phase antenna2_2:397  phase antenna2_2:398  \
# 0               0.279054              0.687361              0.714382
# 1              -0.089655             -0.684514              0.241521
# 2              -0.175068              0.061667             -0.354293
# 3               0.223667              0.503309             -0.459754
# 4              -0.846530              0.102745             -0.673363
# 5               0.736653             -0.522527              0.024958
# 6               0.805900             -0.743622             -0.291777
# 7               0.392720              0.193429              0.545337
# 8               1.803728              0.634331             -0.322128
# 9               0.537887              0.060489             -0.214762
# 10              0.273289              0.406509              0.444913
# 11              0.165698              0.418808             -0.393771
# 12              0.290311              0.313629              0.324598
# 13              0.145311              0.133522             -0.227793
# 14              0.158416              0.905108              0.496535
# 15              0.324219             -0.324924              1.130166
# 16              0.526199              0.087652              1.209278
# 17             -0.879929              0.446021             -0.170925
# 18             -0.276982              0.231378             -0.269015
# 19              0.968589             -0.283306             -0.142997
#
#     phase antenna2_2:399      label
# 0              -0.536424  No_person
# 1              -1.111129  No_person
# 2              -0.400976  No_person
# 3               0.704625  No_person
# 4              -0.301153  No_person
# 5              -0.099664  No_person
# 6               0.684250  No_person
# 7               0.033252  No_person
# 8               0.177742  No_person
# 9              -0.033091  No_person
# 10             -0.534650  No_person
# 11              0.629180  No_person
# 12              0.723255  No_person
# 13              0.714886  No_person
# 14             -0.079633  No_person
# 15              0.124815  No_person
# 16             -0.034021  No_person
# 17              0.140506  No_person
# 18             -0.235584  No_person
# 19              0.878497  No_person
#
# [20 rows x 3201 columns]

# %%
no_activity2 = pd.read_csv('No_person_data_422_amplitudes_phases.csv')
no_activity2
# Out:
#     amplitude antenna1_1:0  amplitude antenna1_1:1  amplitude antenna1_1:2  \
# 0               148.921406              138.478919              111.739155
# 1               172.996870              132.296808              150.925146
# 2               150.409571              142.258939              129.527977
# 3               129.979415              119.037710              123.187965
# 4               127.328865              130.597847              134.496398
# 5               165.154399              109.367316              112.557406
# 6               130.355379              127.092773              133.156998
# 7               102.739940              147.179872              109.527481
# 8               121.466537              130.392235              138.911890
# 9               121.989243              138.818271              118.234633
# 10              110.650617              108.884435              112.335599
# 11              106.869328              109.485542              105.170412
# 12              127.324106              128.173444              128.375787
# 13              106.682977              107.412790              108.236784
# 14              116.128094              115.227825              122.307009
# 15              110.336113              129.431256              115.405279
# 16              113.620494              112.924386              112.890615
# 17              119.174574              120.724285               97.623426
# 18              107.880961               92.716946               90.803476
# 19              101.579223              103.215816              109.695713
#
#     amplitude antenna1_1:3  amplitude antenna1_1:4  amplitude antenna1_1:5  \
# 0               110.387491              127.377833              133.347791
# 1               152.201917              146.611503              147.077977
# 2               116.480448              129.981604              128.965590
# 3               125.077260              128.156196              130.352503
# 4               120.267901              131.542971              136.159878
# 5               150.603455              129.646212              127.324015
# 6               129.316661              123.240760              126.791623
# 7               106.232836              149.977924               85.117257
# 8               135.504573              154.750785              112.147135
# 9               126.108876              133.666373              137.505951
# 10              108.438388              111.295246               96.970731
# 11              103.737094              106.995323              110.559429
# 12              126.710760              121.900037              120.143613
# 13              108.994515              109.523667              110.617133
# 14              109.181186              121.359257              106.904255
# 15              110.728790              113.759130              114.104332
# 16              114.321272              119.961851              119.140606
# 17              127.535314              115.775696               98.944364
# 18              118.136064              102.561845               98.428585
# 19              107.712787               95.803784               96.938774
#
#     amplitude antenna1_1:6  amplitude antenna1_1:7  amplitude antenna1_1:8  \
# 0               146.997653              118.327191              108.010743
# 1               145.593141              146.243749              120.750678
# 2               119.370725              114.446132              136.939890
# 3               130.445554              127.569661              120.979202
# 4               136.853215              135.905435              132.583493
# 5               133.048667              131.470577              129.481863
# 6               133.491487              146.690795              137.362402
# 7               147.730210              108.856165              120.319831
# 8               119.530142              174.496752              141.130148
# 9               138.474096              138.416889              136.859415
# 10              114.853457              121.551812              117.540711
# 11              116.952188              112.407888               96.157087
# 12              111.157552              118.432874              100.803309
# 13              111.797416              114.300709              116.026475
# 14              111.125608              113.693764              114.964575
# 15              114.826326              116.985119              121.431964
# 16              121.046536              118.480435              122.449916
# 17              115.820071              107.088093              111.741011
# 18              107.427184              100.333119              104.324007
# 19              103.591434              134.859966              112.224224
#
#     amplitude antenna1_1:9  ...  phase antenna2_2:391  phase antenna2_2:392  \
# 0               108.121127  ...              6.091629              0.032948
# 1               148.086560  ...              2.401242              4.233961
# 2               155.731251  ...             -4.361953             11.314682
# 3               119.024380  ...            -11.578523             -2.324481
# 4               128.953332  ...             -3.356515             -2.172017
# 5               125.098755  ...              1.256745              2.403487
# 6               134.174800  ...              0.827055             -5.478403
# 7               125.914139  ...              1.743382              1.551911
# 8               105.788435  ...             -1.710465              1.444055
# 9               136.262687  ...             -4.283646              2.104310
# 10              118.333721  ...              6.918180              8.577274
# 11               93.052027  ...             -3.757555             -1.440232
# 12               97.480819  ...              2.600894             -1.295243
# 13              119.011570  ...              0.835363             -0.838824
# 14              117.275640  ...              3.467477              1.341547
# 15              123.288307  ...              2.879580             -2.010114
# 16              107.269632  ...             -8.556210              4.184221
# 17               98.031489  ...              1.373273             -3.997045
# 18              105.833784  ...              2.584153              5.390565
# 19              103.897964  ...              1.355021              2.250505
#
#     phase antenna2_2:393  phase antenna2_2:394  phase antenna2_2:395  \
# 0               0.671529              0.131295              4.165907
# 1              -0.484837              8.063607              4.465790
# 2               4.024572             -0.247033            -10.545973
# 3               2.118014             -4.547185              0.853666
# 4               0.123783              3.319970              7.119905
# 5              -2.822637              1.487039             -0.527958
# 6               2.557427              4.998290             -0.713304
# 7               3.871337             -0.551278             10.286629
# 8               2.586334              9.441019              2.972547
# 9               3.269259              1.047026              3.618665
# 10             -0.613048              2.489420             15.543919
# 11              2.806729             -0.240883             -4.771370
# 12              5.893094              1.158472              7.235737
# 13              0.840114              0.625555              0.126259
# 14              1.983052              9.223571              0.128426
# 15              7.229430              0.669739              4.043471
# 16              9.305497             -0.241682             12.184534
# 17             -4.189784              1.624384              4.481958
# 18              7.882923             -0.911209              1.131598
# 19             -2.288982             -0.049769              5.341769
#
#     phase antenna2_2:396  phase antenna2_2:397  phase antenna2_2:398  \
# 0               6.210272              2.266680              6.959455
# 1               1.623324              0.091225              8.179501
# 2               7.560474              1.439511              2.190911
# 3              -7.081882              1.260613              2.292695
# 4               1.210518              1.214643              3.179598
# 5               3.335036             -0.164925             -1.111551
# 6               1.647155              0.182354              2.100405
# 7               1.938652              2.579611             -0.974577
# 8               1.302225             -4.216533              7.056657
# 9              -0.215442              5.148875             -5.122029
# 10             10.489032             10.703219             -0.881807
# 11              0.848773             -8.452152              5.897726
# 12              1.434050              7.517502              6.907728
# 13              6.259753             12.002658              8.315164
# 14              0.047884              6.257628              6.301275
# 15              3.449376             -1.432863              6.814564
# 16             -6.222113              5.499978             -5.793153
# 17              3.049503             -5.130531              1.581352
# 18              3.480469              2.047484              2.001371
# 19              0.319721             -1.541300             -0.539917
#
#     phase antenna2_2:399      label
# 0               7.762499  No_person
# 1              -0.713788  No_person
# 2               3.712812  No_person
# 3               0.894162  No_person
# 4               0.056425  No_person
# 5               1.305881  No_person
# 6               1.922894  No_person
# 7              -8.434409  No_person
# 8               3.349705  No_person
# 9               9.139854  No_person
# 10             15.330030  No_person
# 11              1.452555  No_person
# 12              2.482878  No_person
# 13              3.279474  No_person
# 14             -4.831301  No_person
# 15              7.454122  No_person
# 16              7.024046  No_person
# 17              2.059527  No_person
# 18             -3.285192  No_person
# 19              2.619359  No_person
#
# [20 rows x 3201 columns]

# %%
df_1 = pd.concat([datasets1[0],no_activity1], axis=0)
df_2 = pd.concat([datasets1[0],datasets1[1],no_activity1], axis=0)
df_3 = pd.concat([datasets1[0],datasets1[1],datasets1[2],no_activity1], axis=0)
df_4 = pd.concat([datasets1[0],datasets1[1],datasets1[2],datasets1[3],no_activity1], axis=0)
df_5 = pd.concat([datasets1[0],datasets1[1],datasets1[2],datasets1[3],datasets1[4],no_activity1], axis=0)
df_6 = pd.concat([datasets1[0],datasets1[1],datasets1[2],datasets1[3],datasets1[4],datasets1[5],no_activity1], axis=0)
df_7 = pd.concat([datasets1[0],datasets1[1],datasets1[2],datasets1[3],datasets1[4],datasets1[5],datasets1[6],no_activity1], axis=0)
df_8 = pd.concat([datasets1[0],datasets1[1],datasets1[2],datasets1[3],datasets1[4],datasets1[5],datasets1[6],datasets1[7],no_activity1], axis=0)
df_9_all1 = pd.concat([datasets1[0],datasets1[1],datasets1[2],datasets1[3],datasets1[4],datasets1[5],datasets1[6],datasets1[7],datasets1[8],no_activity1], axis=0)

# %%
df_12 = pd.concat([datasets2[0],no_activity2], axis=0)
df_22 = pd.concat([datasets2[0],datasets2[1],no_activity2], axis=0)
df_32 = pd.concat([datasets2[0],datasets2[1],datasets2[2],no_activity2], axis=0)
df_42 = pd.concat([datasets2[0],datasets2[1],datasets2[2],datasets2[3],no_activity2], axis=0)
df_52 = pd.concat([datasets2[0],datasets2[1],datasets2[2],datasets2[3],datasets2[4],no_activity2], axis=0)
df_62 = pd.concat([datasets2[0],datasets2[1],datasets2[2],datasets2[3],datasets2[4],datasets2[5],no_activity2], axis=0)
df_72 = pd.concat([datasets2[0],datasets2[1],datasets2[2],datasets2[3],datasets2[4],datasets2[5],datasets2[6],no_activity2], axis=0)
df_82 = pd.concat([datasets2[0],datasets2[1],datasets2[2],datasets2[3],datasets2[4],datasets2[5],datasets2[6],datasets2[7],no_activity2], axis=0)
df_9_all2 = pd.concat([datasets2[0],datasets2[1],datasets2[2],datasets2[3],datasets2[4],datasets2[5],datasets2[6],datasets2[7],datasets2[8],no_activity2], axis=0)

# %%
df_9_all = pd.concat([df_9_all1,df_9_all2], axis=0)

# %%
df_9_all1.to_csv(r'df_9_all_users_421_amplitudes_phases.csv')

# %%
df_9_all2.to_csv(r'df_9_all_users_422_amplitudes_phases.csv')

# %%
df_9_all.to_csv(r'df_9_all_users_421&422_amplitudes_phases.csv')

# %%
#using 2 antennas
dataset1 = pd.read_csv('df_9_all_users_421_amplitudes_phases.csv').drop('Unnamed: 0',axis=1)
dataset1
# Out:
#      amplitude antenna1_1:0  amplitude antenna1_1:1  amplitude antenna1_1:2  \
# 0                118.821378              112.822911              106.837022
# 1                148.483371              144.639285              148.567575
# 2                109.886172              145.986950              138.764032
# 3                155.667170              154.183109              153.547271
# 4                150.309929              119.433062              112.872474
# ..                      ...                     ...                     ...
# 201              119.822745              115.848086              107.103210
# 202              130.822551              130.467753              131.474847
# 203              129.830570              145.995953              122.149555
# 204              108.180462              111.231152              122.680022
# 205              124.585471              126.516226              124.650383
#
#      amplitude antenna1_1:3  amplitude antenna1_1:4  amplitude antenna1_1:5  \
# 0                109.709404              124.425956              129.814456
# 1                149.388417              147.388802              146.997656
# 2                136.643491              135.532147              132.000261
# 3                153.346520              154.359047              153.636943
# 4                108.606127              108.489992              116.570441
# ..                      ...                     ...                     ...
# 201              114.114483              122.588401              143.257543
# 202              130.660140              121.165138              126.764349
# 203              104.717766              124.318335              124.755619
# 204              126.003870              119.249934              115.904951
# 205              132.167936              129.719064              129.014249
#
#      amplitude antenna1_1:6  amplitude antenna1_1:7  amplitude antenna1_1:8  \
# 0                126.797810              119.930096              117.196770
# 1                148.275791              146.360987              142.007667
# 2                130.647803              129.475652              128.704237
# 3                150.047910              150.574210              154.526000
# 4                118.229584              114.287015              112.234404
# ..                      ...                     ...                     ...
# 201              107.270344              104.065145              105.983889
# 202              121.598982              129.358944              110.458527
# 203              117.504266              127.015677              134.890825
# 204              115.122357              115.881879              116.787715
# 205              129.452649              127.351632              123.480417
#
#      amplitude antenna1_1:9  ...  phase antenna2_2:391  phase antenna2_2:392  \
# 0                114.168474  ...              0.338336              0.043629
# 1                140.340542  ...             -0.589837              0.239678
# 2                129.522509  ...              0.679886             -0.202390
# 3                154.037910  ...             -0.969124              1.449868
# 4                115.601707  ...             -0.476618              0.329255
# ..                      ...  ...                   ...                   ...
# 201              113.021336  ...             -0.365291             -0.044464
# 202              132.946514  ...              0.283221             -0.410994
# 203              108.816994  ...             -0.179250              0.295153
# 204              117.548732  ...              0.318028              0.771467
# 205              120.674202  ...              0.937781              0.377561
#
#      phase antenna2_2:393  phase antenna2_2:394  phase antenna2_2:395  \
# 0                0.204637             -0.898825             -0.072797
# 1               -2.576487             -4.509775             -1.023096
# 2                0.239198             -1.601885             -0.471877
# 3                0.498628             -0.429339             -1.159371
# 4               -0.477999             -0.202025             -0.041491
# ..                    ...                   ...                   ...
# 201              0.341703              0.579487              0.186221
# 202              0.177939              0.519889              1.045032
# 203              0.214762              0.633537              1.632786
# 204              0.636562              0.990444             -0.451011
# 205              1.072371              0.376938             -0.303171
#
#      phase antenna2_2:396  phase antenna2_2:397  phase antenna2_2:398  \
# 0                0.671153              0.676866             -0.525145
# 1               -2.149382              1.149288             -4.969789
# 2               -0.052204              0.026742             -0.220398
# 3                1.293141              0.052404              0.119457
# 4               -0.496974              0.869297              0.273831
# ..                    ...                   ...                   ...
# 201              0.324219             -0.324924              1.130166
# 202              0.526199              0.087652              1.209278
# 203             -0.879929              0.446021             -0.170925
# 204             -0.276982              0.231378             -0.269015
# 205              0.968589             -0.283306             -0.142997
#
#      phase antenna2_2:399           label
# 0               -0.468376  left_direction
# 1               -0.837617  left_direction
# 2               -0.418835  left_direction
# 3               -0.089252  left_direction
# 4                0.927966  left_direction
# ..                    ...             ...
# 201              0.124815       No_person
# 202             -0.034021       No_person
# 203              0.140506       No_person
# 204             -0.235584       No_person
# 205              0.878497       No_person
#
# [206 rows x 3201 columns]

# %%
#using 2 antennas
dataset2 = pd.read_csv('df_9_all_users_422_amplitudes_phases.csv').drop('Unnamed: 0',axis=1)
dataset2
# Out:
#      amplitude antenna1_1:0  amplitude antenna1_1:1  amplitude antenna1_1:2  \
# 0                255.408448              256.845062              238.869712
# 1                246.146937              244.973766              220.851457
# 2                231.136582              232.687284              235.453669
# 3                242.896318              233.410750              230.610184
# 4                247.620151              250.812291              242.338649
# ..                      ...                     ...                     ...
# 197              110.336113              129.431256              115.405279
# 198              113.620494              112.924386              112.890615
# 199              119.174574              120.724285               97.623426
# 200              107.880961               92.716946               90.803476
# 201              101.579223              103.215816              109.695713
#
#      amplitude antenna1_1:3  amplitude antenna1_1:4  amplitude antenna1_1:5  \
# 0                245.692967              248.616090              235.114531
# 1                216.538726              235.143090              244.435189
# 2                235.834520              221.107084              216.739403
# 3                233.457734              234.620198              248.138665
# 4                241.080150              244.163769              246.027683
# ..                      ...                     ...                     ...
# 197              110.728790              113.759130              114.104332
# 198              114.321272              119.961851              119.140606
# 199              127.535314              115.775696               98.944364
# 200              118.136064              102.561845               98.428585
# 201              107.712787               95.803784               96.938774
#
#      amplitude antenna1_1:6  amplitude antenna1_1:7  amplitude antenna1_1:8  \
# 0                253.614301              230.071366              233.833652
# 1                250.616794              244.497788              243.929262
# 2                239.408848              244.231174              243.633197
# 3                210.291412              264.944862              238.630337
# 4                246.353721              249.347121              249.227465
# ..                      ...                     ...                     ...
# 197              114.826326              116.985119              121.431964
# 198              121.046536              118.480435              122.449916
# 199              115.820071              107.088093              111.741011
# 200              107.427184              100.333119              104.324007
# 201              103.591434              134.859966              112.224224
#
#      amplitude antenna1_1:9  ...  phase antenna2_2:391  phase antenna2_2:392  \
# 0                241.812226  ...              0.925651              1.977109
# 1                240.269599  ...              4.015907              1.856945
# 2                225.027699  ...              1.971364             -5.231626
# 3                231.731246  ...              0.478470              2.780300
# 4                256.503926  ...              1.063346              0.987371
# ..                      ...  ...                   ...                   ...
# 197              123.288307  ...              2.879580             -2.010114
# 198              107.269632  ...             -8.556210              4.184221
# 199               98.031489  ...              1.373273             -3.997045
# 200              105.833784  ...              2.584153              5.390565
# 201              103.897964  ...              1.355021              2.250505
#
#      phase antenna2_2:393  phase antenna2_2:394  phase antenna2_2:395  \
# 0               -0.076000              0.701390              0.946679
# 1                1.634922              2.868157             -2.598609
# 2                1.335634              1.403948              0.221963
# 3                4.114707              2.359960              0.738125
# 4                7.494369              2.740151              0.296221
# ..                    ...                   ...                   ...
# 197              7.229430              0.669739              4.043471
# 198              9.305497             -0.241682             12.184534
# 199             -4.189784              1.624384              4.481958
# 200              7.882923             -0.911209              1.131598
# 201             -2.288982             -0.049769              5.341769
#
#      phase antenna2_2:396  phase antenna2_2:397  phase antenna2_2:398  \
# 0                0.354959              1.084616              1.729726
# 1                1.450499              4.813834              0.463380
# 2                2.350598             -4.940310              1.298321
# 3                0.398679              2.803338              3.477338
# 4                0.163648              1.106713              1.022716
# ..                    ...                   ...                   ...
# 197              3.449376             -1.432863              6.814564
# 198             -6.222113              5.499978             -5.793153
# 199              3.049503             -5.130531              1.581352
# 200              3.480469              2.047484              2.001371
# 201              0.319721             -1.541300             -0.539917
#
#      phase antenna2_2:399           label
# 0                0.741469  left_direction
# 1                3.235748  left_direction
# 2                1.621090  left_direction
# 3                1.944250  left_direction
# 4                1.582583  left_direction
# ..                    ...             ...
# 197              7.454122       No_person
# 198              7.024046       No_person
# 199              2.059527       No_person
# 200             -3.285192       No_person
# 201              2.619359       No_person
#
# [202 rows x 3201 columns]

# %%
dataset = pd.read_csv('df_9_all_users_421&422_amplitudes_phases.csv').drop('Unnamed: 0',axis=1)
dataset
# Out:
#      amplitude antenna1_1:0  amplitude antenna1_1:1  amplitude antenna1_1:2  \
# 0                118.821378              112.822911              106.837022
# 1                148.483371              144.639285              148.567575
# 2                109.886172              145.986950              138.764032
# 3                155.667170              154.183109              153.547271
# 4                150.309929              119.433062              112.872474
# ..                      ...                     ...                     ...
# 403              110.336113              129.431256              115.405279
# 404              113.620494              112.924386              112.890615
# 405              119.174574              120.724285               97.623426
# 406              107.880961               92.716946               90.803476
# 407              101.579223              103.215816              109.695713
#
#      amplitude antenna1_1:3  amplitude antenna1_1:4  amplitude antenna1_1:5  \
# 0                109.709404              124.425956              129.814456
# 1                149.388417              147.388802              146.997656
# 2                136.643491              135.532147              132.000261
# 3                153.346520              154.359047              153.636943
# 4                108.606127              108.489992              116.570441
# ..                      ...                     ...                     ...
# 403              110.728790              113.759130              114.104332
# 404              114.321272              119.961851              119.140606
# 405              127.535314              115.775696               98.944364
# 406              118.136064              102.561845               98.428585
# 407              107.712787               95.803784               96.938774
#
#      amplitude antenna1_1:6  amplitude antenna1_1:7  amplitude antenna1_1:8  \
# 0                126.797810              119.930096              117.196770
# 1                148.275791              146.360987              142.007667
# 2                130.647803              129.475652              128.704237
# 3                150.047910              150.574210              154.526000
# 4                118.229584              114.287015              112.234404
# ..                      ...                     ...                     ...
# 403              114.826326              116.985119              121.431964
# 404              121.046536              118.480435              122.449916
# 405              115.820071              107.088093              111.741011
# 406              107.427184              100.333119              104.324007
# 407              103.591434              134.859966              112.224224
#
#      amplitude antenna1_1:9  ...  phase antenna2_2:391  phase antenna2_2:392  \
# 0                114.168474  ...              0.338336              0.043629
# 1                140.340542  ...             -0.589837              0.239678
# 2                129.522509  ...              0.679886             -0.202390
# 3                154.037910  ...             -0.969124              1.449868
# 4                115.601707  ...             -0.476618              0.329255
# ..                      ...  ...                   ...                   ...
# 403              123.288307  ...              2.879580             -2.010114
# 404              107.269632  ...             -8.556210              4.184221
# 405               98.031489  ...              1.373273             -3.997045
# 406              105.833784  ...              2.584153              5.390565
# 407              103.897964  ...              1.355021              2.250505
#
#      phase antenna2_2:393  phase antenna2_2:394  phase antenna2_2:395  \
# 0                0.204637             -0.898825             -0.072797
# 1               -2.576487             -4.509775             -1.023096
# 2                0.239198             -1.601885             -0.471877
# 3                0.498628             -0.429339             -1.159371
# 4               -0.477999             -0.202025             -0.041491
# ..                    ...                   ...                   ...
# 403              7.229430              0.669739              4.043471
# 404              9.305497             -0.241682             12.184534
# 405             -4.189784              1.624384              4.481958
# 406              7.882923             -0.911209              1.131598
# 407             -2.288982             -0.049769              5.341769
#
#      phase antenna2_2:396  phase antenna2_2:397  phase antenna2_2:398  \
# 0                0.671153              0.676866             -0.525145
# 1               -2.149382              1.149288             -4.969789
# 2               -0.052204              0.026742             -0.220398
# 3                1.293141              0.052404              0.119457
# 4               -0.496974              0.869297              0.273831
# ..                    ...                   ...                   ...
# 403              3.449376             -1.432863              6.814564
# 404             -6.222113              5.499978             -5.793153
# 405              3.049503             -5.130531              1.581352
# 406              3.480469              2.047484              2.001371
# 407              0.319721             -1.541300             -0.539917
#
#      phase antenna2_2:399           label
# 0               -0.468376  left_direction
# 1               -0.837617  left_direction
# 2               -0.418835  left_direction
# 3               -0.089252  left_direction
# 4                0.927966  left_direction
# ..                    ...             ...
# 403              7.454122       No_person
# 404              7.024046       No_person
# 405              2.059527       No_person
# 406             -3.285192       No_person
# 407              2.619359       No_person
#
# [408 rows x 3201 columns]

# %% [markdown]
# # Train the dataset

# %%
#Data encoding: to convert categorical features to numberical
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# %%
dataset1['label']=label_encoder.fit_transform(dataset1['label'])
dataset1
# Out:
#      amplitude antenna1_1:0  amplitude antenna1_1:1  amplitude antenna1_1:2  \
# 0                118.821378              112.822911              106.837022
# 1                148.483371              144.639285              148.567575
# 2                109.886172              145.986950              138.764032
# 3                155.667170              154.183109              153.547271
# 4                150.309929              119.433062              112.872474
# ..                      ...                     ...                     ...
# 201              119.822745              115.848086              107.103210
# 202              130.822551              130.467753              131.474847
# 203              129.830570              145.995953              122.149555
# 204              108.180462              111.231152              122.680022
# 205              124.585471              126.516226              124.650383
#
#      amplitude antenna1_1:3  amplitude antenna1_1:4  amplitude antenna1_1:5  \
# 0                109.709404              124.425956              129.814456
# 1                149.388417              147.388802              146.997656
# 2                136.643491              135.532147              132.000261
# 3                153.346520              154.359047              153.636943
# 4                108.606127              108.489992              116.570441
# ..                      ...                     ...                     ...
# 201              114.114483              122.588401              143.257543
# 202              130.660140              121.165138              126.764349
# 203              104.717766              124.318335              124.755619
# 204              126.003870              119.249934              115.904951
# 205              132.167936              129.719064              129.014249
#
#      amplitude antenna1_1:6  amplitude antenna1_1:7  amplitude antenna1_1:8  \
# 0                126.797810              119.930096              117.196770
# 1                148.275791              146.360987              142.007667
# 2                130.647803              129.475652              128.704237
# 3                150.047910              150.574210              154.526000
# 4                118.229584              114.287015              112.234404
# ..                      ...                     ...                     ...
# 201              107.270344              104.065145              105.983889
# 202              121.598982              129.358944              110.458527
# 203              117.504266              127.015677              134.890825
# 204              115.122357              115.881879              116.787715
# 205              129.452649              127.351632              123.480417
#
#      amplitude antenna1_1:9  ...  phase antenna2_2:391  phase antenna2_2:392  \
# 0                114.168474  ...              0.338336              0.043629
# 1                140.340542  ...             -0.589837              0.239678
# 2                129.522509  ...              0.679886             -0.202390
# 3                154.037910  ...             -0.969124              1.449868
# 4                115.601707  ...             -0.476618              0.329255
# ..                      ...  ...                   ...                   ...
# 201              113.021336  ...             -0.365291             -0.044464
# 202              132.946514  ...              0.283221             -0.410994
# 203              108.816994  ...             -0.179250              0.295153
# 204              117.548732  ...              0.318028              0.771467
# 205              120.674202  ...              0.937781              0.377561
#
#      phase antenna2_2:393  phase antenna2_2:394  phase antenna2_2:395  \
# 0                0.204637             -0.898825             -0.072797
# 1               -2.576487             -4.509775             -1.023096
# 2                0.239198             -1.601885             -0.471877
# 3                0.498628             -0.429339             -1.159371
# 4               -0.477999             -0.202025             -0.041491
# ..                    ...                   ...                   ...
# 201              0.341703              0.579487              0.186221
# 202              0.177939              0.519889              1.045032
# 203              0.214762              0.633537              1.632786
# 204              0.636562              0.990444             -0.451011
# 205              1.072371              0.376938             -0.303171
#
#      phase antenna2_2:396  phase antenna2_2:397  phase antenna2_2:398  \
# 0                0.671153              0.676866             -0.525145
# 1               -2.149382              1.149288             -4.969789
# 2               -0.052204              0.026742             -0.220398
# 3                1.293141              0.052404              0.119457
# 4               -0.496974              0.869297              0.273831
# ..                    ...                   ...                   ...
# 201              0.324219             -0.324924              1.130166
# 202              0.526199              0.087652              1.209278
# 203             -0.879929              0.446021             -0.170925
# 204             -0.276982              0.231378             -0.269015
# 205              0.968589             -0.283306             -0.142997
#
#      phase antenna2_2:399  label
# 0               -0.468376      2
# 1               -0.837617      2
# 2               -0.418835      2
# 3               -0.089252      2
# 4                0.927966      2
# ..                    ...    ...
# 201              0.124815      0
# 202             -0.034021      0
# 203              0.140506      0
# 204             -0.235584      0
# 205              0.878497      0
#
# [206 rows x 3201 columns]

# %%
dataset2['label']=label_encoder.fit_transform(dataset2['label'])
dataset2
# Out:
#      amplitude antenna1_1:0  amplitude antenna1_1:1  amplitude antenna1_1:2  \
# 0                255.408448              256.845062              238.869712
# 1                246.146937              244.973766              220.851457
# 2                231.136582              232.687284              235.453669
# 3                242.896318              233.410750              230.610184
# 4                247.620151              250.812291              242.338649
# ..                      ...                     ...                     ...
# 197              110.336113              129.431256              115.405279
# 198              113.620494              112.924386              112.890615
# 199              119.174574              120.724285               97.623426
# 200              107.880961               92.716946               90.803476
# 201              101.579223              103.215816              109.695713
#
#      amplitude antenna1_1:3  amplitude antenna1_1:4  amplitude antenna1_1:5  \
# 0                245.692967              248.616090              235.114531
# 1                216.538726              235.143090              244.435189
# 2                235.834520              221.107084              216.739403
# 3                233.457734              234.620198              248.138665
# 4                241.080150              244.163769              246.027683
# ..                      ...                     ...                     ...
# 197              110.728790              113.759130              114.104332
# 198              114.321272              119.961851              119.140606
# 199              127.535314              115.775696               98.944364
# 200              118.136064              102.561845               98.428585
# 201              107.712787               95.803784               96.938774
#
#      amplitude antenna1_1:6  amplitude antenna1_1:7  amplitude antenna1_1:8  \
# 0                253.614301              230.071366              233.833652
# 1                250.616794              244.497788              243.929262
# 2                239.408848              244.231174              243.633197
# 3                210.291412              264.944862              238.630337
# 4                246.353721              249.347121              249.227465
# ..                      ...                     ...                     ...
# 197              114.826326              116.985119              121.431964
# 198              121.046536              118.480435              122.449916
# 199              115.820071              107.088093              111.741011
# 200              107.427184              100.333119              104.324007
# 201              103.591434              134.859966              112.224224
#
#      amplitude antenna1_1:9  ...  phase antenna2_2:391  phase antenna2_2:392  \
# 0                241.812226  ...              0.925651              1.977109
# 1                240.269599  ...              4.015907              1.856945
# 2                225.027699  ...              1.971364             -5.231626
# 3                231.731246  ...              0.478470              2.780300
# 4                256.503926  ...              1.063346              0.987371
# ..                      ...  ...                   ...                   ...
# 197              123.288307  ...              2.879580             -2.010114
# 198              107.269632  ...             -8.556210              4.184221
# 199               98.031489  ...              1.373273             -3.997045
# 200              105.833784  ...              2.584153              5.390565
# 201              103.897964  ...              1.355021              2.250505
#
#      phase antenna2_2:393  phase antenna2_2:394  phase antenna2_2:395  \
# 0               -0.076000              0.701390              0.946679
# 1                1.634922              2.868157             -2.598609
# 2                1.335634              1.403948              0.221963
# 3                4.114707              2.359960              0.738125
# 4                7.494369              2.740151              0.296221
# ..                    ...                   ...                   ...
# 197              7.229430              0.669739              4.043471
# 198              9.305497             -0.241682             12.184534
# 199             -4.189784              1.624384              4.481958
# 200              7.882923             -0.911209              1.131598
# 201             -2.288982             -0.049769              5.341769
#
#      phase antenna2_2:396  phase antenna2_2:397  phase antenna2_2:398  \
# 0                0.354959              1.084616              1.729726
# 1                1.450499              4.813834              0.463380
# 2                2.350598             -4.940310              1.298321
# 3                0.398679              2.803338              3.477338
# 4                0.163648              1.106713              1.022716
# ..                    ...                   ...                   ...
# 197              3.449376             -1.432863              6.814564
# 198             -6.222113              5.499978             -5.793153
# 199              3.049503             -5.130531              1.581352
# 200              3.480469              2.047484              2.001371
# 201              0.319721             -1.541300             -0.539917
#
#      phase antenna2_2:399  label
# 0                0.741469      2
# 1                3.235748      2
# 2                1.621090      2
# 3                1.944250      2
# 4                1.582583      2
# ..                    ...    ...
# 197              7.454122      0
# 198              7.024046      0
# 199              2.059527      0
# 200             -3.285192      0
# 201              2.619359      0
#
# [202 rows x 3201 columns]

# %%
dataset['label']=label_encoder.fit_transform(dataset['label'])

# %%
y_1=dataset1['label']
X_1=dataset1.drop('label',axis=1)

# %%
y_2=dataset2['label']
X_2=dataset2.drop('label',axis=1)

# %%
y=dataset['label']
X=dataset.drop('label',axis=1)

# %%
#Trainset Splitting
from sklearn.model_selection import train_test_split
X_train_1, X_test_1, y_train_1, y_test_1= train_test_split(X_1, y_1, test_size=0.2,random_state=123)
X_train_2, X_test_2, y_train_2, y_test_2= train_test_split(X_2, y_2, test_size=0.2,random_state=123)
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.2,random_state=123)

# %%
#X_train=pd.concat([X_train_1,X_train_2], axis=0)
#y_train=pd.concat([y_train_1,y_train_2], axis=0)
#X_test=pd.concat([X_test_1,X_test_2], axis=0)
#y_test=pd.concat([y_test_1,y_test_2], axis=0)

# %%
X_train.shape,X_train_1.shape,X_train_2.shape
# Out:
# ((326, 3200), (164, 3200), (161, 3200))

# %%
X_test.shape,X_test_1.shape,X_test_2.shape
# Out:
# ((82, 3200), (42, 3200), (41, 3200))

# %% [markdown]
#  2      3     4    1    0:
# left   right  up  down  No

# %%
dataset1.shape
# Out:
# (206, 3201)

# %%
dataset2.shape
# Out:
# (202, 3201)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from sklearn.preprocessing import StandardScaler  

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train.values.reshape(X_train.shape[0], -1))
X_test_scaled = scaler.transform(X_test.values.reshape(X_test.shape[0], -1))

X_train_reshaped = np.reshape(X_train_scaled, (X_train.shape[0], 3200, 1))
X_test_reshaped = np.reshape(X_test_scaled, (X_test.shape[0], 3200, 1))

# Define the model
model_cnn = Sequential()

# Add a 1D Convolutional layer
model_cnn.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(3200, 1)))
model_cnn.add(MaxPooling1D(pool_size=2))
model_cnn.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model_cnn.add(MaxPooling1D(pool_size=2))
model_cnn.add(Flatten())  # Flatten the output for the dense layers

# Add dense layers
model_cnn.add(Dense(512, activation='relu'))
model_cnn.add(Dense(256, activation='relu'))
model_cnn.add(Dense(128, activation='relu'))

# Output layer with 5 classes (assuming 5 different activities)
model_cnn.add(Dense(5, activation='softmax'))

# Compile the model with run_eagerly=True
model_cnn.compile(optimizer=Adam(), loss=SparseCategoricalCrossentropy(), metrics=['accuracy'], run_eagerly=True)

# Print model summary
model_cnn.summary()

# Train the model
history_cnn = model_cnn.fit(X_train_reshaped, y_train.values, epochs=100, batch_size=128, validation_data=(X_test_reshaped, y_test.values))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 3198, 32)          128
#
#  max_pooling1d_2 (MaxPooling  (None, 1599, 32)         0
#  1D)
#
#  conv1d_3 (Conv1D)           (None, 1597, 64)          6208
#
#  max_pooling1d_3 (MaxPooling  (None, 798, 64)          0
#  1D)
#
#  flatten_1 (Flatten)         (None, 51072)             0
#
#  dense_4 (Dense)             (None, 512)               26149376
#
#  dense_5 (Dense)             (None, 256)               131328
#
#  dense_6 (Dense)             (None, 128)               32896
#
#  dense_7 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 26,320,581
# Trainable params: 26,320,581
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 3/3 [==============================] - 2s 482ms/step - loss: 2.5928 - accuracy: 0.2209 - val_loss: 3.7719 - val_accuracy: 0.3902
# Epoch 2/100
# 3/3 [==============================] - 1s 471ms/step - loss: 3.2884 - accuracy: 0.2914 - val_loss: 1.3238 - val_accuracy: 0.3902
# Epoch 3/100
# 3/3 [==============================] - 1s 486ms/step - loss: 1.3289 - accuracy: 0.4540 - val_loss: 1.2321 - val_accuracy: 0.4756
# Epoch 4/100
# 3/3 [==============================] - 1s 466ms/step - loss: 1.0642 - accuracy: 0.5460 - val_loss: 1.0131 - val_accuracy: 0.6098
# Epoch 5/100
# 3/3 [==============================] - 1s 521ms/step - loss: 0.8954 - accuracy: 0.7209 - val_loss: 0.9714 - val_accuracy: 0.6098
# Epoch 6/100
# 3/3 [==============================] - 1s 461ms/step - loss: 0.7493 - accuracy: 0.7761 - val_loss: 0.8699 - val_accuracy: 0.6098
# Epoch 7/100
# 3/3 [==============================] - 1s 451ms/step - loss: 0.5986 - accuracy: 0.8558 - val_loss: 0.7743 - val_accuracy: 0.6829
# Epoch 8/100
# 3/3 [==============================] - 1s 472ms/step - loss: 0.4654 - accuracy: 0.8834 - val_loss: 0.6966 - val_accuracy: 0.6951
# Epoch 9/100
# 3/3 [==============================] - 1s 439ms/step - loss: 0.3333 - accuracy: 0.9294 - val_loss: 0.6391 - val_accuracy: 0.6951
# Epoch 10/100
# 3/3 [==============================] - 1s 499ms/step - loss: 0.2050 - accuracy: 0.9816 - val_loss: 0.6285 - val_accuracy: 0.7195
# Epoch 11/100
# 3/3 [==============================] - 1s 499ms/step - loss: 0.1440 - accuracy: 0.9816 - val_loss: 0.5523 - val_accuracy: 0.7683
# Epoch 12/100
# 3/3 [==============================] - 1s 405ms/step - loss: 0.0832 - accuracy: 0.9969 - val_loss: 0.5701 - val_accuracy: 0.7561
# Epoch 13/100
# 3/3 [==============================] - 1s 415ms/step - loss: 0.0482 - accuracy: 1.0000 - val_loss: 0.5589 - val_accuracy: 0
# 3/3 [==============================] - 1s 452ms/step - loss: 5.2754e-05 - accuracy: 1.0000 - val_loss: 0.7135 - val_accuracy: 0.8171
# Epoch 90/100
# 3/3 [==============================] - 1s 471ms/step - loss: 5.1802e-05 - accuracy: 1.0000 - val_loss: 0.7145 - val_accuracy: 0.8171
# Epoch 91/100
# 3/3 [==============================] - 1s 431ms/step - loss: 5.0884e-05 - accuracy: 1.0000 - val_loss: 0.7154 - val_accuracy: 0.8171
# Epoch 92/100
# 3/3 [==============================] - 1s 442ms/step - loss: 5.0006e-05 - accuracy: 1.0000 - val_loss: 0.7164 - val_accuracy: 0.8171
# Epoch 93/100
# 3/3 [==============================] - 1s 488ms/step - loss: 4.9155e-05 - accuracy: 1.0000 - val_loss: 0.7173 - val_accuracy: 0.8171
# Epoch 94/100
# 3/3 [==============================] - 1s 495ms/step - loss: 4.8371e-05 - accuracy: 1.0000 - val_loss: 0.7177 - val_accuracy: 0.8171
# Epoch 95/100
# 3/3 [==============================] - 1s 482ms/step - loss: 4.7597e-05 - accuracy: 1.0000 - val_loss: 0.7181 - val_accuracy: 0.8171
# Epoch 96/100
# 3/3 [==============================] - 1s 475ms/step - loss: 4.6845e-05 - accuracy: 1.0000 - val_loss: 0.7189 - val_accuracy: 0.8171
# Epoch 97/100
# 3/3 [==============================] - 1s 426ms/step - loss: 4.6124e-05 - accuracy: 1.0000 - val_loss: 0.7198 - val_accuracy: 0.8171
# Epoch 98/100
# 3/3 [==============================] - 1s 466ms/step - loss: 4.5382e-05 - accuracy: 1.0000 - val_loss: 0.7206 - val_accuracy: 0.8171
# Epoch 99/100
# 3/3 [==============================] - 1s 505ms/step - loss: 4.4678e-05 - accuracy: 1.0000 - val_loss: 0.7214 - val_accuracy: 0.8171
# Epoch 100/100
# 3/3 [==============================] - 2s 537ms/step - loss: 4.4053e-05 - accuracy: 1.0000 - val_loss: 0.7224 - val_accuracy: 0.8171

# %%
# Extract losses
train_loss_cnn = history_cnn.history['loss']
val_loss_cnn = history_cnn.history['val_loss']

# Plot the training and validation losses
epochs_cnn = range(1, len(train_loss_cnn) + 1)
plt.plot(epochs_cnn, train_loss_cnn, 'bo', label='Training Loss')
plt.plot(epochs_cnn, val_loss_cnn, 'b', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
training_history_cnn = pd.DataFrame(history_cnn.history)
training_history_cnn.to_csv("history_room1_room2_cnn.csv", index=False)

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming your model is named 'model_cnn' and you have trained it

# Get predictions on the test set
y_pred = model_cnn.predict(X_test_reshaped)
# Convert continuous predictions to discrete class labels
y_pred_labels = np.argmax(y_pred, axis=1)

cm_model_cnn = confusion_matrix(y_test, y_pred_labels, normalize='true')
class_names = ["Empty", "Down", "Left", "Right", "Up"]

# Plot confusion matrix as heatmap
sns.heatmap(cm_model_cnn, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1, xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.savefig("confusion_matrix_lab1&lab2_1D-CNN_amplitudes.pdf", format="pdf")

plt.show()
# Out:
# 3/3 [==============================] - 0s 52ms/step

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy

scaler1 = StandardScaler()

X_train_scaled1 = scaler1.fit_transform(X_train_1.values.reshape(X_train_1.shape[0], -1))
X_test_scaled1 = scaler1.transform(X_test_1.values.reshape(X_test_1.shape[0], -1))

X_train_1_reshaped = np.reshape(X_train_scaled1, (X_train_1.shape[0], 3200, 1))
X_test_1_reshaped = np.reshape(X_test_scaled1, (X_test_1.shape[0], 3200, 1))


# Define the model
model1_cnn = Sequential()

# Add a 1D Convolutional layer
model1_cnn.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(3200, 1)))
model1_cnn.add(MaxPooling1D(pool_size=2))
model1_cnn.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model1_cnn.add(MaxPooling1D(pool_size=2))
model1_cnn.add(Flatten())  # Flatten the output for the dense layers

# Add dense layers
model1_cnn.add(Dense(512, activation='relu'))
model1_cnn.add(Dense(256, activation='relu'))
model1_cnn.add(Dense(128, activation='relu'))

# Output layer with 5 classes (assuming 5 different activities)
model1_cnn.add(Dense(5, activation='softmax'))

# Compile the model with run_eagerly=True
model1_cnn.compile(optimizer=Adam(), loss=SparseCategoricalCrossentropy(), metrics=['accuracy'], run_eagerly=True)

# Print model summary
model1_cnn.summary()

# Train the model
history1_cnn = model1_cnn.fit(X_train_1_reshaped, y_train_1.values, epochs=100, batch_size=128, validation_data=(X_test_1_reshaped, y_test_1.values))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 3198, 32)          128
#
#  max_pooling1d_4 (MaxPooling  (None, 1599, 32)         0
#  1D)
#
#  conv1d_5 (Conv1D)           (None, 1597, 64)          6208
#
#  max_pooling1d_5 (MaxPooling  (None, 798, 64)          0
#  1D)
#
#  flatten_2 (Flatten)         (None, 51072)             0
#
#  dense_8 (Dense)             (None, 512)               26149376
#
#  dense_9 (Dense)             (None, 256)               131328
#
#  dense_10 (Dense)            (None, 128)               32896
#
#  dense_11 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 26,320,581
# Trainable params: 26,320,581
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 2/2 [==============================] - 1s 425ms/step - loss: 2.2893 - accuracy: 0.1951 - val_loss: 3.1060 - val_accuracy: 0.3333
# Epoch 2/100
# 2/2 [==============================] - 1s 367ms/step - loss: 2.7131 - accuracy: 0.4573 - val_loss: 2.9193 - val_accuracy: 0.4048
# Epoch 3/100
# 2/2 [==============================] - 1s 406ms/step - loss: 2.4393 - accuracy: 0.4085 - val_loss: 2.2570 - val_accuracy: 0.3810
# Epoch 4/100
# 2/2 [==============================] - 1s 327ms/step - loss: 1.8143 - accuracy: 0.4451 - val_loss: 1.1486 - val_accuracy: 0.4524
# Epoch 5/100
# 2/2 [==============================] - 1s 338ms/step - loss: 0.8787 - accuracy: 0.5915 - val_loss: 1.1865 - val_accuracy: 0.4524
# Epoch 6/100
# 2/2 [==============================] - 1s 361ms/step - loss: 0.9450 - accuracy: 0.6280 - val_loss: 1.2377 - val_accuracy: 0.5476
# Epoch 7/100
# 2/2 [==============================] - 1s 335ms/step - loss: 0.9243 - accuracy: 0.6951 - val_loss: 1.0201 - val_accuracy: 0.5714
# Epoch 8/100
# 2/2 [==============================] - 1s 396ms/step - loss: 0.6842 - accuracy: 0.7256 - val_loss: 0.7921 - val_accuracy: 0.7143
# Epoch 9/100
# 2/2 [==============================] - 1s 420ms/step - loss: 0.4579 - accuracy: 0.9451 - val_loss: 0.8522 - val_accuracy: 0.5476
# Epoch 10/100
# 2/2 [==============================] - 1s 368ms/step - loss: 0.4185 - accuracy: 0.9329 - val_loss: 0.7387 - val_accuracy: 0.7143
# Epoch 11/100
# 2/2 [==============================] - 1s 402ms/step - loss: 0.2767 - accuracy: 0.9817 - val_loss: 0.6483 - val_accuracy: 0.6905
# Epoch 12/100
# 2/2 [==============================] - 1s 424ms/step - loss: 0.1840 - accuracy: 0.9817 - val_loss: 0.7267 - val_accuracy: 0.5952
# Epoch 13/100
# 2/2 [==============================] - 1s 413ms/step - loss: 0.1420 - accuracy: 0.9817 - val_loss: 0.6768 - val_accuracy: 0.6905
# Epoch 14/100
# 2/2 [==============================] - 1s 292ms/step - loss: 0.0739 - accuracy: 1.0000 - val_loss: 0.5553 - val_accuracy: 0.7143
# Epoch 15/100
# 2/2 [==============================] - 1s 310ms/step - loss: 0.0333 - accuracy: 1.0000 - val_loss: 0.5854 - val_accuracy: 0.7619
# Epoch 16/100
# 2/2 [==============================] - 1s 281ms/step - loss: 0.0218 - accuracy: 1.0000 - val_loss: 0.5907 - val_accuracy: 0.7619
# Epoch 17/100
# 2/2 [==============================] - 1s 289ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.5848 - val_accuracy: 0.7619
# Epoch 18/100
# 2/2 [==============================] - 1s 351ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.5983 - val_accuracy: 0.7619
# Epoch 19/100
# 2/2 [==============================] - 1s 333ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.6438 - val_accuracy: 0.7381
# Epoch 20/100
# 2/2 [==============================] - 1s 364ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.6868 - val_accuracy: 0.7143
# Epoch 21/100
# 2/2 [==============================] - 1s 358ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.7078 - val_accuracy: 0.7143
# Epoch 22/100
# 2/2 [==============================] - 1s 407ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.7228 - val_accuracy: 0.7143
# Epoch 23/100
# 2/2 [==============================] - 1s 356ms/step - loss: 6.9152e-04 - accuracy: 1.0000 - val_loss: 0.7307 - val_accuracy: 0.7143
# Epoch 24/100
# 2/2 [==============================] - 1s 341ms/step - loss: 3.8718e-04 - accuracy: 1.0000 - val_loss: 0.7210 - val_accuracy: 0.7143
# Epoch 25/100
# 2/2 [==============================] - 1s 407ms/step - loss: 2.3918e-04 - accuracy: 1.0000 - val_loss: 0.7164 - val_accuracy: 0.7381
# Epoch 26/100
# 2/2 [==============================] - 1s 310ms/step - loss: 1.8942e-04 - accuracy: 1.0000 - val_loss: 0.7181 - val_accuracy: 0.7381
# Epoch 27/100
# 2/2 [==============================] - 1s 431ms/step - loss: 1.7145e-04 - accuracy: 1.0000 - val_loss: 0.7271 - val_accuracy: 0.7619
# Epoch 28/100
# 2/2 [==============================] - 1s 415ms/step - loss: 1.5259e-04 - accuracy: 1.0000 - val_loss: 0.7361 - val_accuracy: 0.7619
# Epoch 29/100
# 2/2 [==============================] - 1s 451ms/step - loss: 1.2772e-04 - accuracy: 1.0000 - val_loss: 0.7447 - val_accuracy: 0.7619
# Epoch 30/100
# 2/2 [==============================] - 1s 330ms/step - loss: 1.0152e-04 - accuracy: 1.0000 - val_loss: 0.7539 - val_accuracy: 0.7619
# Epoch 31/100
# 2/2 [==============================] - 1s 369ms/step - loss: 8.2829e-05 - accuracy: 1.0000 - val_loss: 0.7649 - val_accuracy: 0.7619
# Epoch 32/100
# 2/2 [==============================] - 1s 402ms/step - loss: 6.8433e-05 - accuracy: 1.0000 - val_loss: 0.7761 - val_accuracy: 0.7857
# Epoch 33/100
# 2/2 [==============================] - 1s 430ms/step - loss: 5.7321e-05 - accuracy: 1.0000 - val_loss: 0.7864 - val_accuracy: 0.7857
# Epoch 34/100
# 2/2 [==============================] - 1s 342ms/step - loss: 5.0926e-05 - accuracy: 1.0000 - val_loss: 0.7956 - val_accuracy: 0.7619
# Epoch 35/100
# 2/2 [==============================] - 1s 368ms/step - loss: 9.4428e-06 - accuracy: 1.0000 - val_loss: 0.8541 - val_accuracy: 0.7619
# Epoch 92/100
# 2/2 [==============================] - 1s 398ms/step - loss: 9.2887e-06 - accuracy: 1.0000 - val_loss: 0.8544 - val_accuracy: 0.7619
# Epoch 93/100
# 2/2 [==============================] - 1s 435ms/step - loss: 9.1455e-06 - accuracy: 1.0000 - val_loss: 0.8545 - val_accuracy: 0.7619
# Epoch 94/100
# 2/2 [==============================] - 1s 322ms/step - loss: 9.0037e-06 - accuracy: 1.0000 - val_loss: 0.8547 - val_accuracy: 0.7619
# Epoch 95/100
# 2/2 [==============================] - 1s 289ms/step - loss: 8.8664e-06 - accuracy: 1.0000 - val_loss: 0.8555 - val_accuracy: 0.7619
# Epoch 96/100
# 2/2 [==============================] - 1s 314ms/step - loss: 8.7210e-06 - accuracy: 1.0000 - val_loss: 0.8564 - val_accuracy: 0.7619
# Epoch 97/100
# 2/2 [==============================] - 1s 316ms/step - loss: 8.6011e-06 - accuracy: 1.0000 - val_loss: 0.8573 - val_accuracy: 0.7619
# Epoch 98/100
# 2/2 [==============================] - 1s 382ms/step - loss: 8.4572e-06 - accuracy: 1.0000 - val_loss: 0.8580 - val_accuracy: 0.7619
# Epoch 99/100
# 2/2 [==============================] - 1s 284ms/step - loss: 8.3321e-06 - accuracy: 1.0000 - val_loss: 0.8583 - val_accuracy: 0.7619
# Epoch 100/100
# 2/2 [==============================] - 1s 331ms/step - loss: 8.2042e-06 - accuracy: 1.0000 - val_loss: 0.8586 - val_accuracy: 0.7619

# %%
# Extract losses for history1
train_loss_1_cnn = history1_cnn.history['loss']
val_loss_1_cnn = history1_cnn.history['val_loss']

# Plot the training and validation losses for history1
epochs_1_cnn = range(1, len(train_loss_1_cnn) + 1)
plt.plot(epochs_1_cnn, train_loss_1_cnn, 'ro', label='Model Training Loss')
plt.plot(epochs_1_cnn, val_loss_1_cnn, 'r', label='Model Validation Loss')
plt.title('Training and Validation Loss for Model')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
training_history1_cnn = pd.DataFrame(history1_cnn.history)
training_history1_cnn.to_csv("history_room1_cnn.csv", index=False)

# %%
# Get predictions on the test set
y_pred_1 = model1_cnn.predict(X_test_1_reshaped)
# Convert continuous predictions to discrete class labels
y_pred_labels_1 = np.argmax(y_pred_1, axis=1)

cm_model1_cnn = confusion_matrix(y_test_1, y_pred_labels_1, normalize='true')
class_names = ["Empty", "Down", "Left", "Right", "Up"]

# Plot confusion matrix as heatmap
sns.heatmap(cm_model1_cnn, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1, xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.savefig("confusion_matrix_lab1_1D-CNN_amplitudes.pdf", format="pdf")

plt.show()
# Out:
# 2/2 [==============================] - 0s 34ms/step

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy


scaler2 = StandardScaler()
X_train_scaled2 = scaler2.fit_transform(X_train_2.values.reshape(X_train_2.shape[0], -1))
X_test_scaled2 = scaler2.transform(X_test_2.values.reshape(X_test_2.shape[0], -1))

X_train_2_reshaped = np.reshape(X_train_scaled2, (X_train_2.shape[0], 3200, 1))
X_test_2_reshaped = np.reshape(X_test_scaled2, (X_test_2.shape[0], 3200, 1))


# Define the model
model2_cnn = Sequential()

# Add a 1D Convolutional layer
model2_cnn.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(3200, 1)))
model2_cnn.add(MaxPooling1D(pool_size=2))
model2_cnn.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model2_cnn.add(MaxPooling1D(pool_size=2))
model2_cnn.add(Flatten())  # Flatten the output for the dense layers

# Add dense layers
model2_cnn.add(Dense(512, activation='relu'))
model2_cnn.add(Dense(256, activation='relu'))
model2_cnn.add(Dense(128, activation='relu'))

# Output layer with 5 classes (assuming 5 different activities)
model2_cnn.add(Dense(5, activation='softmax'))

# Compile the model with run_eagerly=True
model2_cnn.compile(optimizer=Adam(), loss=SparseCategoricalCrossentropy(), metrics=['accuracy'], run_eagerly=True)

# Print model summary
model2_cnn.summary()

# Train the model
history2_cnn = model2_cnn.fit(X_train_2_reshaped, y_train_2.values, epochs=100, batch_size=128, validation_data=(X_test_2_reshaped, y_test_2.values))
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_6 (Conv1D)           (None, 3198, 32)          128
#
#  max_pooling1d_6 (MaxPooling  (None, 1599, 32)         0
#  1D)
#
#  conv1d_7 (Conv1D)           (None, 1597, 64)          6208
#
#  max_pooling1d_7 (MaxPooling  (None, 798, 64)          0
#  1D)
#
#  flatten_3 (Flatten)         (None, 51072)             0
#
#  dense_12 (Dense)            (None, 512)               26149376
#
#  dense_13 (Dense)            (None, 256)               131328
#
#  dense_14 (Dense)            (None, 128)               32896
#
#  dense_15 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 26,320,581
# Trainable params: 26,320,581
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 2/2 [==============================] - 1s 348ms/step - loss: 1.8126 - accuracy: 0.2547 - val_loss: 2.3631 - val_accuracy: 0.1707
# Epoch 2/100
# 2/2 [==============================] - 1s 324ms/step - loss: 2.4436 - accuracy: 0.2981 - val_loss: 1.3353 - val_accuracy: 0.4634
# Epoch 3/100
# 2/2 [==============================] - 1s 333ms/step - loss: 1.3053 - accuracy: 0.4845 - val_loss: 1.1452 - val_accuracy: 0.3415
# Epoch 4/100
# 2/2 [==============================] - 1s 311ms/step - loss: 0.9866 - accuracy: 0.5217 - val_loss: 0.8591 - val_accuracy: 0.6829
# Epoch 5/100
# 2/2 [==============================] - 1s 316ms/step - loss: 0.7564 - accuracy: 0.6584 - val_loss: 0.6199 - val_accuracy: 0.8537
# Epoch 6/100
# 2/2 [==============================] - 1s 318ms/step - loss: 0.4530 - accuracy: 0.9379 - val_loss: 0.5004 - val_accuracy: 0.8780
# Epoch 7/100
# 2/2 [==============================] - 1s 318ms/step - loss: 0.2850 - accuracy: 0.9441 - val_loss: 0.3972 - val_accuracy: 0.8293
# Epoch 8/100
# 2/2 [==============================] - 1s 301ms/step - loss: 0.1880 - accuracy: 0.9689 - val_loss: 0.2994 - val_accuracy: 0.9024
# Epoch 9/100
# 2/2 [==============================] - 1s 329ms/step - loss: 0.1121 - accuracy: 1.0000 - val_loss: 0.1940 - val_accuracy: 0.9268
# Epoch 10/100
# 2/2 [==============================] - 1s 358ms/step - loss: 0.0649 - accuracy: 0.9938 - val_loss: 0.1841 - val_accuracy: 0.9756
# Epoch 11/100
# 2/2 [==============================] - 1s 318ms/step - loss: 0.0473 - accuracy: 1.0000 - val_loss: 0.2076 - val_accuracy: 0.9024
# Epoch 12/100
# 2/2 [==============================] - 1s 295ms/step - loss: 0.0255 - accuracy: 1.0000 - val_loss: 0.2291 - val_accuracy: 0.9024
# Epoch 13/100
# 2/2 [==============================] - 1s 393ms/step - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.2087 - val_accuracy: 0.9268
# Epoch 14/100
# 2/2 [==============================] - 1s 413ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.2231 - val_accuracy: 0.8780
# Epoch 15/100
# 2/2 [==============================] - 1s 391ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.2391 - val_accuracy: 0.8780
# Epoch 16/100
# 2/2 [==============================] - 1s 364ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.1870 - val_accuracy: 0.9024
# Epoch 17/100
# 2/2 [==============================] - 1s 406ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1506 - val_accuracy: 0.9512
# Epoch 18/100
# 2/2 [==============================] - 1s 389ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1474 - val_accuracy: 0.
- accuracy: 1.0000 - val_loss: 0.1027 - val_accuracy: 0.9512
# Epoch 80/100
# 2/2 [==============================] - 1s 352ms/step - loss: 1.4385e-05 - accuracy: 1.0000 - val_loss: 0.1038 - val_accuracy: 0.9512
# Epoch 81/100
# 2/2 [==============================] - 1s 319ms/step - loss: 1.4087e-05 - accuracy: 1.0000 - val_loss: 0.1048 - val_accuracy: 0.9512
# Epoch 82/100
# 2/2 [==============================] - 1s 319ms/step - loss: 1.3803e-05 - accuracy: 1.0000 - val_loss: 0.1057 - val_accuracy: 0.9512
# Epoch 83/100
# 2/2 [==============================] - 1s 316ms/step - loss: 1.3515e-05 - accuracy: 1.0000 - val_loss: 0.1067 - val_accuracy: 0.9512
# Epoch 84/100
# 2/2 [==============================] - 1s 319ms/step - loss: 1.3265e-05 - accuracy: 1.0000 - val_loss: 0.1073 - val_accuracy: 0.9512
# Epoch 85/100
# 2/2 [==============================] - 1s 333ms/step - loss: 1.2997e-05 - accuracy: 1.0000 - val_loss: 0.1072 - val_accuracy: 0.9512
# Epoch 86/100
# 2/2 [==============================] - 1s 302ms/step - loss: 1.2745e-05 - accuracy: 1.0000 - val_loss: 0.1066 - val_accuracy: 0.9512
# Epoch 87/100
# 2/2 [==============================] - 1s 321ms/step - loss: 1.2476e-05 - accuracy: 1.0000 - val_loss: 0.1055 - val_accuracy: 0.9512
# Epoch 88/100
# 2/2 [==============================] - 1s 288ms/step - loss: 1.2204e-05 - accuracy: 1.0000 - val_loss: 0.1049 - val_accuracy: 0.9512
# Epoch 89/100
# 2/2 [==============================] - 1s 372ms/step - loss: 1.1963e-05 - accuracy: 1.0000 - val_loss: 0.1048 - val_accuracy: 0.9512
# Epoch 90/100
# 2/2 [==============================] - 1s 396ms/step - loss: 1.1713e-05 - accuracy: 1.0000 - val_loss: 0.1047 - val_accuracy: 0.9512
# Epoch 91/100
# 2/2 [==============================] - 1s 373ms/step - loss: 1.1452e-05 - accuracy: 1.0000 - val_loss: 0.1045 - val_accuracy: 0.9512
# Epoch 92/100
# 2/2 [==============================] - 1s 340ms/step - loss: 1.1238e-05 - accuracy: 1.0000 - val_loss: 0.1042 - val_accuracy: 0.9512
# Epoch 93/100
# 2/2 [==============================] - 1s 374ms/step - loss: 1.0995e-05 - accuracy: 1.0000 - val_loss: 0.1039 - val_accuracy: 0.9512
# Epoch 94/100
# 2/2 [==============================] - 1s 400ms/step - loss: 1.0786e-05 - accuracy: 1.0000 - val_loss: 0.1038 - val_accuracy: 0.9512
# Epoch 95/100
# 2/2 [==============================] - 1s 316ms/step - loss: 1.0603e-05 - accuracy: 1.0000 - val_loss: 0.1033 - val_accuracy: 0.9512
# Epoch 96/100
# 2/2 [==============================] - 1s 405ms/step - loss: 1.0378e-05 - accuracy: 1.0000 - val_loss: 0.1018 - val_accuracy: 0.9512
# Epoch 97/100
# 2/2 [==============================] - 1s 439ms/step - loss: 1.0193e-05 - accuracy: 1.0000 - val_loss: 0.1007 - val_accuracy: 0.9512
# Epoch 98/100
# 2/2 [==============================] - 1s 406ms/step - loss: 1.0003e-05 - accuracy: 1.0000 - val_loss: 0.0999 - val_accuracy: 0.9512
# Epoch 99/100
# 2/2 [==============================] - 1s 323ms/step - loss: 9.8253e-06 - accuracy: 1.0000 - val_loss: 0.0995 - val_accuracy: 0.9512
# Epoch 100/100
# 2/2 [==============================] - 1s 313ms/step - loss: 9.6387e-06 - accuracy: 1.0000 - val_loss: 0.0995 - val_accuracy: 0.9512

# %%
# Extract losses for history1
train_loss_2_cnn = history2_cnn.history['loss']
val_loss_2_cnn = history2_cnn.history['val_loss']

# Plot the training and validation losses for history1
epochs_2_cnn = range(1, len(train_loss_2_cnn) + 1)
plt.plot(epochs_2_cnn, train_loss_2_cnn, 'ro', label='Model Training Loss')
plt.plot(epochs_2_cnn, val_loss_2_cnn, 'r', label='Model Validation Loss')
plt.title('Training and Validation Loss for Model')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
training_history2_cnn = pd.DataFrame(history2_cnn.history)
training_history2_cnn.to_csv("history_room2_cnn.csv", index=False)

# %%
# Get predictions on the test set
y_pred_2 = model2_cnn.predict(X_test_2_reshaped)
# Convert continuous predictions to discrete class labels
y_pred_labels_2 = np.argmax(y_pred_2, axis=1)

cm_model2_cnn = confusion_matrix(y_test_2, y_pred_labels_2, normalize='true')
class_names = ["Empty", "Down", "Left", "Right", "Up"]

# Plot confusion matrix as heatmap
sns.heatmap(cm_model2_cnn, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1, xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.savefig("confusion_matrix_lab2_1D-CNN_amplitudes.pdf", format="pdf")

plt.show()
# Out:
# 2/2 [==============================] - 0s 20ms/step

# %% [markdown]
# # classification using ML models

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# %%
RF_Accuracy=[]
SVM_Accuracy=[]
KNN_Accuracy=[]

# %% [markdown]
# # 1. Random Forest Classifier

# %% [markdown]
# # 1.1 Room Lab1

# %%
from sklearn.ensemble import RandomForestClassifier

classifier_rfc_1=RandomForestClassifier(max_depth=12)
classifier_rfc_1.fit(X_train_1,y_train_1)
y_pred_rfc_1=classifier_rfc_1.predict(X_train_1)
print("the accuracy of training data: ", accuracy_score(y_train_1,y_pred_rfc_1))
y_pred_rfc_test_1=classifier_rfc_1.predict(X_test_1)
print("the accuracy of testing data:  ", accuracy_score(y_test_1,y_pred_rfc_test_1))
RF_Accuracy.append(accuracy_score(y_test_1,y_pred_rfc_test_1))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.7380952380952381

# %%
cm_rfc_1 = confusion_matrix(y_test_1, y_pred_rfc_test_1, normalize='true')
class_names = ["Empty","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_rfc_1, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for Random Forest Classifier of Room Lab1")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_rfc_1 = classification_report(y_test_1, y_pred_rfc_test_1)
print("Classification report for Random Forest of Room Lab1:")
print(report_rfc_1)
# Out:
# Classification report for Random Forest of Room Lab1:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       0.50      0.80      0.62        10
#            2       1.00      0.80      0.89        10
#            3       1.00      0.89      0.94         9
#            4       0.50      0.33      0.40         9
#
#     accuracy                           0.74        42
#    macro avg       0.80      0.76      0.77        42
# weighted avg       0.77      0.74      0.74        42

# %% [markdown]
# # 1.2 Room Lab2

# %%
from sklearn.ensemble import RandomForestClassifier

classifier_rfc_2=RandomForestClassifier(max_depth=12)
classifier_rfc_2.fit(X_train_2,y_train_2)
y_pred_rfc_2=classifier_rfc_2.predict(X_train_2)
print("the accuracy of training data: ", accuracy_score(y_train_2,y_pred_rfc_2))
y_pred_rfc_test_2=classifier_rfc_2.predict(X_test_2)
print("the accuracy of testing data:  ", accuracy_score(y_test_2,y_pred_rfc_test_2))
RF_Accuracy.append(accuracy_score(y_test_2,y_pred_rfc_test_2))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.8536585365853658

# %%
cm_rfc_2 = confusion_matrix(y_test_2, y_pred_rfc_test_2, normalize='true')
class_names = ["Empty","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_rfc_2, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for Random Forest Classifier of Room Lab2")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_rfc_2 = classification_report(y_test_2, y_pred_rfc_test_2)
print("Classification report for Random Forest of of Room Lab2:")
print(report_rfc_2)
# Out:
# Classification report for Random Forest of of Room Lab2:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       1.00      0.79      0.88        14
#            2       0.75      0.86      0.80         7
#            3       0.88      1.00      0.93         7
#            4       0.67      0.75      0.71         8
#
#     accuracy                           0.85        41
#    macro avg       0.86      0.88      0.86        41
# weighted avg       0.87      0.85      0.86        41

# %% [markdown]
# # 1.3 Room Lab1 & Lab2

# %%
from sklearn.ensemble import RandomForestClassifier

classifier_rfc=RandomForestClassifier(max_depth=12)
classifier_rfc.fit(X_train,y_train)
y_pred_rfc=classifier_rfc.predict(X_train)
print("the accuracy of training data: ", accuracy_score(y_train,y_pred_rfc))
y_pred_rfc_test=classifier_rfc.predict(X_test)
print("the accuracy of testing data:  ", accuracy_score(y_test,y_pred_rfc_test))
RF_Accuracy.append(accuracy_score(y_test,y_pred_rfc_test))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.7439024390243902

# %%
cm_rfc = confusion_matrix(y_test, y_pred_rfc_test, normalize='true')
class_names = ["Empty","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_rfc, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for Random Forest Classifier of Room Lab1 and Room Lab2")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_rfc = classification_report(y_test, y_pred_rfc_test)
print("Classification report for Random Forest of Room Lab1 and Room Lab2:")
print(report_rfc)
# Out:
# Classification report for Random Forest of Room Lab1 and Room Lab2:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.65      0.68      0.67        22
#            2       0.80      0.71      0.75        17
#            3       0.79      0.85      0.81        13
#            4       0.65      0.65      0.65        20
#
#     accuracy                           0.74        82
#    macro avg       0.78      0.78      0.78        82
# weighted avg       0.75      0.74      0.74        82

# %%
X_train.shape,X_train_1.shape,X_train_2.shape
# Out:
# ((326, 3200), (164, 3200), (161, 3200))

# %% [markdown]
# # 1.2 Support Vector Machine

# %% [markdown]
# # 1.2.1 Room Lab1

# %%
from sklearn import svm
classifier_svm_1 = svm.SVC(kernel='linear')
classifier_svm_1.fit(X_train_1,y_train_1)
y_pred_svm_1=classifier_svm_1.predict(X_train_1)
print("the accuracy of training data: ", accuracy_score(y_train_1,y_pred_svm_1))
y_pred_svm_test_1=classifier_svm_1.predict(X_test_1)
print("the accuracy of testing data:  ", accuracy_score(y_test_1,y_pred_svm_test_1))
SVM_Accuracy.append(accuracy_score(y_test_1,y_pred_svm_test_1))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.9285714285714286

# %%
cm_svm_1 = confusion_matrix(y_test_1, y_pred_svm_test_1, normalize='true')
class_names = ["Empty","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_svm_1, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for Support Vector Machines of Room Lab1")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_svm_1 = classification_report(y_test_1, y_pred_svm_test_1)
print("Classification report for Support Vector Machines of Room Lab1:")
print(report_svm_1)
# Out:
# Classification report for Support Vector Machines of Room Lab1:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       0.83      1.00      0.91        10
#            2       1.00      1.00      1.00        10
#            3       1.00      0.89      0.94         9
#            4       0.88      0.78      0.82         9
#
#     accuracy                           0.93        42
#    macro avg       0.94      0.93      0.93        42
# weighted avg       0.93      0.93      0.93        42

# %% [markdown]
# # 1.2.2 Room Lab2

# %%
from sklearn import svm
classifier_svm_2 = svm.SVC(kernel='linear')
classifier_svm_2.fit(X_train_2,y_train_2)
y_pred_svm_2=classifier_svm_2.predict(X_train_2)
print("the accuracy of training data: ", accuracy_score(y_train_2,y_pred_svm_2))
y_pred_svm_test_2=classifier_svm_2.predict(X_test_2)
print("the accuracy of testing data:  ", accuracy_score(y_test_2,y_pred_svm_test_2))
SVM_Accuracy.append(accuracy_score(y_test_2,y_pred_svm_test_2))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.9512195121951219

# %%
cm_svm_2 = confusion_matrix(y_test_2, y_pred_svm_test_2, normalize='true')
class_names = ["Empty","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_svm_2, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for Support Vector Machines of Room Lab2")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_svm_2 = classification_report(y_test_2, y_pred_svm_test_2)
print("Classification report for Support Vector Machines of Room Lab2:")
print(report_svm_2)
# Out:
# Classification report for Support Vector Machines of Room Lab2:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       1.00      0.93      0.96        14
#            2       1.00      0.86      0.92         7
#            3       1.00      1.00      1.00         7
#            4       0.80      1.00      0.89         8
#
#     accuracy                           0.95        41
#    macro avg       0.96      0.96      0.95        41
# weighted avg       0.96      0.95      0.95        41

# %% [markdown]
# # 1.2.1 Room Lab1 & Lab2

# %%
from sklearn import svm
classifier_svm = svm.SVC(kernel='linear')
classifier_svm.fit(X_train,y_train)
y_pred_svm=classifier_svm.predict(X_train)
print("the accuracy of training data: ", accuracy_score(y_train,y_pred_svm))
y_pred_svm_test=classifier_svm.predict(X_test)
print("the accuracy of testing data:  ", accuracy_score(y_test,y_pred_svm_test))
SVM_Accuracy.append(accuracy_score(y_test,y_pred_svm_test))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.8780487804878049

# %%
cm_svm = confusion_matrix(y_test, y_pred_svm_test, normalize='true')
class_names = ["Empty","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_svm, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for Support Vector Machines of Room Lab1 and Lab2")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_svm = classification_report(y_test, y_pred_svm_test)
print("Classification report for Support Vector Machines of Room Lab1 and Lab2:")
print(report_svm)
# Out:
# Classification report for Support Vector Machines of Room Lab1 and Lab2:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.83      0.86      0.84        22
#            2       0.93      0.82      0.87        17
#            3       0.92      0.85      0.88        13
#            4       0.82      0.90      0.86        20
#
#     accuracy                           0.88        82
#    macro avg       0.90      0.89      0.89        82
# weighted avg       0.88      0.88      0.88        82

# %% [markdown]
# # 1.3 K-Nearest Neighbors

# %% [markdown]
# # 1.3.1 Room Lab1

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier_knn_1 = KNeighborsClassifier(n_neighbors=3,weights='distance',p=1)
classifier_knn_1.fit(X_train_1,y_train_1)
y_pred_knn_1=classifier_knn_1.predict(X_train_1)
print("the accuracy of training data: ", accuracy_score(y_train_1,y_pred_knn_1))
y_pred_knn_test_1=classifier_knn_1.predict(X_test_1)
print("the accuracy of testing data:  ", accuracy_score(y_test_1,y_pred_knn_test_1))
KNN_Accuracy.append(accuracy_score(y_test_1,y_pred_knn_test_1))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.7619047619047619

# %%
cm_knn_1 = confusion_matrix(y_test_1, y_pred_knn_test_1, normalize='true')
class_names = ["Empty","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_knn_1, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for K-Nearest Neighbors of Room Lab1")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_knn_1 = classification_report(y_test_1, y_pred_knn_test_1)
print("Classification report for K-Nearest Neighbors of Room Lab1:")
print(report_knn_1)
# Out:
# Classification report for K-Nearest Neighbors of Room Lab1:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       0.64      0.90      0.75        10
#            2       1.00      0.70      0.82        10
#            3       1.00      0.78      0.88         9
#            4       0.50      0.56      0.53         9
#
#     accuracy                           0.76        42
#    macro avg       0.83      0.79      0.79        42
# weighted avg       0.81      0.76      0.77        42

# %% [markdown]
# # 1.3.2 Room Lab2

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier_knn_2 = KNeighborsClassifier(n_neighbors=3,weights='distance',p=1)
classifier_knn_2.fit(X_train_2,y_train_2)
y_pred_knn_2=classifier_knn_2.predict(X_train_2)
print("the accuracy of training data: ", accuracy_score(y_train_2,y_pred_knn_2))
y_pred_knn_test_2=classifier_knn_2.predict(X_test_2)
print("the accuracy of testing data:  ", accuracy_score(y_test_2,y_pred_knn_test_2))
KNN_Accuracy.append(accuracy_score(y_test_2,y_pred_knn_test_2))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.9024390243902439

# %%
cm_knn_2 = confusion_matrix(y_test_2, y_pred_knn_test_2, normalize='true')
class_names = ["Empty","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_knn_2, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for K-Nearest Neighbors of Room Lab2")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_knn_2 = classification_report(y_test_2, y_pred_knn_test_2)
print("Classification report for K-Nearest Neighbors of Room Lab2:")
print(report_knn_2)
# Out:
# Classification report for K-Nearest Neighbors of Room Lab2:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       0.93      0.93      0.93        14
#            2       1.00      0.57      0.73         7
#            3       1.00      1.00      1.00         7
#            4       0.73      1.00      0.84         8
#
#     accuracy                           0.90        41
#    macro avg       0.93      0.90      0.90        41
# weighted avg       0.92      0.90      0.90        41

# %% [markdown]
# # 1.3.3 Room Lab1 & Lab2

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier_knn = KNeighborsClassifier(n_neighbors=3,weights='distance',p=1)
classifier_knn.fit(X_train,y_train)
y_pred_knn=classifier_knn.predict(X_train)
print("the accuracy of training data: ", accuracy_score(y_train,y_pred_knn))
y_pred_knn_test=classifier_knn.predict(X_test)
print("the accuracy of testing data:  ", accuracy_score(y_test,y_pred_knn_test))
KNN_Accuracy.append(accuracy_score(y_test,y_pred_knn_test))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.8048780487804879

# %%
cm_knn = confusion_matrix(y_test, y_pred_knn_test, normalize='true')
class_names = ["Empty","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_knn, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
#plt.title("Confusion Matrix for K-Nearest Neighbors of Room Lab1 and Lab2")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_knn = classification_report(y_test, y_pred_knn_test)
print("Classification report for K-Nearest Neighbors of Room Lab1 and Lab2:")
print(report_knn)
# Out:
# Classification report for K-Nearest Neighbors of Room Lab1 and Lab2:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.70      0.86      0.78        22
#            2       1.00      0.47      0.64        17
#            3       0.92      0.92      0.92        13
#            4       0.71      0.85      0.77        20
#
#     accuracy                           0.80        82
#    macro avg       0.87      0.82      0.82        82
# weighted avg       0.84      0.80      0.80        82

# %%
indices=['classroom', 'meeting room', 'classroom + meeting room']
Rf_accuracy=pd.DataFrame(data=RF_Accuracy[0:],
                index=indices,
                columns=['RF'])

SVM_accuracy=pd.DataFrame(data=SVM_Accuracy[0:],
                index=indices,
                columns=['SVM'])

KNN_accuracy=pd.DataFrame(data=KNN_Accuracy[0:],
                index=indices,
                columns=['KNN'])

# %%
df_accuracy = pd.concat([Rf_accuracy,SVM_accuracy,KNN_accuracy], axis=1)
df_accuracy
# Out:
#                                 RF       SVM       KNN
# classroom                 0.738095  0.928571  0.761905
# meeting room              0.853659  0.951220  0.902439
# classroom + meeting room  0.743902  0.878049  0.804878

# %%
df_accuracy.to_csv(r'human_walking_direction_df_accuracy_421_and_422_amplitudes_phases_80%.csv')

# %%
plt.plot(df_accuracy['RF'], label='Random Forest')
plt.plot(df_accuracy['SVM'], label='SVM')
plt.plot(df_accuracy['KNN'], label='KNN')

plt.title("Accuracy with different number of classifiers and Room Labs")
plt.xlabel("Number of volunteers")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
