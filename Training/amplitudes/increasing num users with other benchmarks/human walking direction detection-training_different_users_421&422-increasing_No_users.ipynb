# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#using 2 antennas
dataset1 = pd.read_csv('human_walking_direction_amir_421.csv').drop('Unnamed: 0',axis=1)
dataset2 = pd.read_csv('human_walking_direction_irina_421.csv').drop('Unnamed: 0',axis=1)
dataset3 = pd.read_csv('human_walking_direction_mohamed_421.csv').drop('Unnamed: 0',axis=1)
dataset4 = pd.read_csv('human_walking_direction_alaa_421.csv').drop('Unnamed: 0',axis=1)
dataset5 = pd.read_csv('human_walking_direction_abdelrahman_421.csv').drop('Unnamed: 0',axis=1)
dataset6 = pd.read_csv('human_walking_direction_elbatanony_421.csv').drop('Unnamed: 0',axis=1)
dataset7 = pd.read_csv('human_walking_direction_fahima_421.csv').drop('Unnamed: 0',axis=1)
dataset8 = pd.read_csv('human_walking_direction_belal_421.csv').drop('Unnamed: 0',axis=1)
dataset9 = pd.read_csv('human_walking_direction_odilbek_421.csv').drop('Unnamed: 0',axis=1)

# %%
#using 2 antennas
dataset12 = pd.read_csv('human_walking_direction_amir_422.csv').drop('Unnamed: 0',axis=1)
dataset22 = pd.read_csv('human_walking_direction_irina_422.csv').drop('Unnamed: 0',axis=1)
dataset32 = pd.read_csv('human_walking_direction_mohamed_422.csv').drop('Unnamed: 0',axis=1)
dataset42 = pd.read_csv('human_walking_direction_alaa_422.csv').drop('Unnamed: 0',axis=1)
dataset52 = pd.read_csv('human_walking_direction_abdelrahman_422.csv').drop('Unnamed: 0',axis=1)
dataset62 = pd.read_csv('human_walking_direction_elbatanony_422.csv').drop('Unnamed: 0',axis=1)
dataset72 = pd.read_csv('human_walking_direction_fahima_422.csv').drop('Unnamed: 0',axis=1)
dataset82 = pd.read_csv('human_walking_direction_belal_422.csv').drop('Unnamed: 0',axis=1)
dataset92 = pd.read_csv('human_walking_direction_odilbek_422.csv').drop('Unnamed: 0',axis=1)

# %%
dataset1.shape,dataset2.shape,dataset3.shape,dataset4.shape,dataset5.shape,dataset6.shape,dataset7.shape,dataset8.shape,dataset9.shape
# Out:
# ((42, 1601),
#  (40, 1601),
#  (40, 1601),
#  (40, 1601),
#  (40, 1601),
#  (42, 1601),
#  (41, 1601),
#  (41, 1601),
#  (40, 1601))

# %%
datasets1=[]
datasets1.append(dataset1)
datasets1.append(dataset2)
datasets1.append(dataset3)
datasets1.append(dataset4)
datasets1.append(dataset5)
datasets1.append(dataset6)
datasets1.append(dataset7)
datasets1.append(dataset8)
datasets1.append(dataset9)

# %%
datasets2=[]
datasets2.append(dataset12)
datasets2.append(dataset22)
datasets2.append(dataset32)
datasets2.append(dataset42)
datasets2.append(dataset52)
datasets2.append(dataset62)
datasets2.append(dataset72)
datasets2.append(dataset82)
datasets2.append(dataset92)

# %%
label = 'No_person'
for i in range(len(datasets1)):
    selected_rows_no_person1 = datasets1[i].loc[datasets1[i]['label'] == label]
    if i==0:
        selected_rows_no_person1.to_csv(f"No_person_data_421_phases.csv", index=False)
    datasets1[i] = datasets1[i].drop(selected_rows_no_person1.index)
    print(datasets1[i].shape)
# Out:
# (22, 1601)
# (20, 1601)
# (20, 1601)
# (20, 1601)
# (20, 1601)
# (22, 1601)
# (21, 1601)
# (21, 1601)
# (20, 1601)

# %%
label = 'No_person'
for i in range(len(datasets2)):
    selected_rows_no_person2 = datasets2[i].loc[datasets2[i]['label'] == label]
    if i==0:
        selected_rows_no_person2.to_csv(f"No_person_data_422_phases.csv", index=False)
    datasets2[i] = datasets2[i].drop(selected_rows_no_person2.index)
    print(datasets2[i].shape)
# Out:
# (20, 1601)
# (20, 1601)
# (20, 1601)
# (20, 1601)
# (20, 1601)
# (22, 1601)
# (20, 1601)
# (20, 1601)
# (20, 1601)

# %%
no_activity1 = pd.read_csv('No_person_data_421_phases.csv')
no_activity1
# Out:
#     amplitude antenna1_1:0  amplitude antenna1_1:1  amplitude antenna1_1:2  \
# 0               169.807449              167.697563              163.167068
# 1               156.608358              167.925743              144.281351
# 2               153.845851              153.956437              159.831766
# 3               159.048246              155.892607              155.093766
# 4               148.583782              181.044455              154.058066
# 5               164.549052              144.257100              154.765438
# 6               131.714200              135.445130              139.074644
# 7               125.306956              124.276932              121.198427
# 8               121.369769              121.943878              127.655757
# 9               120.095463              120.817488              120.507466
# 10              127.995375              120.635038              125.563837
# ...

# %%
no_activity2 = pd.read_csv('No_person_data_422_phases.csv')
no_activity2
# Out:
#     amplitude antenna1_1:0  amplitude antenna1_1:1  amplitude antenna1_1:2  \
# 0               148.921406              138.478919              111.739155
# 1               172.996870              132.296808              150.925146
# 2               150.409571              142.258939              129.527977
# 3               129.979415              119.037710              123.187965
# 4               127.328865              130.597847              134.496398
# 5               165.154399              109.367316              112.557406
# 6               130.355379              127.092773              133.156998
# 7               102.739940              147.179872              109.527481
# 8               121.466537              130.392235              138.911890
# 9               121.989243              138.818271              118.234633
# 10              110.650617              108.884435              112.335599
# ...

# %%
df_1 = pd.concat([datasets1[0],no_activity1], axis=0)
df_2 = pd.concat([datasets1[0],datasets1[1],no_activity1], axis=0)
df_3 = pd.concat([datasets1[0],datasets1[1],datasets1[2],no_activity1], axis=0)
df_4 = pd.concat([datasets1[0],datasets1[1],datasets1[2],datasets1[3],no_activity1], axis=0)
df_5 = pd.concat([datasets1[0],datasets1[1],datasets1[2],datasets1[3],datasets1[4],no_activity1], axis=0)
df_6 = pd.concat([datasets1[0],datasets1[1],datasets1[2],datasets1[3],datasets1[4],datasets1[5],no_activity1], axis=0)
df_7 = pd.concat([datasets1[0],datasets1[1],datasets1[2],datasets1[3],datasets1[4],datasets1[5],datasets1[6],no_activity1], axis=0)
df_8 = pd.concat([datasets1[0],datasets1[1],datasets1[2],datasets1[3],datasets1[4],datasets1[5],datasets1[6],datasets1[7],no_activity1], axis=0)
df_9_all = pd.concat([datasets1[0],datasets1[1],datasets1[2],datasets1[3],datasets1[4],datasets1[5],datasets1[6],datasets1[7],datasets1[8],no_activity1], axis=0)

# %%
df_12 = pd.concat([datasets2[0],no_activity2], axis=0)
df_22 = pd.concat([datasets2[0],datasets2[1],no_activity2], axis=0)
df_32 = pd.concat([datasets2[0],datasets2[1],datasets2[2],no_activity2], axis=0)
df_42 = pd.concat([datasets2[0],datasets2[1],datasets2[2],datasets2[3],no_activity2], axis=0)
df_52 = pd.concat([datasets2[0],datasets2[1],datasets2[2],datasets2[3],datasets2[4],no_activity2], axis=0)
df_62 = pd.concat([datasets2[0],datasets2[1],datasets2[2],datasets2[3],datasets2[4],datasets2[5],no_activity2], axis=0)
df_72 = pd.concat([datasets2[0],datasets2[1],datasets2[2],datasets2[3],datasets2[4],datasets2[5],datasets2[6],no_activity2], axis=0)
df_82 = pd.concat([datasets2[0],datasets2[1],datasets2[2],datasets2[3],datasets2[4],datasets2[5],datasets2[6],datasets2[7],no_activity2], axis=0)
df_9_all2 = pd.concat([datasets2[0],datasets2[1],datasets2[2],datasets2[3],datasets2[4],datasets2[5],datasets2[6],datasets2[7],datasets2[8],no_activity2], axis=0)

# %%
df_1.shape,df_2.shape, df_3.shape,df_4.shape,df_5.shape,df_6.shape,df_7.shape,df_8.shape,df_9_all.shape
# Out:
# ((42, 1601),
#  (62, 1601),
#  (82, 1601),
#  (102, 1601),
#  (122, 1601),
#  (144, 1601),
#  (165, 1601),
#  (186, 1601),
#  (206, 1601))

# %%
df_2_1 = pd.concat([df_1,df_12], axis=0)
df_2_2 = pd.concat([df_2,df_22], axis=0)
df_2_3 = pd.concat([df_3,df_32], axis=0)
df_2_4 = pd.concat([df_4,df_42], axis=0)
df_2_5 = pd.concat([df_5,df_52], axis=0)
df_2_6 = pd.concat([df_6,df_62], axis=0)
df_2_7 = pd.concat([df_7,df_72], axis=0)
df_2_8 = pd.concat([df_8,df_82], axis=0)
df_2_9_all = pd.concat([df_9_all,df_9_all2], axis=0)

# %%
import seaborn as sns

sns.set(color_codes=True)

plt.figure(0, (10, 10))
sns_plot = sns.countplot(df_9_all['label'], color="dodgerblue", label="Compact")
# Out:
# C:\Users\hanan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Train the dataset

# %%
#Data encoding: to convert categorical features to numberical
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# %%
df_1['label']=label_encoder.fit_transform(df_1['label'])
df_12['label']=label_encoder.fit_transform(df_12['label'])
df_2_1['label']=label_encoder.fit_transform(df_2_1['label'])

# %%
df_2['label']=label_encoder.fit_transform(df_2['label'])
df_22['label']=label_encoder.fit_transform(df_22['label'])
df_2_2['label']=label_encoder.fit_transform(df_2_2['label'])

# %%
df_3['label']=label_encoder.fit_transform(df_3['label'])
df_32['label']=label_encoder.fit_transform(df_32['label'])
df_2_3['label']=label_encoder.fit_transform(df_2_3['label'])

# %%
df_4['label']=label_encoder.fit_transform(df_4['label'])
df_42['label']=label_encoder.fit_transform(df_42['label'])
df_2_4['label']=label_encoder.fit_transform(df_2_4['label'])

# %%
df_5['label']=label_encoder.fit_transform(df_5['label'])
df_52['label']=label_encoder.fit_transform(df_52['label'])
df_2_5['label']=label_encoder.fit_transform(df_2_5['label'])

# %%
df_6['label']=label_encoder.fit_transform(df_6['label'])
df_62['label']=label_encoder.fit_transform(df_62['label'])
df_2_6['label']=label_encoder.fit_transform(df_2_6['label'])

# %%
df_7['label']=label_encoder.fit_transform(df_7['label'])
df_72['label']=label_encoder.fit_transform(df_72['label'])
df_2_7['label']=label_encoder.fit_transform(df_2_7['label'])

# %%
df_8['label']=label_encoder.fit_transform(df_8['label'])
df_82['label']=label_encoder.fit_transform(df_82['label'])
df_2_8['label']=label_encoder.fit_transform(df_2_8['label'])

# %%
df_9_all['label']=label_encoder.fit_transform(df_9_all['label'])
df_9_all2['label']=label_encoder.fit_transform(df_9_all2['label'])
df_2_9_all['label']=label_encoder.fit_transform(df_2_9_all['label'])

# %%
df_2['label'].unique()
# Out:
# array([2, 3, 4, 1, 0])

# %%
y_1=df_1['label']
X_1=df_1.drop('label',axis=1)

y_2=df_2['label']
X_2=df_2.drop('label',axis=1)

y_3=df_3['label']
X_3=df_3.drop('label',axis=1)

y_4=df_4['label']
X_4=df_4.drop('label',axis=1)

y_5=df_5['label']
X_5=df_5.drop('label',axis=1)

y_6=df_6['label']
X_6=df_6.drop('label',axis=1)

y_7=df_7['label']
X_7=df_7.drop('label',axis=1)

y_8=df_8['label']
X_8=df_8.drop('label',axis=1)

y_9_all=df_9_all['label']
X_9_all=df_9_all.drop('label',axis=1)

# %%
y_12=df_12['label']
X_12=df_12.drop('label',axis=1)

y_22=df_22['label']
X_22=df_22.drop('label',axis=1)

y_32=df_32['label']
X_32=df_32.drop('label',axis=1)

y_42=df_42['label']
X_42=df_42.drop('label',axis=1)

y_52=df_52['label']
X_52=df_52.drop('label',axis=1)

y_62=df_62['label']
X_62=df_62.drop('label',axis=1)

y_72=df_72['label']
X_72=df_72.drop('label',axis=1)

y_82=df_82['label']
X_82=df_82.drop('label',axis=1)

y_9_all2=df_9_all2['label']
X_9_all2=df_9_all2.drop('label',axis=1)

# %%
y_2_1=df_2_1['label']
X_2_1=df_2_1.drop('label',axis=1)

y_2_2=df_2_2['label']
X_2_2=df_2_2.drop('label',axis=1)

y_2_3=df_2_3['label']
X_2_3=df_2_3.drop('label',axis=1)

y_2_4=df_2_4['label']
X_2_4=df_2_4.drop('label',axis=1)

y_2_5=df_2_5['label']
X_2_5=df_2_5.drop('label',axis=1)

y_2_6=df_2_6['label']
X_2_6=df_2_6.drop('label',axis=1)

y_2_7=df_2_7['label']
X_2_7=df_2_7.drop('label',axis=1)

y_2_8=df_2_8['label']
X_2_8=df_2_8.drop('label',axis=1)

y_2_9_all=df_9_all['label']
X_2_9_all=df_9_all.drop('label',axis=1)

# %%
y_2
# Out:
# 0     2
# 1     2
# 2     2
# 3     2
# 4     2
#      ..
# 15    0
# 16    0
# 17    0
# 18    0
# 19    0
# Name: label, Length: 62, dtype: int32

# %%
#Trainset Splitting
from sklearn.model_selection import train_test_split

# %%
X_train_1, X_test_1, y_train_1, y_test_1= train_test_split(X_1, y_1, test_size=0.2,random_state=123)
X_train_2, X_test_2, y_train_2, y_test_2= train_test_split(X_2, y_2, test_size=0.2,random_state=123)
X_train_3, X_test_3, y_train_3, y_test_3= train_test_split(X_3, y_3, test_size=0.2,random_state=123)
X_train_4, X_test_4, y_train_4, y_test_4= train_test_split(X_4, y_4, test_size=0.2,random_state=123)
X_train_5, X_test_5, y_train_5, y_test_5= train_test_split(X_5, y_5, test_size=0.2,random_state=123)
X_train_6, X_test_6, y_train_6, y_test_6= train_test_split(X_6, y_6, test_size=0.2,random_state=123)
X_train_7, X_test_7, y_train_7, y_test_7= train_test_split(X_7, y_7, test_size=0.2,random_state=123)
X_train_8, X_test_8, y_train_8, y_test_8= train_test_split(X_8, y_8, test_size=0.2,random_state=123)
X_train_9_all, X_test_9_all, y_train_9_all, y_test_9_all= train_test_split(X_9_all, y_9_all, test_size=0.2,random_state=123)

# %%
X_train_12, X_test_12, y_train_12, y_test_12= train_test_split(X_12, y_12, test_size=0.2,random_state=123)
X_train_22, X_test_22, y_train_22, y_test_22= train_test_split(X_22, y_22, test_size=0.2,random_state=123)
X_train_32, X_test_32, y_train_32, y_test_32= train_test_split(X_32, y_32, test_size=0.2,random_state=123)
X_train_42, X_test_42, y_train_42, y_test_42= train_test_split(X_42, y_42, test_size=0.2,random_state=123)
X_train_52, X_test_52, y_train_52, y_test_52= train_test_split(X_52, y_52, test_size=0.2,random_state=123)
X_train_62, X_test_62, y_train_62, y_test_62= train_test_split(X_62, y_62, test_size=0.2,random_state=123)
X_train_72, X_test_72, y_train_72, y_test_72= train_test_split(X_72, y_72, test_size=0.2,random_state=123)
X_train_82, X_test_82, y_train_82, y_test_82= train_test_split(X_82, y_82, test_size=0.2,random_state=123)
X_train_92_all, X_test_92_all, y_train_92_all, y_test_92_all= train_test_split(X_9_all2, y_9_all2, test_size=0.2,random_state=123)

# %%
X_train_2_1, X_test_2_1, y_train_2_1, y_test_2_1= train_test_split(X_2_1, y_2_1, test_size=0.2,random_state=123)
X_train_2_2, X_test_2_2, y_train_2_2, y_test_2_2= train_test_split(X_2_2, y_2_2, test_size=0.2,random_state=123)
X_train_2_3, X_test_2_3, y_train_2_3, y_test_2_3= train_test_split(X_2_3, y_2_3, test_size=0.2,random_state=123)
X_train_2_4, X_test_2_4, y_train_2_4, y_test_2_4= train_test_split(X_2_4, y_2_4, test_size=0.2,random_state=123)
X_train_2_5, X_test_2_5, y_train_2_5, y_test_2_5= train_test_split(X_2_5, y_2_5, test_size=0.2,random_state=123)
X_train_2_6, X_test_2_6, y_train_2_6, y_test_2_6= train_test_split(X_2_6, y_2_6, test_size=0.2,random_state=123)
X_train_2_7, X_test_2_7, y_train_2_7, y_test_2_7= train_test_split(X_2_7, y_2_7, test_size=0.2,random_state=123)
X_train_2_8, X_test_2_8, y_train_2_8, y_test_2_8= train_test_split(X_2_8, y_2_8, test_size=0.2,random_state=123)
X_train_2_9_all, X_test_2_9_all, y_train_2_9_all, y_test_2_9_all= train_test_split(X_2_9_all, y_2_9_all, test_size=0.2,random_state=123)

# %%
X_train_1.shape,X_train_2.shape,X_train_3.shape,X_train_4.shape,X_train_5.shape,X_train_6.shape,X_train_7.shape,X_train_8.shape,X_train_9_all.shape
# Out:
# ((33, 1600),
#  (49, 1600),
#  (65, 1600),
#  (81, 1600),
#  (97, 1600),
#  (115, 1600),
#  (132, 1600),
#  (148, 1600),
#  (164, 1600))

# %%
X_test_1.shape,X_test_2.shape,X_test_3.shape,X_test_4.shape,X_test_5.shape,X_test_6.shape,X_test_7.shape,X_test_8.shape,X_test_9_all.shape,
# Out:
# ((9, 1600),
#  (13, 1600),
#  (17, 1600),
#  (21, 1600),
#  (25, 1600),
#  (29, 1600),
#  (33, 1600),
#  (38, 1600),
#  (42, 1600))

# %% [markdown]
#  2      3     4    1    0:
# left   right  up  down  No

# %% [markdown]
# # classification using ML models

# %%
RF_Accuracy=[]
SVM_Accuracy=[]
KNN_Accuracy=[]
RF_Accuracy2=[]
SVM_Accuracy2=[]
KNN_Accuracy2=[]

# %%
RF_Accuracy3=[]
SVM_Accuracy3=[]
KNN_Accuracy3=[]

# %% [markdown]
# # 1. Random Forest Classifier

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1.1 One volunteer

# %%
from sklearn.ensemble import RandomForestClassifier

classifier_rfc_1=RandomForestClassifier(max_depth=12)
classifier_rfc_1.fit(X_train_1,y_train_1)
y_pred_rfc_1=classifier_rfc_1.predict(X_train_1)
print("the accuracy of training data: ", accuracy_score(y_train_1,y_pred_rfc_1))
y_pred_rfc_test_1=classifier_rfc_1.predict(X_test_1)
print("the accuracy of testing data:  ", accuracy_score(y_test_1,y_pred_rfc_test_1))
RF_Accuracy.append(accuracy_score(y_test_1,y_pred_rfc_test_1))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.6666666666666666

# %%
cm_rfc_1 = confusion_matrix(y_test_1, y_pred_rfc_test_1, normalize='true')
class_names = ["No_person","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_rfc_1, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for Random Forest Classifier of one volunteer")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_rfc_1 = classification_report(y_test_1, y_pred_rfc_test_1)
print("Classification report for Random Forest of one volunteers:")
print(report_rfc_1)
# Out:
# Classification report for Random Forest of one volunteers:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       0.00      0.00      0.00         0
#            2       1.00      1.00      1.00         1
#            3       0.67      1.00      0.80         2
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.67         9
#    macro avg       0.53      0.60      0.56         9
# weighted avg       0.59      0.67      0.62         9
# C:\Users\hanan\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
classifier_rfc_12=RandomForestClassifier(max_depth=12)
classifier_rfc_12.fit(X_train_12,y_train_12)
y_pred_rfc_12=classifier_rfc_12.predict(X_train_12)
print("the accuracy of training data: ", accuracy_score(y_train_12,y_pred_rfc_12))
y_pred_rfc_test_12=classifier_rfc_12.predict(X_test_12)
print("the accuracy of testing data:  ", accuracy_score(y_test_12,y_pred_rfc_test_12))
RF_Accuracy2.append(accuracy_score(y_test_12,y_pred_rfc_test_12))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.75

# %%
classifier_rfc_2_1=RandomForestClassifier(max_depth=12)
classifier_rfc_2_1.fit(X_train_2_1,y_train_2_1)
y_pred_rfc_2_1=classifier_rfc_2_1.predict(X_train_2_1)
print("the accuracy of training data: ", accuracy_score(y_train_2_1,y_pred_rfc_2_1))
y_pred_rfc_test_2_1=classifier_rfc_2_1.predict(X_test_2_1)
print("the accuracy of testing data:  ", accuracy_score(y_test_2_1,y_pred_rfc_test_2_1))
RF_Accuracy3.append(accuracy_score(y_test_2_1,y_pred_rfc_test_2_1))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.9411764705882353

# %% [markdown]
# # 1.2 Two volunteers

# %%
from sklearn.ensemble import RandomForestClassifier

classifier_rfc_2=RandomForestClassifier(max_depth=12)
classifier_rfc_2.fit(X_train_2,y_train_2)
y_pred_rfc_2=classifier_rfc_2.predict(X_train_2)
print("the accuracy of training data: ", accuracy_score(y_train_2,y_pred_rfc_2))
y_pred_rfc_test_2=classifier_rfc_2.predict(X_test_2)
print("the accuracy of testing data:  ", accuracy_score(y_test_2,y_pred_rfc_test_2))
RF_Accuracy.append(accuracy_score(y_test_2,y_pred_rfc_test_2))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.9230769230769231

# %%
cm_rfc_2 = confusion_matrix(y_test_2, y_pred_rfc_test_2, normalize='true')
class_names = ["No_person","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_rfc_2, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for Random Forest Classifier of two volunteers")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_rfc_2 = classification_report(y_test_2, y_pred_rfc_test_2)
print("Classification report for Random Forest of two volunteers:")
print(report_rfc_2)
# Out:
# Classification report for Random Forest of two volunteers:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      0.75      0.86         4
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         2
#            4       0.50      1.00      0.67         1
#
#     accuracy                           0.92        13
#    macro avg       0.90      0.95      0.90        13
# weighted avg       0.96      0.92      0.93        13

# %%
#report_rfc_2 = classification_report(y_test_2, y_pred_rfc_test_2, output_dict=True)
#report_rfc_df_2 = pd.DataFrame(report_rfc_2).transpose()
#class_names = ["No_person","Down","Left","Right", "Up"]
#report_rfc_df_2=report_rfc_df_2.drop(['macro avg', 'weighted avg', 'accuracy'], axis=0)
#report_rfc_df_2=report_rfc_df_2.drop(['support'], axis=1)
#sns.heatmap(report_rfc_df_2, annot=True, cmap='Blues', fmt='.2%', cbar=False, yticklabels=class_names)
#plt.title("Random Forest of two volunteers")

# %%
classifier_rfc_22=RandomForestClassifier(max_depth=12)
classifier_rfc_22.fit(X_train_22,y_train_22)
y_pred_rfc_22=classifier_rfc_22.predict(X_train_22)
print("the accuracy of training data: ", accuracy_score(y_train_22,y_pred_rfc_22))
y_pred_rfc_test_22=classifier_rfc_22.predict(X_test_22)
print("the accuracy of testing data:  ", accuracy_score(y_test_22,y_pred_rfc_test_22))
RF_Accuracy2.append(accuracy_score(y_test_22,y_pred_rfc_test_22))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.8333333333333334

# %%
classifier_rfc_2_2=RandomForestClassifier(max_depth=12)
classifier_rfc_2_2.fit(X_train_2_2,y_train_2_2)
y_pred_rfc_2_2=classifier_rfc_2_2.predict(X_train_2_2)
print("the accuracy of training data: ", accuracy_score(y_train_2_2,y_pred_rfc_2_2))
y_pred_rfc_test_2_2=classifier_rfc_2_2.predict(X_test_2_2)
print("the accuracy of testing data:  ", accuracy_score(y_test_2_2,y_pred_rfc_test_2_2))
RF_Accuracy3.append(accuracy_score(y_test_2_2,y_pred_rfc_test_2_2))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.6

# %% [markdown]
# # 1.3 three volunteers

# %%
from sklearn.ensemble import RandomForestClassifier

classifier_rfc_3=RandomForestClassifier(max_depth=12)
classifier_rfc_3.fit(X_train_3,y_train_3)
y_pred_rfc_3=classifier_rfc_3.predict(X_train_3)
print("the accuracy of training data: ", accuracy_score(y_train_3,y_pred_rfc_3))
y_pred_rfc_test_3=classifier_rfc_3.predict(X_test_3)
print("the accuracy of testing data:  ", accuracy_score(y_test_3,y_pred_rfc_test_3))
RF_Accuracy.append(accuracy_score(y_test_3,y_pred_rfc_test_3))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.7647058823529411

# %%
cm_rfc_3 = confusion_matrix(y_test_3, y_pred_rfc_test_3, normalize='true')
class_names = ["No_person","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_rfc_3, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for Random Forest Classifier of three volunteers")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_rfc_3 = classification_report(y_test_3, y_pred_rfc_test_3)
print("Classification report for Random Forest of three volunteers:")
print(report_rfc_3)
# Out:
# Classification report for Random Forest of three volunteers:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         7
#            1       0.50      0.50      0.50         2
#            2       1.00      0.50      0.67         4
#            3       0.75      0.75      0.75         4
#            4       0.00      0.00      0.00         0
#
#     accuracy                           0.76        17
#    macro avg       0.65      0.55      0.58        17
# weighted avg       0.88      0.76      0.80        17
# C:\Users\hanan\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
classifier_rfc_32=RandomForestClassifier(max_depth=12)
classifier_rfc_32.fit(X_train_32,y_train_32)
y_pred_rfc_32=classifier_rfc_32.predict(X_train_32)
print("the accuracy of training data: ", accuracy_score(y_train_32,y_pred_rfc_32))
y_pred_rfc_test_32=classifier_rfc_32.predict(X_test_32)
print("the accuracy of testing data:  ", accuracy_score(y_test_32,y_pred_rfc_test_32))
RF_Accuracy2.append(accuracy_score(y_test_32,y_pred_rfc_test_32))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   1.0

# %%
classifier_rfc_2_3=RandomForestClassifier(max_depth=12)
classifier_rfc_2_3.fit(X_train_2_3,y_train_2_3)
y_pred_rfc_2_3=classifier_rfc_2_3.predict(X_train_2_3)
print("the accuracy of training data: ", accuracy_score(y_train_2_3,y_pred_rfc_2_3))
y_pred_rfc_test_2_3=classifier_rfc_2_3.predict(X_test_2_3)
print("the accuracy of testing data:  ", accuracy_score(y_test_2_3,y_pred_rfc_test_2_3))
RF_Accuracy3.append(accuracy_score(y_test_2_3,y_pred_rfc_test_2_3))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.8484848484848485

# %% [markdown]
# # 1.4 Four volunteers

# %%
from sklearn.ensemble import RandomForestClassifier

classifier_rfc_4=RandomForestClassifier(max_depth=12)
classifier_rfc_4.fit(X_train_4,y_train_4)
y_pred_rfc_4=classifier_rfc_4.predict(X_train_4)
print("the accuracy of training data: ", accuracy_score(y_train_4,y_pred_rfc_4))
y_pred_rfc_test_4=classifier_rfc_4.predict(X_test_4)
print("the accuracy of testing data:  ", accuracy_score(y_test_4,y_pred_rfc_test_4))
RF_Accuracy.append(accuracy_score(y_test_4,y_pred_rfc_test_4))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.8095238095238095

# %%
cm_rfc_4 = confusion_matrix(y_test_4, y_pred_rfc_test_4, normalize='true')
class_names = ["No_person","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_rfc_4, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for Random Forest Classifier of four volunteer")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_rfc_4 = classification_report(y_test_4, y_pred_rfc_test_4)
print("Classification report for Random Forest of four volunteers:")
print(report_rfc_4)
# Out:
# Classification report for Random Forest of four volunteers:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       0.50      1.00      0.67         3
#            2       1.00      0.86      0.92         7
#            3       1.00      0.60      0.75         5
#            4       0.67      0.67      0.67         3
#
#     accuracy                           0.81        21
#    macro avg       0.83      0.82      0.80        21
# weighted avg       0.88      0.81      0.82        21

# %%
classifier_rfc_42=RandomForestClassifier(max_depth=12)
classifier_rfc_42.fit(X_train_42,y_train_42)
y_pred_rfc_42=classifier_rfc_42.predict(X_train_42)
print("the accuracy of training data: ", accuracy_score(y_train_42,y_pred_rfc_42))
y_pred_rfc_test_42=classifier_rfc_42.predict(X_test_42)
print("the accuracy of testing data:  ", accuracy_score(y_test_42,y_pred_rfc_test_42))
RF_Accuracy2.append(accuracy_score(y_test_42,y_pred_rfc_test_42))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.8

# %%
classifier_rfc_2_4=RandomForestClassifier(max_depth=12)
classifier_rfc_2_4.fit(X_train_2_4,y_train_2_4)
y_pred_rfc_2_4=classifier_rfc_2_4.predict(X_train_2_4)
print("the accuracy of training data: ", accuracy_score(y_train_2_4,y_pred_rfc_2_4))
y_pred_rfc_test_2_4=classifier_rfc_2_4.predict(X_test_2_4)
print("the accuracy of testing data:  ", accuracy_score(y_test_2_4,y_pred_rfc_test_2_4))
RF_Accuracy3.append(accuracy_score(y_test_2_4,y_pred_rfc_test_2_4))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.6585365853658537

# %% [markdown]
# # 1.5 Five volunteers

# %%
from sklearn.ensemble import RandomForestClassifier

classifier_rfc_5=RandomForestClassifier(max_depth=12)
classifier_rfc_5.fit(X_train_5,y_train_5)
y_pred_rfc_5=classifier_rfc_5.predict(X_train_5)
print("the accuracy of training data: ", accuracy_score(y_train_5,y_pred_rfc_5))
y_pred_rfc_test_5=classifier_rfc_5.predict(X_test_5)
print("the accuracy of testing data:  ", accuracy_score(y_test_5,y_pred_rfc_test_5))
RF_Accuracy.append(accuracy_score(y_test_5,y_pred_rfc_test_5))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.76

# %%
cm_rfc_5 = confusion_matrix(y_test_5, y_pred_rfc_test_5, normalize='true')
class_names = ["No_person","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_rfc_5, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for Random Forest Classifier of five volunteers")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_rfc_5 = classification_report(y_test_5, y_pred_rfc_test_5)
print("Classification report for Random Forest of five volunteers:")
print(report_rfc_5)
# Out:
# Classification report for Random Forest of five volunteers:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       0.57      1.00      0.73         4
#            2       1.00      0.60      0.75         5
#            3       1.00      0.50      0.67         8
#            4       0.67      1.00      0.80         6
#
#     accuracy                           0.76        25
#    macro avg       0.85      0.82      0.79        25
# weighted avg       0.85      0.76      0.75        25

# %%
classifier_rfc_52=RandomForestClassifier(max_depth=12)
classifier_rfc_52.fit(X_train_52,y_train_52)
y_pred_rfc_52=classifier_rfc_52.predict(X_train_52)
print("the accuracy of training data: ", accuracy_score(y_train_52,y_pred_rfc_52))
y_pred_rfc_test_52=classifier_rfc_52.predict(X_test_52)
print("the accuracy of testing data:  ", accuracy_score(y_test_52,y_pred_rfc_test_52))
RF_Accuracy2.append(accuracy_score(y_test_52,y_pred_rfc_test_52))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.9583333333333334

# %%
classifier_rfc_2_5=RandomForestClassifier(max_depth=12)
classifier_rfc_2_5.fit(X_train_2_5,y_train_2_5)
y_pred_rfc_2_5=classifier_rfc_2_5.predict(X_train_2_5)
print("the accuracy of training data: ", accuracy_score(y_train_2_5,y_pred_rfc_2_5))
y_pred_rfc_test_2_5=classifier_rfc_2_5.predict(X_test_2_5)
print("the accuracy of testing data:  ", accuracy_score(y_test_2_5,y_pred_rfc_test_2_5))
RF_Accuracy3.append(accuracy_score(y_test_2_5,y_pred_rfc_test_2_5))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.7346938775510204

# %% [markdown]
# # 1.6 six volunteers

# %%
from sklearn.ensemble import RandomForestClassifier

classifier_rfc_6=RandomForestClassifier(max_depth=12)
classifier_rfc_6.fit(X_train_6,y_train_6)
y_pred_rfc_6=classifier_rfc_6.predict(X_train_6)
print("the accuracy of training data: ", accuracy_score(y_train_6,y_pred_rfc_6))
y_pred_rfc_test_6=classifier_rfc_6.predict(X_test_6)
print("the accuracy of testing data:  ", accuracy_score(y_test_6,y_pred_rfc_test_6))
RF_Accuracy.append(accuracy_score(y_test_6,y_pred_rfc_test_6))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.8620689655172413

# %%
cm_rfc_6 = confusion_matrix(y_test_6, y_pred_rfc_test_6, normalize='true')
class_names = ["No_person","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_rfc_6, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for Random Forest Classifier of six volunteers")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_rfc_6 = classification_report(y_test_6, y_pred_rfc_test_6)
print("Classification report for Random Forest of six volunteers:")
print(report_rfc_6)
# Out:
# Classification report for Random Forest of six volunteers:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       0.67      0.80      0.73         5
#            2       1.00      0.86      0.92         7
#            3       0.83      0.83      0.83         6
#            4       0.83      0.83      0.83         6
#
#     accuracy                           0.86        29
#    macro avg       0.87      0.86      0.86        29
# weighted avg       0.87      0.86      0.87        29

# %%
classifier_rfc_62=RandomForestClassifier(max_depth=12)
classifier_rfc_62.fit(X_train_62,y_train_62)
y_pred_rfc_62=classifier_rfc_62.predict(X_train_62)
print("the accuracy of training data: ", accuracy_score(y_train_62,y_pred_rfc_62))
y_pred_rfc_test_62=classifier_rfc_62.predict(X_test_62)
print("the accuracy of testing data:  ", accuracy_score(y_test_62,y_pred_rfc_test_62))
RF_Accuracy2.append(accuracy_score(y_test_62,y_pred_rfc_test_62))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.8620689655172413

# %%
classifier_rfc_2_6=RandomForestClassifier(max_depth=12)
classifier_rfc_2_6.fit(X_train_2_6,y_train_2_6)
y_pred_rfc_2_6=classifier_rfc_2_6.predict(X_train_2_6)
print("the accuracy of training data: ", accuracy_score(y_train_2_6,y_pred_rfc_2_6))
y_pred_rfc_test_2_6=classifier_rfc_2_6.predict(X_test_2_6)
print("the accuracy of testing data:  ", accuracy_score(y_test_2_6,y_pred_rfc_test_2_6))
RF_Accuracy3.append(accuracy_score(y_test_2_6,y_pred_rfc_test_2_6))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.8275862068965517

# %% [markdown]
# # 1.7 seven volunteers

# %%
from sklearn.ensemble import RandomForestClassifier

classifier_rfc_7=RandomForestClassifier(max_depth=12)
classifier_rfc_7.fit(X_train_7,y_train_7)
y_pred_rfc_7=classifier_rfc_7.predict(X_train_7)
print("the accuracy of training data: ", accuracy_score(y_train_7,y_pred_rfc_7))
y_pred_rfc_test_7=classifier_rfc_7.predict(X_test_7)
print("the accuracy of testing data:  ", accuracy_score(y_test_7,y_pred_rfc_test_7))
RF_Accuracy.append(accuracy_score(y_test_7,y_pred_rfc_test_7))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.7272727272727273

# %%
cm_rfc_7 = confusion_matrix(y_test_7, y_pred_rfc_test_7, normalize='true')
class_names = ["No_person","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_rfc_7, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for Random Forest Classifier of seven volunteers")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_rfc_7 = classification_report(y_test_7, y_pred_rfc_test_7)
print("Classification report for Random Forest of seven volunteers:")
print(report_rfc_7)
# Out:
# Classification report for Random Forest of seven volunteers:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       0.50      0.60      0.55         5
#            2       0.88      0.88      0.88         8
#            3       0.67      0.57      0.62         7
#            4       0.57      0.57      0.57         7
#
#     accuracy                           0.73        33
#    macro avg       0.72      0.72      0.72        33
# weighted avg       0.73      0.73      0.73        33

# %%
classifier_rfc_72=RandomForestClassifier(max_depth=12)
classifier_rfc_72.fit(X_train_72,y_train_72)
y_pred_rfc_72=classifier_rfc_72.predict(X_train_72)
print("the accuracy of training data: ", accuracy_score(y_train_72,y_pred_rfc_72))
y_pred_rfc_test_72=classifier_rfc_72.predict(X_test_72)
print("the accuracy of testing data:  ", accuracy_score(y_test_72,y_pred_rfc_test_72))
RF_Accuracy2.append(accuracy_score(y_test_72,y_pred_rfc_test_72))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.9090909090909091

# %%
classifier_rfc_2_7=RandomForestClassifier(max_depth=12)
classifier_rfc_2_7.fit(X_train_2_7,y_train_2_7)
y_pred_rfc_2_7=classifier_rfc_2_7.predict(X_train_2_7)
print("the accuracy of training data: ", accuracy_score(y_train_2_7,y_pred_rfc_2_7))
y_pred_rfc_test_2_7=classifier_rfc_2_7.predict(X_test_2_7)
print("the accuracy of testing data:  ", accuracy_score(y_test_2_7,y_pred_rfc_test_2_7))
RF_Accuracy3.append(accuracy_score(y_test_2_7,y_pred_rfc_test_2_7))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.7727272727272727

# %% [markdown]
# # 1.8 eight volunteers

# %%
from sklearn.ensemble import RandomForestClassifier

classifier_rfc_8=RandomForestClassifier(max_depth=12)
classifier_rfc_8.fit(X_train_8,y_train_8)
y_pred_rfc_8=classifier_rfc_8.predict(X_train_8)
print("the accuracy of training data: ", accuracy_score(y_train_8,y_pred_rfc_8))
y_pred_rfc_test_8=classifier_rfc_8.predict(X_test_8)
print("the accuracy of testing data:  ", accuracy_score(y_test_8,y_pred_rfc_test_8))
RF_Accuracy.append(accuracy_score(y_test_8,y_pred_rfc_test_8))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.8157894736842105

# %%
cm_rfc_8 = confusion_matrix(y_test_8, y_pred_rfc_test_8, normalize='true')
class_names = ["No_person","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_rfc_8, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for Random Forest Classifier of eight volunteers")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_rfc_8 = classification_report(y_test_8, y_pred_rfc_test_8)
print("Classification report for Random Forest of eight volunteers:")
print(report_rfc_8)
# Out:
# Classification report for Random Forest of eight volunteers:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       0.86      0.60      0.71        10
#            2       1.00      0.91      0.95        11
#            3       0.78      1.00      0.88         7
#            4       0.50      0.67      0.57         6
#
#     accuracy                           0.82        38
#    macro avg       0.83      0.84      0.82        38
# weighted avg       0.84      0.82      0.82        38

# %%
classifier_rfc_82=RandomForestClassifier(max_depth=12)
classifier_rfc_82.fit(X_train_82,y_train_82)
y_pred_rfc_82=classifier_rfc_82.predict(X_train_82)
print("the accuracy of training data: ", accuracy_score(y_train_82,y_pred_rfc_82))
y_pred_rfc_test_82=classifier_rfc_82.predict(X_test_82)
print("the accuracy of testing data:  ", accuracy_score(y_test_82,y_pred_rfc_test_82))
RF_Accuracy2.append(accuracy_score(y_test_82,y_pred_rfc_test_82))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.8648648648648649

# %%
classifier_rfc_2_8=RandomForestClassifier(max_depth=12)
classifier_rfc_2_8.fit(X_train_2_8,y_train_2_8)
y_pred_rfc_2_8=classifier_rfc_2_8.predict(X_train_2_8)
print("the accuracy of training data: ", accuracy_score(y_train_2_8,y_pred_rfc_2_8))
y_pred_rfc_test_2_8=classifier_rfc_2_8.predict(X_test_2_8)
print("the accuracy of testing data:  ", accuracy_score(y_test_2_8,y_pred_rfc_test_2_8))
RF_Accuracy3.append(accuracy_score(y_test_2_8,y_pred_rfc_test_2_8))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.7972972972972973

# %% [markdown]
# # 1.9 nine volunteers (All)

# %%
from sklearn.ensemble import RandomForestClassifier

classifier_rfc_9_all=RandomForestClassifier(max_depth=12)
classifier_rfc_9_all.fit(X_train_9_all,y_train_9_all)
y_pred_rfc_9_all=classifier_rfc_9_all.predict(X_train_9_all)
print("the accuracy of training data: ", accuracy_score(y_train_9_all,y_pred_rfc_9_all))
y_pred_rfc_test_9_all=classifier_rfc_9_all.predict(X_test_9_all)
print("the accuracy of testing data:  ", accuracy_score(y_test_9_all,y_pred_rfc_test_9_all))
RF_Accuracy.append(accuracy_score(y_test_9_all,y_pred_rfc_test_9_all))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.8095238095238095

# %%
cm_rfc_9_all = confusion_matrix(y_test_9_all, y_pred_rfc_test_9_all, normalize='true')
class_names = ["No_person","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_rfc_9_all, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for Random Forest Classifier of nine volunteers at room lab1")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_rfc_9_all = classification_report(y_test_9_all, y_pred_rfc_test_9_all)
print("Classification report for Random Forest of nine volunteers in room lab1:")
print(report_rfc_9_all)
# Out:
# Classification report for Random Forest of nine volunteers in room lab1:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       0.64      0.70      0.67        10
#            2       1.00      1.00      1.00        10
#            3       1.00      0.89      0.94         9
#            4       0.56      0.56      0.56         9
#
#     accuracy                           0.81        42
#    macro avg       0.84      0.83      0.83        42
# weighted avg       0.82      0.81      0.81        42

# %%
classifier_rfc_92_all=RandomForestClassifier(max_depth=12)
classifier_rfc_92_all.fit(X_train_92_all,y_train_92_all)
y_pred_rfc_92_all=classifier_rfc_92_all.predict(X_train_92_all)
print("the accuracy of training data: ", accuracy_score(y_train_92_all,y_pred_rfc_92_all))
y_pred_rfc_test_92_all=classifier_rfc_92_all.predict(X_test_92_all)
print("the accuracy of testing data:  ", accuracy_score(y_test_92_all,y_pred_rfc_test_92_all))
RF_Accuracy2.append(accuracy_score(y_test_92_all,y_pred_rfc_test_92_all))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.926829268292683

# %%
classifier_rfc_2_9=RandomForestClassifier(max_depth=12)
classifier_rfc_2_9.fit(X_train_2_9_all,y_train_2_9_all)
y_pred_rfc_2_9=classifier_rfc_2_9.predict(X_train_2_9_all)
print("the accuracy of training data: ", accuracy_score(y_train_2_9_all,y_pred_rfc_2_9))
y_pred_rfc_test_2_9=classifier_rfc_2_9.predict(X_test_2_9_all)
print("the accuracy of testing data:  ", accuracy_score(y_test_2_9_all,y_pred_rfc_test_2_9))
RF_Accuracy3.append(accuracy_score(y_test_2_9_all,y_pred_rfc_test_2_9))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.8333333333333334

# %% [markdown]
# # 1.2 Support Vector Machine

# %% [markdown]
# # 1.2.1 one volunteer

# %%
from sklearn import svm
classifier_svm_1 = svm.SVC(kernel='linear')
classifier_svm_1.fit(X_train_1,y_train_1)
y_pred_svm_1=classifier_svm_1.predict(X_train_1)
print("the accuracy of training data: ", accuracy_score(y_train_1,y_pred_svm_1))
y_pred_svm_test_1=classifier_svm_1.predict(X_test_1)
print("the accuracy of testing data:  ", accuracy_score(y_test_1,y_pred_svm_test_1))
SVM_Accuracy.append(accuracy_score(y_test_1,y_pred_svm_test_1))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.7777777777777778

# %%
cm_svm_1 = confusion_matrix(y_test_1, y_pred_svm_test_1, normalize='true')
class_names = ["No_person","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_svm_1, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for Support Vector Machines of one volunteer")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_svm_1 = classification_report(y_test_1, y_pred_svm_test_1)
print("Classification report for Support Vector Machines of one volunteers:")
print(report_svm_1)
# Out:
# Classification report for Support Vector Machines of one volunteers:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            2       0.00      0.00      0.00         1
#            3       0.50      0.50      0.50         2
#            4       0.75      1.00      0.86         3
#
#     accuracy                           0.78         9
#    macro avg       0.56      0.62      0.59         9
# weighted avg       0.69      0.78      0.73         9
# C:\Users\hanan\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
classifier_svm_12 = svm.SVC(kernel='linear')
classifier_svm_12.fit(X_train_12,y_train_12)
y_pred_svm_12=classifier_svm_12.predict(X_train_12)
print("the accuracy of training data: ", accuracy_score(y_train_12,y_pred_svm_12))
y_pred_svm_test_12=classifier_svm_12.predict(X_test_12)
print("the accuracy of testing data:  ", accuracy_score(y_test_12,y_pred_svm_test_12))
SVM_Accuracy2.append(accuracy_score(y_test_12,y_pred_svm_test_12))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.875

# %%
classifier_svm_2_1 = svm.SVC(kernel='linear')
classifier_svm_2_1.fit(X_train_2_1,y_train_2_1)
y_pred_svm_2_1=classifier_svm_2_1.predict(X_train_2_1)
print("the accuracy of training data: ", accuracy_score(y_train_2_1,y_pred_svm_2_1))
y_pred_svm_test_2_1=classifier_svm_2_1.predict(X_test_2_1)
print("the accuracy of testing data:  ", accuracy_score(y_test_2_1,y_pred_svm_test_2_1))
SVM_Accuracy3.append(accuracy_score(y_test_2_1,y_pred_svm_test_2_1))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   1.0

# %% [markdown]
# # 1.2.2 two volunteers

# %%
from sklearn import svm
classifier_svm_2 = svm.SVC(kernel='linear')
classifier_svm_2.fit(X_train_2,y_train_2)
y_pred_svm_2=classifier_svm_2.predict(X_train_2)
print("the accuracy of training data: ", accuracy_score(y_train_2,y_pred_svm_2))
y_pred_svm_test_2=classifier_svm_2.predict(X_test_2)
print("the accuracy of testing data:  ", accuracy_score(y_test_2,y_pred_svm_test_2))
SVM_Accuracy.append(accuracy_score(y_test_2,y_pred_svm_test_2))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.9230769230769231

# %%
cm_svm_2 = confusion_matrix(y_test_2, y_pred_svm_test_2, normalize='true')
class_names = ["No_person","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_svm_2, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for Support Vector Machines of two volunteers")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_svm_2 = classification_report(y_test_2, y_pred_svm_test_2)
print("Classification report for Support Vector Machines of two volunteers:")
print(report_svm_2)
# Out:
# Classification report for Support Vector Machines of two volunteers:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         4
#            2       0.67      1.00      0.80         2
#            3       1.00      0.50      0.67         2
#            4       1.00      1.00      1.00         1
#
#     accuracy                           0.92        13
#    macro avg       0.93      0.90      0.89        13
# weighted avg       0.95      0.92      0.92        13

# %%
classifier_svm_22 = svm.SVC(kernel='linear')
classifier_svm_22.fit(X_train_22,y_train_22)
y_pred_svm_22=classifier_svm_22.predict(X_train_22)
print("the accuracy of training data: ", accuracy_score(y_train_22,y_pred_svm_22))
y_pred_svm_test_22=classifier_svm_22.predict(X_test_22)
print("the accuracy of testing data:  ", accuracy_score(y_test_22,y_pred_svm_test_22))
SVM_Accuracy2.append(accuracy_score(y_test_22,y_pred_svm_test_22))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.9166666666666666

# %%
classifier_svm_2_2 = svm.SVC(kernel='linear')
classifier_svm_2_2.fit(X_train_2_2,y_train_2_2)
y_pred_svm_2_2=classifier_svm_2_2.predict(X_train_2_2)
print("the accuracy of training data: ", accuracy_score(y_train_2_2,y_pred_svm_2_2))
y_pred_svm_test_2_2=classifier_svm_2_2.predict(X_test_2_2)
print("the accuracy of testing data:  ", accuracy_score(y_test_2_2,y_pred_svm_test_2_2))
SVM_Accuracy3.append(accuracy_score(y_test_2_2,y_pred_svm_test_2_2))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.68

# %% [markdown]
# # 1.2.3 three volunteers

# %%
from sklearn import svm
classifier_svm_3 = svm.SVC(kernel='linear')
classifier_svm_3.fit(X_train_3,y_train_3)
y_pred_svm_3=classifier_svm_3.predict(X_train_3)
print("the accuracy of training data: ", accuracy_score(y_train_3,y_pred_svm_3))
y_pred_svm_test_3=classifier_svm_3.predict(X_test_3)
print("the accuracy of testing data:  ", accuracy_score(y_test_3,y_pred_svm_test_3))
SVM_Accuracy.append(accuracy_score(y_test_3,y_pred_svm_test_3))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.8823529411764706

# %%
cm_svm_3 = confusion_matrix(y_test_3, y_pred_svm_test_3, normalize='true')
class_names = ["No_person","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_svm_3, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for Support Vector Machines of three volunteers")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_svm_3 = classification_report(y_test_3, y_pred_svm_test_3)
print("Classification report for Support Vector Machines of three volunteers:")
print(report_svm_3)
# Out:
# Classification report for Support Vector Machines of three volunteers:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         7
#            1       0.67      1.00      0.80         2
#            2       0.80      1.00      0.89         4
#            3       1.00      0.50      0.67         4
#
#     accuracy                           0.88        17
#    macro avg       0.87      0.88      0.84        17
# weighted avg       0.91      0.88      0.87        17

# %%
classifier_svm_32 = svm.SVC(kernel='linear')
classifier_svm_32.fit(X_train_32,y_train_32)
y_pred_svm_32=classifier_svm_32.predict(X_train_32)
print("the accuracy of training data: ", accuracy_score(y_train_32,y_pred_svm_32))
y_pred_svm_test_32=classifier_svm_32.predict(X_test_32)
print("the accuracy of testing data:  ", accuracy_score(y_test_32,y_pred_svm_test_32))
SVM_Accuracy2.append(accuracy_score(y_test_32,y_pred_svm_test_32))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   1.0

# %%
classifier_svm_2_3 = svm.SVC(kernel='linear')
classifier_svm_2_3.fit(X_train_2_3,y_train_2_3)
y_pred_svm_2_3=classifier_svm_2_3.predict(X_train_2_3)
print("the accuracy of training data: ", accuracy_score(y_train_2_3,y_pred_svm_2_3))
y_pred_svm_test_2_3=classifier_svm_2_3.predict(X_test_2_3)
print("the accuracy of testing data:  ", accuracy_score(y_test_2_3,y_pred_svm_test_2_3))
SVM_Accuracy3.append(accuracy_score(y_test_2_3,y_pred_svm_test_2_3))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.7272727272727273

# %% [markdown]
# # 1.2.4 four volunteers

# %%
from sklearn import svm
classifier_svm_4 = svm.SVC(kernel='linear')
classifier_svm_4.fit(X_train_4,y_train_4)
y_pred_svm_4=classifier_svm_4.predict(X_train_4)
print("the accuracy of training data: ", accuracy_score(y_train_4,y_pred_svm_4))
y_pred_svm_test_4=classifier_svm_4.predict(X_test_4)
print("the accuracy of testing data:  ", accuracy_score(y_test_4,y_pred_svm_test_4))
SVM_Accuracy.append(accuracy_score(y_test_4,y_pred_svm_test_4))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.7619047619047619

# %%
cm_svm_4 = confusion_matrix(y_test_4, y_pred_svm_test_4, normalize='true')
class_names = ["No_person","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_svm_4, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for Support Vector Machines of four volunteers")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_svm_4 = classification_report(y_test_4, y_pred_svm_test_4)
print("Classification report for Support Vector Machines of four volunteers:")
print(report_svm_4)
# Out:
# Classification report for Support Vector Machines of four volunteers:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       0.60      1.00      0.75         3
#            2       1.00      1.00      1.00         7
#            3       1.00      0.20      0.33         5
#            4       0.40      0.67      0.50         3
#
#     accuracy                           0.76        21
#    macro avg       0.80      0.77      0.72        21
# weighted avg       0.86      0.76      0.73        21

# %%
classifier_svm_42 = svm.SVC(kernel='linear')
classifier_svm_42.fit(X_train_42,y_train_42)
y_pred_svm_42=classifier_svm_42.predict(X_train_42)
print("the accuracy of training data: ", accuracy_score(y_train_42,y_pred_svm_42))
y_pred_svm_test_42=classifier_svm_42.predict(X_test_42)
print("the accuracy of testing data:  ", accuracy_score(y_test_42,y_pred_svm_test_42))
SVM_Accuracy2.append(accuracy_score(y_test_42,y_pred_svm_test_42))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.95

# %%
classifier_svm_2_4 = svm.SVC(kernel='linear')
classifier_svm_2_4.fit(X_train_2_4,y_train_2_4)
y_pred_svm_2_4=classifier_svm_2_4.predict(X_train_2_4)
print("the accuracy of training data: ", accuracy_score(y_train_2_4,y_pred_svm_2_4))
y_pred_svm_test_2_4=classifier_svm_2_4.predict(X_test_2_4)
print("the accuracy of testing data:  ", accuracy_score(y_test_2_4,y_pred_svm_test_2_4))
SVM_Accuracy3.append(accuracy_score(y_test_2_4,y_pred_svm_test_2_4))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.7317073170731707

# %% [markdown]
# # 1.2.5 five volunteers

# %%
from sklearn import svm
classifier_svm_5 = svm.SVC(kernel='linear')
classifier_svm_5.fit(X_train_5,y_train_5)
y_pred_svm_5=classifier_svm_5.predict(X_train_5)
print("the accuracy of training data: ", accuracy_score(y_train_5,y_pred_svm_5))
y_pred_svm_test_5=classifier_svm_5.predict(X_test_5)
print("the accuracy of testing data:  ", accuracy_score(y_test_5,y_pred_svm_test_5))
SVM_Accuracy.append(accuracy_score(y_test_5,y_pred_svm_test_5))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.88

# %%
cm_svm_5 = confusion_matrix(y_test_5, y_pred_svm_test_5, normalize='true')
class_names = ["No_person","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_svm_5, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for Support Vector Machines of five volunteers")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_svm_5 = classification_report(y_test_5, y_pred_svm_test_5)
print("Classification report for Support Vector Machines of five volunteers:")
print(report_svm_5)
# Out:
# Classification report for Support Vector Machines of five volunteers:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         4
#            2       1.00      1.00      1.00         5
#            3       1.00      0.62      0.77         8
#            4       0.67      1.00      0.80         6
#
#     accuracy                           0.88        25
#    macro avg       0.93      0.93      0.91        25
# weighted avg       0.92      0.88      0.88        25

# %%
classifier_svm_52 = svm.SVC(kernel='linear')
classifier_svm_52.fit(X_train_52,y_train_52)
y_pred_svm_52=classifier_svm_52.predict(X_train_52)
print("the accuracy of training data: ", accuracy_score(y_train_52,y_pred_svm_52))
y_pred_svm_test_52=classifier_svm_52.predict(X_test_52)
print("the accuracy of testing data:  ", accuracy_score(y_test_52,y_pred_svm_test_52))
SVM_Accuracy2.append(accuracy_score(y_test_52,y_pred_svm_test_52))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.8333333333333334

# %%
classifier_svm_2_5 = svm.SVC(kernel='linear')
classifier_svm_2_5.fit(X_train_2_5,y_train_2_5)
y_pred_svm_2_5=classifier_svm_2_5.predict(X_train_2_5)
print("the accuracy of training data: ", accuracy_score(y_train_2_5,y_pred_svm_2_5))
y_pred_svm_test_2_5=classifier_svm_2_5.predict(X_test_2_5)
print("the accuracy of testing data:  ", accuracy_score(y_test_2_5,y_pred_svm_test_2_5))
SVM_Accuracy3.append(accuracy_score(y_test_2_5,y_pred_svm_test_2_5))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.673469387755102

# %% [markdown]
# # 1.2.6 six volunteers

# %%
from sklearn import svm
classifier_svm_6 = svm.SVC(kernel='linear')
classifier_svm_6.fit(X_train_6,y_train_6)
y_pred_svm_6=classifier_svm_6.predict(X_train_6)
print("the accuracy of training data: ", accuracy_score(y_train_6,y_pred_svm_6))
y_pred_svm_test_6=classifier_svm_6.predict(X_test_6)
print("the accuracy of testing data:  ", accuracy_score(y_test_6,y_pred_svm_test_6))
SVM_Accuracy.append(accuracy_score(y_test_6,y_pred_svm_test_6))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.896551724137931

# %%
cm_svm_6 = confusion_matrix(y_test_6, y_pred_svm_test_6, normalize='true')
class_names = ["No_person","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_svm_6, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for Support Vector Machines of six volunteers")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_svm_1 = classification_report(y_test_1, y_pred_svm_test_1)
print("Classification report for Support Vector Machines of six volunteers:")
print(report_svm_1)
# Out:
# Classification report for Support Vector Machines of six volunteers:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            2       0.00      0.00      0.00         1
#            3       0.50      0.50      0.50         2
#            4       0.75      1.00      0.86         3
#
#     accuracy                           0.78         9
#    macro avg       0.56      0.62      0.59         9
# weighted avg       0.69      0.78      0.73         9
# C:\Users\hanan\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
classifier_svm_62 = svm.SVC(kernel='linear')
classifier_svm_62.fit(X_train_62,y_train_62)
y_pred_svm_62=classifier_svm_62.predict(X_train_62)
print("the accuracy of training data: ", accuracy_score(y_train_62,y_pred_svm_62))
y_pred_svm_test_62=classifier_svm_62.predict(X_test_62)
print("the accuracy of testing data:  ", accuracy_score(y_test_62,y_pred_svm_test_62))
SVM_Accuracy2.append(accuracy_score(y_test_62,y_pred_svm_test_62))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.7931034482758621

# %%
classifier_svm_2_6 = svm.SVC(kernel='linear')
classifier_svm_2_6.fit(X_train_2_6,y_train_2_6)
y_pred_svm_2_6=classifier_svm_2_6.predict(X_train_2_6)
print("the accuracy of training data: ", accuracy_score(y_train_2_6,y_pred_svm_2_6))
y_pred_svm_test_2_6=classifier_svm_2_6.predict(X_test_2_6)
print("the accuracy of testing data:  ", accuracy_score(y_test_2_6,y_pred_svm_test_2_6))
SVM_Accuracy3.append(accuracy_score(y_test_2_6,y_pred_svm_test_2_6))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.8103448275862069

# %% [markdown]
# # 1.2.7 seven volunteers

# %%
from sklearn import svm
classifier_svm_7 = svm.SVC(kernel='linear')
classifier_svm_7.fit(X_train_7,y_train_7)
y_pred_svm_7=classifier_svm_7.predict(X_train_7)
print("the accuracy of training data: ", accuracy_score(y_train_7,y_pred_svm_7))
y_pred_svm_test_7=classifier_svm_7.predict(X_test_7)
print("the accuracy of testing data:  ", accuracy_score(y_test_7,y_pred_svm_test_7))
SVM_Accuracy.append(accuracy_score(y_test_7,y_pred_svm_test_7))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.8787878787878788

# %%
cm_svm_7 = confusion_matrix(y_test_7, y_pred_svm_test_7, normalize='true')
class_names = ["No_person","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_svm_7, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for Support Vector Machines of seven volunteers")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_svm_7 = classification_report(y_test_7, y_pred_svm_test_7)
print("Classification report for Support Vector Machines of seven volunteers:")
print(report_svm_7)
# Out:
# Classification report for Support Vector Machines of seven volunteers:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       1.00      1.00      1.00         5
#            2       1.00      0.88      0.93         8
#            3       0.80      0.57      0.67         7
#            4       0.70      1.00      0.82         7
#
#     accuracy                           0.88        33
#    macro avg       0.90      0.89      0.88        33
# weighted avg       0.89      0.88      0.88        33

# %%
classifier_svm_72 = svm.SVC(kernel='linear')
classifier_svm_72.fit(X_train_72,y_train_72)
y_pred_svm_72=classifier_svm_72.predict(X_train_72)
print("the accuracy of training data: ", accuracy_score(y_train_72,y_pred_svm_72))
y_pred_svm_test_72=classifier_svm_72.predict(X_test_72)
print("the accuracy of testing data:  ", accuracy_score(y_test_72,y_pred_svm_test_72))
SVM_Accuracy2.append(accuracy_score(y_test_72,y_pred_svm_test_72))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.9090909090909091

# %%
classifier_svm_2_7 = svm.SVC(kernel='linear')
classifier_svm_2_7.fit(X_train_2_7,y_train_2_7)
y_pred_svm_2_7=classifier_svm_2_7.predict(X_train_2_7)
print("the accuracy of training data: ", accuracy_score(y_train_2_7,y_pred_svm_2_7))
y_pred_svm_test_2_7=classifier_svm_2_7.predict(X_test_2_7)
print("the accuracy of testing data:  ", accuracy_score(y_test_2_7,y_pred_svm_test_2_7))
SVM_Accuracy3.append(accuracy_score(y_test_2_7,y_pred_svm_test_2_7))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.8181818181818182

# %% [markdown]
# # 1.2.8 eight volunteers

# %%
from sklearn import svm
classifier_svm_8 = svm.SVC(kernel='linear')
classifier_svm_8.fit(X_train_8,y_train_8)
y_pred_svm_8=classifier_svm_8.predict(X_train_8)
print("the accuracy of training data: ", accuracy_score(y_train_8,y_pred_svm_8))
y_pred_svm_test_8=classifier_svm_8.predict(X_test_8)
print("the accuracy of testing data:  ", accuracy_score(y_test_8,y_pred_svm_test_8))
SVM_Accuracy.append(accuracy_score(y_test_8,y_pred_svm_test_8))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   1.0

# %%
cm_svm_8 = confusion_matrix(y_test_8, y_pred_svm_test_8, normalize='true')
class_names = ["No_person","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_svm_8, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for Support Vector Machines of eight volunteers")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_svm_8 = classification_report(y_test_8, y_pred_svm_test_8)
print("Classification report for Support Vector Machines of eight volunteers:")
print(report_svm_8)
# Out:
# Classification report for Support Vector Machines of eight volunteers:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00        10
#            2       1.00      1.00      1.00        11
#            3       1.00      1.00      1.00         7
#            4       1.00      1.00      1.00         6
#
#     accuracy                           1.00        38
#    macro avg       1.00      1.00      1.00        38
# weighted avg       1.00      1.00      1.00        38

# %%
classifier_svm_82 = svm.SVC(kernel='linear')
classifier_svm_82.fit(X_train_82,y_train_82)
y_pred_svm_82=classifier_svm_82.predict(X_train_82)
print("the accuracy of training data: ", accuracy_score(y_train_82,y_pred_svm_82))
y_pred_svm_test_82=classifier_svm_82.predict(X_test_82)
print("the accuracy of testing data:  ", accuracy_score(y_test_82,y_pred_svm_test_82))
SVM_Accuracy2.append(accuracy_score(y_test_82,y_pred_svm_test_82))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.8918918918918919

# %%
classifier_svm_2_8 = svm.SVC(kernel='linear')
classifier_svm_2_8.fit(X_train_2_8,y_train_2_8)
y_pred_svm_2_8=classifier_svm_2_8.predict(X_train_2_8)
print("the accuracy of training data: ", accuracy_score(y_train_2_8,y_pred_svm_2_8))
y_pred_svm_test_2_8=classifier_svm_2_8.predict(X_test_2_8)
print("the accuracy of testing data:  ", accuracy_score(y_test_2_8,y_pred_svm_test_2_8))
SVM_Accuracy3.append(accuracy_score(y_test_2_8,y_pred_svm_test_2_8))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.8108108108108109

# %% [markdown]
# # 1.2.9 nine volunteers

# %%
from sklearn import svm
classifier_svm_9_all = svm.SVC(kernel='linear')
classifier_svm_9_all.fit(X_train_9_all,y_train_9_all)
y_pred_svm_9_all=classifier_svm_9_all.predict(X_train_9_all)
print("the accuracy of training data: ", accuracy_score(y_train_9_all,y_pred_svm_9_all))
y_pred_svm_test_9_all=classifier_svm_9_all.predict(X_test_9_all)
print("the accuracy of testing data:  ", accuracy_score(y_test_9_all,y_pred_svm_test_9_all))
SVM_Accuracy.append(accuracy_score(y_test_9_all,y_pred_svm_test_9_all))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.9285714285714286

# %%
cm_svm_9_all = confusion_matrix(y_test_9_all, y_pred_svm_test_9_all, normalize='true')
class_names = ["No_person","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_svm_9_all, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for Support Vector Machines of nine volunteers at room lab1")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_svm_9_all = classification_report(y_test_9_all, y_pred_svm_test_9_all)
print("Classification report for Support Vector Machines of nine volunteers at room lab1:")
print(report_svm_9_all)
# Out:
# Classification report for Support Vector Machines of nine volunteers at room lab1:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       0.83      1.00      0.91        10
#            2       1.00      1.00      1.00        10
#            3       1.00      0.89      0.94         9
#            4       0.88      0.78      0.82         9
#
#     accuracy                           0.93        42
#    macro avg       0.94      0.93      0.93        42
# weighted avg       0.93      0.93      0.93        42

# %%
classifier_svm_92_all = svm.SVC(kernel='linear')
classifier_svm_92_all.fit(X_train_92_all,y_train_92_all)
y_pred_svm_92_all=classifier_svm_92_all.predict(X_train_92_all)
print("the accuracy of training data: ", accuracy_score(y_train_92_all,y_pred_svm_92_all))
y_pred_svm_test_92_all=classifier_svm_92_all.predict(X_test_92_all)
print("the accuracy of testing data:  ", accuracy_score(y_test_92_all,y_pred_svm_test_92_all))
SVM_Accuracy2.append(accuracy_score(y_test_92_all,y_pred_svm_test_92_all))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.9512195121951219

# %%
classifier_svm_2_9 = svm.SVC(kernel='linear')
classifier_svm_2_9.fit(X_train_2_9_all,y_train_2_9_all)
y_pred_svm_2_9=classifier_svm_2_9.predict(X_train_2_9_all)
print("the accuracy of training data: ", accuracy_score(y_train_2_9_all,y_pred_svm_2_9))
y_pred_svm_test_2_9=classifier_svm_2_9.predict(X_test_2_9_all)
print("the accuracy of testing data:  ", accuracy_score(y_test_2_9_all,y_pred_svm_test_2_9))
SVM_Accuracy3.append(accuracy_score(y_test_2_9_all,y_pred_svm_test_2_9))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.9285714285714286

# %% [markdown]
# # 1.3 K-Nearest Neighbors

# %% [markdown]
# # 1.3.1 one volunteer

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier_knn_1 = KNeighborsClassifier(n_neighbors=3,weights='distance',p=1)
classifier_knn_1.fit(X_train_1,y_train_1)
y_pred_knn_1=classifier_knn_1.predict(X_train_1)
print("the accuracy of training data: ", accuracy_score(y_train_1,y_pred_knn_1))
y_pred_knn_test_1=classifier_knn_1.predict(X_test_1)
print("the accuracy of testing data:  ", accuracy_score(y_test_1,y_pred_knn_test_1))
KNN_Accuracy.append(accuracy_score(y_test_1,y_pred_knn_test_1))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.6666666666666666

# %%
cm_knn_1 = confusion_matrix(y_test_1, y_pred_knn_test_1, normalize='true')
class_names = ["No_person","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_knn_1, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for K-Nearest Neighbors of one volunteer")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_knn_1 = classification_report(y_test_1, y_pred_knn_test_1)
print("Classification report for K-Nearest Neighbors of one volunteer:")
print(report_knn_1)
# Out:
# Classification report for K-Nearest Neighbors of one volunteer:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       0.00      0.00      0.00         0
#            2       1.00      1.00      1.00         1
#            3       1.00      0.50      0.67         2
#            4       1.00      0.33      0.50         3
#
#     accuracy                           0.67         9
#    macro avg       0.80      0.57      0.63         9
# weighted avg       1.00      0.67      0.76         9
# C:\Users\hanan\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
classifier_knn_12 = KNeighborsClassifier(n_neighbors=3,weights='distance',p=1)
classifier_knn_12.fit(X_train_12,y_train_12)
y_pred_knn_12=classifier_knn_12.predict(X_train_12)
print("the accuracy of training data: ", accuracy_score(y_train_12,y_pred_knn_12))
y_pred_knn_test_12=classifier_knn_12.predict(X_test_12)
print("the accuracy of testing data:  ", accuracy_score(y_test_12,y_pred_knn_test_12))
KNN_Accuracy2.append(accuracy_score(y_test_12,y_pred_knn_test_12))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.875

# %%
classifier_knn_2_1 = KNeighborsClassifier(n_neighbors=3,weights='distance',p=1)
classifier_knn_2_1.fit(X_train_2_1,y_train_2_1)
y_pred_knn_2_1=classifier_knn_2_1.predict(X_train_2_1)
print("the accuracy of training data: ", accuracy_score(y_train_2_1,y_pred_knn_2_1))
y_pred_knn_test_2_1=classifier_knn_2_1.predict(X_test_2_1)
print("the accuracy of testing data:  ", accuracy_score(y_test_2_1,y_pred_knn_test_2_1))
KNN_Accuracy3.append(accuracy_score(y_test_2_1,y_pred_knn_test_2_1))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   1.0

# %% [markdown]
# # 1.3.2 two volunteers

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier_knn_2 = KNeighborsClassifier(n_neighbors=3,weights='distance',p=1)
classifier_knn_2.fit(X_train_2,y_train_2)
y_pred_knn_2=classifier_knn_2.predict(X_train_2)
print("the accuracy of training data: ", accuracy_score(y_train_2,y_pred_knn_2))
y_pred_knn_test_2=classifier_knn_2.predict(X_test_2)
print("the accuracy of testing data:  ", accuracy_score(y_test_2,y_pred_knn_test_2))
KNN_Accuracy.append(accuracy_score(y_test_2,y_pred_knn_test_2))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.9230769230769231

# %%
cm_knn_2 = confusion_matrix(y_test_2, y_pred_knn_test_2, normalize='true')
class_names = ["No_person","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_knn_2, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for K-Nearest Neighbors of two volunteers")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_knn_2 = classification_report(y_test_2, y_pred_knn_test_2)
print("Classification report for K-Nearest Neighbors of two volunteers:")
print(report_knn_2)
# Out:
# Classification report for K-Nearest Neighbors of two volunteers:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       0.80      1.00      0.89         4
#            2       1.00      1.00      1.00         2
#            3       1.00      0.50      0.67         2
#            4       1.00      1.00      1.00         1
#
#     accuracy                           0.92        13
#    macro avg       0.96      0.90      0.91        13
# weighted avg       0.94      0.92      0.91        13

# %%
classifier_knn_22 = KNeighborsClassifier(n_neighbors=3,weights='distance',p=1)
classifier_knn_22.fit(X_train_22,y_train_22)
y_pred_knn_22=classifier_knn_22.predict(X_train_22)
print("the accuracy of training data: ", accuracy_score(y_train_22,y_pred_knn_22))
y_pred_knn_test_22=classifier_knn_22.predict(X_test_22)
print("the accuracy of testing data:  ", accuracy_score(y_test_22,y_pred_knn_test_22))
KNN_Accuracy2.append(accuracy_score(y_test_22,y_pred_knn_test_22))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   1.0

# %%
classifier_knn_2_2 = KNeighborsClassifier(n_neighbors=3,weights='distance',p=1)
classifier_knn_2_2.fit(X_train_2_2,y_train_2_2)
y_pred_knn_2_2=classifier_knn_2_2.predict(X_train_2_2)
print("the accuracy of training data: ", accuracy_score(y_train_2_2,y_pred_knn_2_2))
y_pred_knn_test_2_2=classifier_knn_2_2.predict(X_test_2_2)
print("the accuracy of testing data:  ", accuracy_score(y_test_2_2,y_pred_knn_test_2_2))
KNN_Accuracy3.append(accuracy_score(y_test_2_2,y_pred_knn_test_2_2))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.8

# %% [markdown]
# # 1.3.3 three volunteers

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier_knn_3 = KNeighborsClassifier(n_neighbors=3,weights='distance',p=1)
classifier_knn_3.fit(X_train_3,y_train_3)
y_pred_knn_3=classifier_knn_3.predict(X_train_3)
print("the accuracy of training data: ", accuracy_score(y_train_3,y_pred_knn_3))
y_pred_knn_test_3=classifier_knn_3.predict(X_test_3)
print("the accuracy of testing data:  ", accuracy_score(y_test_3,y_pred_knn_test_3))
KNN_Accuracy.append(accuracy_score(y_test_3,y_pred_knn_test_3))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.8235294117647058

# %%
cm_knn_3 = confusion_matrix(y_test_3, y_pred_knn_test_3, normalize='true')
class_names = ["No_person","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_knn_3, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for K-Nearest Neighbors of three volunteers")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_knn_3 = classification_report(y_test_3, y_pred_knn_test_3)
print("Classification report for K-Nearest Neighbors of three volunteers:")
print(report_knn_3)
# Out:
# Classification report for K-Nearest Neighbors of three volunteers:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         7
#            1       0.50      1.00      0.67         2
#            2       1.00      0.50      0.67         4
#            3       1.00      0.75      0.86         4
#            4       0.00      0.00      0.00         0
#
#     accuracy                           0.82        17
#    macro avg       0.70      0.65      0.64        17
# weighted avg       0.94      0.82      0.85        17
# C:\Users\hanan\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
classifier_knn_32 = KNeighborsClassifier(n_neighbors=3,weights='distance',p=1)
classifier_knn_32.fit(X_train_32,y_train_32)
y_pred_knn_32=classifier_knn_32.predict(X_train_32)
print("the accuracy of training data: ", accuracy_score(y_train_32,y_pred_knn_32))
y_pred_knn_test_32=classifier_knn_32.predict(X_test_32)
print("the accuracy of testing data:  ", accuracy_score(y_test_32,y_pred_knn_test_32))
KNN_Accuracy2.append(accuracy_score(y_test_32,y_pred_knn_test_32))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.9375

# %%
classifier_knn_2_3 = KNeighborsClassifier(n_neighbors=3,weights='distance',p=1)
classifier_knn_2_3.fit(X_train_2_3,y_train_2_3)
y_pred_knn_2_3=classifier_knn_2_3.predict(X_train_2_3)
print("the accuracy of training data: ", accuracy_score(y_train_2_3,y_pred_knn_2_3))
y_pred_knn_test_2_3=classifier_knn_2_3.predict(X_test_2_3)
print("the accuracy of testing data:  ", accuracy_score(y_test_2_3,y_pred_knn_test_2_3))
KNN_Accuracy3.append(accuracy_score(y_test_2_3,y_pred_knn_test_2_3))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.8787878787878788

# %% [markdown]
# # 1.3.4 four volunteers

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier_knn_4 = KNeighborsClassifier(n_neighbors=3,weights='distance',p=1)
classifier_knn_4.fit(X_train_4,y_train_4)
y_pred_knn_4=classifier_knn_4.predict(X_train_4)
print("the accuracy of training data: ", accuracy_score(y_train_4,y_pred_knn_4))
y_pred_knn_test_4=classifier_knn_4.predict(X_test_4)
print("the accuracy of testing data:  ", accuracy_score(y_test_4,y_pred_knn_test_4))
KNN_Accuracy.append(accuracy_score(y_test_4,y_pred_knn_test_4))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.6190476190476191

# %%
cm_knn_4 = confusion_matrix(y_test_4, y_pred_knn_test_4, normalize='true')
class_names = ["No_person","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_knn_4, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for K-Nearest Neighbors of four volunteers")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_knn_4 = classification_report(y_test_4, y_pred_knn_test_4)
print("Classification report for K-Nearest Neighbors of four volunteers:")
print(report_knn_4)
# Out:
# Classification report for K-Nearest Neighbors of four volunteers:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         3
#            1       0.43      1.00      0.60         3
#            2       1.00      0.57      0.73         7
#            3       1.00      0.40      0.57         5
#            4       0.20      0.33      0.25         3
#
#     accuracy                           0.62        21
#    macro avg       0.73      0.66      0.63        21
# weighted avg       0.80      0.62      0.64        21

# %%
classifier_knn_42 = KNeighborsClassifier(n_neighbors=3,weights='distance',p=1)
classifier_knn_42.fit(X_train_42,y_train_42)
y_pred_knn_42=classifier_knn_42.predict(X_train_42)
print("the accuracy of training data: ", accuracy_score(y_train_42,y_pred_knn_42))
y_pred_knn_test_42=classifier_knn_42.predict(X_test_42)
print("the accuracy of testing data:  ", accuracy_score(y_test_42,y_pred_knn_test_42))
KNN_Accuracy2.append(accuracy_score(y_test_42,y_pred_knn_test_42))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.7

# %%
classifier_knn_2_4 = KNeighborsClassifier(n_neighbors=3,weights='distance',p=1)
classifier_knn_2_4.fit(X_train_2_4,y_train_2_4)
y_pred_knn_2_4=classifier_knn_2_4.predict(X_train_2_4)
print("the accuracy of training data: ", accuracy_score(y_train_2_4,y_pred_knn_2_4))
y_pred_knn_test_2_4=classifier_knn_2_4.predict(X_test_2_4)
print("the accuracy of testing data:  ", accuracy_score(y_test_2_4,y_pred_knn_test_2_4))
KNN_Accuracy3.append(accuracy_score(y_test_2_4,y_pred_knn_test_2_4))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.8048780487804879

# %% [markdown]
# # 1.3.5 five volunteers

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier_knn_5 = KNeighborsClassifier(n_neighbors=3,weights='distance',p=1)
classifier_knn_5.fit(X_train_5,y_train_5)
y_pred_knn_5=classifier_knn_5.predict(X_train_5)
print("the accuracy of training data: ", accuracy_score(y_train_5,y_pred_knn_5))
y_pred_knn_test_5=classifier_knn_5.predict(X_test_5)
print("the accuracy of testing data:  ", accuracy_score(y_test_5,y_pred_knn_test_5))
KNN_Accuracy.append(accuracy_score(y_test_5,y_pred_knn_test_5))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.68

# %%
cm_knn_5 = confusion_matrix(y_test_5, y_pred_knn_test_5, normalize='true')
class_names = ["No_person","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_knn_5, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for K-Nearest Neighbors of five volunteers")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_knn_5 = classification_report(y_test_5, y_pred_knn_test_5)
print("Classification report for K-Nearest Neighbors of five volunteers:")
print(report_knn_5)
# Out:
# Classification report for K-Nearest Neighbors of five volunteers:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       0.57      1.00      0.73         4
#            2       1.00      0.60      0.75         5
#            3       1.00      0.38      0.55         8
#            4       0.50      0.83      0.62         6
#
#     accuracy                           0.68        25
#    macro avg       0.81      0.76      0.73        25
# weighted avg       0.81      0.68      0.67        25

# %%
classifier_knn_52 = KNeighborsClassifier(n_neighbors=3,weights='distance',p=1)
classifier_knn_52.fit(X_train_52,y_train_52)
y_pred_knn_52=classifier_knn_52.predict(X_train_52)
print("the accuracy of training data: ", accuracy_score(y_train_52,y_pred_knn_52))
y_pred_knn_test_52=classifier_knn_52.predict(X_test_52)
print("the accuracy of testing data:  ", accuracy_score(y_test_52,y_pred_knn_test_52))
KNN_Accuracy2.append(accuracy_score(y_test_52,y_pred_knn_test_52))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.9166666666666666

# %%
classifier_knn_2_5 = KNeighborsClassifier(n_neighbors=3,weights='distance',p=1)
classifier_knn_2_5.fit(X_train_2_5,y_train_2_5)
y_pred_knn_2_5=classifier_knn_2_5.predict(X_train_2_5)
print("the accuracy of training data: ", accuracy_score(y_train_2_5,y_pred_knn_2_5))
y_pred_knn_test_2_5=classifier_knn_2_5.predict(X_test_2_5)
print("the accuracy of testing data:  ", accuracy_score(y_test_2_5,y_pred_knn_test_2_5))
KNN_Accuracy3.append(accuracy_score(y_test_2_5,y_pred_knn_test_2_5))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.7755102040816326

# %% [markdown]
# # 1.3.6 six volunteers

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier_knn_6 = KNeighborsClassifier(n_neighbors=3,weights='distance',p=1)
classifier_knn_6.fit(X_train_6,y_train_6)
y_pred_knn_6=classifier_knn_6.predict(X_train_6)
print("the accuracy of training data: ", accuracy_score(y_train_6,y_pred_knn_6))
y_pred_knn_test_6=classifier_knn_6.predict(X_test_6)
print("the accuracy of testing data:  ", accuracy_score(y_test_6,y_pred_knn_test_6))
KNN_Accuracy.append(accuracy_score(y_test_6,y_pred_knn_test_6))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.7931034482758621

# %%
cm_knn_6 = confusion_matrix(y_test_6, y_pred_knn_test_6, normalize='true')
class_names = ["No_person","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_knn_6, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for K-Nearest Neighbors of six volunteers")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_knn_6 = classification_report(y_test_6, y_pred_knn_test_6)
print("Classification report for K-Nearest Neighbors of six volunteers:")
print(report_knn_6)
# Out:
# Classification report for K-Nearest Neighbors of six volunteers:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       0.62      1.00      0.77         5
#            2       1.00      0.71      0.83         7
#            3       1.00      0.50      0.67         6
#            4       0.62      0.83      0.71         6
#
#     accuracy                           0.79        29
#    macro avg       0.85      0.81      0.80        29
# weighted avg       0.86      0.79      0.79        29

# %%
classifier_knn_62 = KNeighborsClassifier(n_neighbors=3,weights='distance',p=1)
classifier_knn_62.fit(X_train_62,y_train_62)
y_pred_knn_62=classifier_knn_62.predict(X_train_62)
print("the accuracy of training data: ", accuracy_score(y_train_62,y_pred_knn_62))
y_pred_knn_test_62=classifier_knn_62.predict(X_test_62)
print("the accuracy of testing data:  ", accuracy_score(y_test_62,y_pred_knn_test_62))
KNN_Accuracy2.append(accuracy_score(y_test_62,y_pred_knn_test_62))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.8620689655172413

# %%
classifier_knn_2_6 = KNeighborsClassifier(n_neighbors=3,weights='distance',p=1)
classifier_knn_2_6.fit(X_train_2_6,y_train_2_6)
y_pred_knn_2_6=classifier_knn_2_6.predict(X_train_2_6)
print("the accuracy of training data: ", accuracy_score(y_train_2_6,y_pred_knn_2_6))
y_pred_knn_test_2_6=classifier_knn_2_6.predict(X_test_2_6)
print("the accuracy of testing data:  ", accuracy_score(y_test_2_6,y_pred_knn_test_2_6))
KNN_Accuracy3.append(accuracy_score(y_test_2_6,y_pred_knn_test_2_6))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.8103448275862069

# %% [markdown]
# # 1.3.7 seven volunteers

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier_knn_7 = KNeighborsClassifier(n_neighbors=3,weights='distance',p=1)
classifier_knn_7.fit(X_train_7,y_train_7)
y_pred_knn_7=classifier_knn_7.predict(X_train_7)
print("the accuracy of training data: ", accuracy_score(y_train_7,y_pred_knn_7))
y_pred_knn_test_7=classifier_knn_7.predict(X_test_7)
print("the accuracy of testing data:  ", accuracy_score(y_test_7,y_pred_knn_test_7))
KNN_Accuracy.append(accuracy_score(y_test_7,y_pred_knn_test_7))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.7575757575757576

# %%
cm_knn_7 = confusion_matrix(y_test_7, y_pred_knn_test_7, normalize='true')
class_names = ["No_person","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_knn_7, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for K-Nearest Neighbors of seven volunteers")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_knn_7 = classification_report(y_test_7, y_pred_knn_test_7)
print("Classification report for K-Nearest Neighbors of seven volunteers:")
print(report_knn_7)
# Out:
# Classification report for K-Nearest Neighbors of seven volunteers:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       0.50      0.80      0.62         5
#            2       1.00      0.38      0.55         8
#            3       0.86      0.86      0.86         7
#            4       0.67      0.86      0.75         7
#
#     accuracy                           0.76        33
#    macro avg       0.80      0.78      0.75        33
# weighted avg       0.82      0.76      0.75        33

# %%
classifier_knn_72 = KNeighborsClassifier(n_neighbors=3,weights='distance',p=1)
classifier_knn_72.fit(X_train_72,y_train_72)
y_pred_knn_72=classifier_knn_72.predict(X_train_72)
print("the accuracy of training data: ", accuracy_score(y_train_72,y_pred_knn_72))
y_pred_knn_test_72=classifier_knn_72.predict(X_test_72)
print("the accuracy of testing data:  ", accuracy_score(y_test_72,y_pred_knn_test_72))
KNN_Accuracy2.append(accuracy_score(y_test_72,y_pred_knn_test_72))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.9696969696969697

# %%
classifier_knn_2_7 = KNeighborsClassifier(n_neighbors=3,weights='distance',p=1)
classifier_knn_2_7.fit(X_train_2_7,y_train_2_7)
y_pred_knn_2_7=classifier_knn_2_7.predict(X_train_2_7)
print("the accuracy of training data: ", accuracy_score(y_train_2_7,y_pred_knn_2_7))
y_pred_knn_test_2_7=classifier_knn_2_7.predict(X_test_2_7)
print("the accuracy of testing data:  ", accuracy_score(y_test_2_7,y_pred_knn_test_2_7))
KNN_Accuracy3.append(accuracy_score(y_test_2_7,y_pred_knn_test_2_7))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.8939393939393939

# %% [markdown]
# # 1.3.8 eight volunteers

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier_knn_8 = KNeighborsClassifier(n_neighbors=3,weights='distance',p=1)
classifier_knn_8.fit(X_train_8,y_train_8)
y_pred_knn_8=classifier_knn_8.predict(X_train_8)
print("the accuracy of training data: ", accuracy_score(y_train_8,y_pred_knn_8))
y_pred_knn_test_8=classifier_knn_8.predict(X_test_8)
print("the accuracy of testing data:  ", accuracy_score(y_test_8,y_pred_knn_test_8))
KNN_Accuracy.append(accuracy_score(y_test_8,y_pred_knn_test_8))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.7631578947368421

# %%
cm_knn_8 = confusion_matrix(y_test_8, y_pred_knn_test_8, normalize='true')
class_names = ["No_person","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_knn_8, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for K-Nearest Neighbors of eight volunteers")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_knn_8 = classification_report(y_test_8, y_pred_knn_test_8)
print("Classification report for K-Nearest Neighbors of eight volunteers:")
print(report_knn_8)
# Out:
# Classification report for K-Nearest Neighbors of eight volunteers:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       0.78      0.70      0.74        10
#            2       1.00      0.55      0.71        11
#            3       1.00      0.86      0.92         7
#            4       0.46      1.00      0.63         6
#
#     accuracy                           0.76        38
#    macro avg       0.85      0.82      0.80        38
# weighted avg       0.86      0.76      0.77        38

# %%
classifier_knn_82 = KNeighborsClassifier(n_neighbors=3,weights='distance',p=1)
classifier_knn_82.fit(X_train_82,y_train_82)
y_pred_knn_82=classifier_knn_82.predict(X_train_82)
print("the accuracy of training data: ", accuracy_score(y_train_82,y_pred_knn_82))
y_pred_knn_test_82=classifier_knn_82.predict(X_test_82)
print("the accuracy of testing data:  ", accuracy_score(y_test_82,y_pred_knn_test_82))
KNN_Accuracy2.append(accuracy_score(y_test_82,y_pred_knn_test_82))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.972972972972973

# %%
classifier_knn_2_8 = KNeighborsClassifier(n_neighbors=3,weights='distance',p=1)
classifier_knn_2_8.fit(X_train_2_8,y_train_2_8)
y_pred_knn_2_8=classifier_knn_2_8.predict(X_train_2_8)
print("the accuracy of training data: ", accuracy_score(y_train_2_8,y_pred_knn_2_8))
y_pred_knn_test_2_8=classifier_knn_2_8.predict(X_test_2_8)
print("the accuracy of testing data:  ", accuracy_score(y_test_2_8,y_pred_knn_test_2_8))
KNN_Accuracy3.append(accuracy_score(y_test_2_8,y_pred_knn_test_2_8))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.8918918918918919

# %% [markdown]
# # 1.3.9 nine volunteers

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier_knn_9_all = KNeighborsClassifier(n_neighbors=3,weights='distance',p=1)
classifier_knn_9_all.fit(X_train_9_all,y_train_9_all)
y_pred_knn_9_all=classifier_knn_9_all.predict(X_train_9_all)
print("the accuracy of training data: ", accuracy_score(y_train_9_all,y_pred_knn_9_all))
y_pred_knn_test_9_all=classifier_knn_9_all.predict(X_test_9_all)
print("the accuracy of testing data:  ", accuracy_score(y_test_9_all,y_pred_knn_test_9_all))
KNN_Accuracy.append(accuracy_score(y_test_9_all,y_pred_knn_test_9_all))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.7619047619047619

# %%
cm_knn_9_all = confusion_matrix(y_test_9_all, y_pred_knn_test_9_all, normalize='true')
class_names = ["No_person","Down","Left","Right", "Up"]

# Plot confusion matrix as heatmap

sns.heatmap(cm_knn_9_all, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1,xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix for K-Nearest Neighbors of nine volunteers at room lab1")
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %%
report_knn_9_all = classification_report(y_test_9_all, y_pred_knn_test_9_all)
print("Classification report for K-Nearest Neighbors of nine volunteers at room lab1:")
print(report_knn_9_all)
# Out:
# Classification report for K-Nearest Neighbors of nine volunteers at room lab1:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       0.64      0.90      0.75        10
#            2       1.00      0.70      0.82        10
#            3       1.00      0.78      0.88         9
#            4       0.50      0.56      0.53         9
#
#     accuracy                           0.76        42
#    macro avg       0.83      0.79      0.79        42
# weighted avg       0.81      0.76      0.77        42

# %%
classifier_knn_92_all = KNeighborsClassifier(n_neighbors=3,weights='distance',p=1)
classifier_knn_92_all.fit(X_train_92_all,y_train_92_all)
y_pred_knn_92_all=classifier_knn_92_all.predict(X_train_92_all)
print("the accuracy of training data: ", accuracy_score(y_train_92_all,y_pred_knn_92_all))
y_pred_knn_test_92_all=classifier_knn_92_all.predict(X_test_92_all)
print("the accuracy of testing data:  ", accuracy_score(y_test_92_all,y_pred_knn_test_92_all))
KNN_Accuracy2.append(accuracy_score(y_test_92_all,y_pred_knn_test_92_all))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.9024390243902439

# %%
classifier_knn_2_9 = KNeighborsClassifier(n_neighbors=3,weights='distance',p=1)
classifier_knn_2_9.fit(X_train_2_9_all,y_train_2_9_all)
y_pred_knn_2_9=classifier_knn_2_9.predict(X_train_2_9_all)
print("the accuracy of training data: ", accuracy_score(y_train_2_9_all,y_pred_knn_2_9))
y_pred_knn_test_2_9=classifier_knn_2_9.predict(X_test_2_9_all)
print("the accuracy of testing data:  ", accuracy_score(y_test_2_9_all,y_pred_knn_test_2_9))
KNN_Accuracy3.append(accuracy_score(y_test_2_9_all,y_pred_knn_test_2_9))
# Out:
# the accuracy of training data:  1.0
# the accuracy of testing data:   0.7619047619047619

# %% [markdown]
# # Comparing between the accuracy and different number of volunteers

# %%
indices=[1,2,3,4,5,6,7,8,9]
Rf_accuracy=pd.DataFrame(data=RF_Accuracy[0:],
                index=indices,
                columns=['RF'])

SVM_accuracy=pd.DataFrame(data=SVM_Accuracy[0:],
                index=indices,
                columns=['SVM'])

KNN_accuracy=pd.DataFrame(data=KNN_Accuracy[0:],
                index=indices,
                columns=['KNN'])

# %%
indices=[1,2,3,4,5,6,7,8,9]
Rf_accuracy2=pd.DataFrame(data=RF_Accuracy2[0:],
                index=indices,
                columns=['RF'])

SVM_accuracy2=pd.DataFrame(data=SVM_Accuracy2[0:],
                index=indices,
                columns=['SVM'])

KNN_accuracy2=pd.DataFrame(data=KNN_Accuracy2[0:],
                index=indices,
                columns=['KNN'])

# %%
indices=[1,2,3,4,5,6,7,8,9]
Rf_accuracy3=pd.DataFrame(data=RF_Accuracy3[0:],
                index=indices,
                columns=['RF'])

SVM_accuracy3=pd.DataFrame(data=SVM_Accuracy3[0:],
                index=indices,
                columns=['SVM'])

KNN_accuracy3=pd.DataFrame(data=KNN_Accuracy3[0:],
                index=indices,
                columns=['KNN'])

# %%
df_accuracy = pd.concat([Rf_accuracy,SVM_accuracy,KNN_accuracy], axis=1)

# %%
df_accuracy2 = pd.concat([Rf_accuracy2,SVM_accuracy2,KNN_accuracy2], axis=1)

# %%
df_accuracy3 = pd.concat([Rf_accuracy3,SVM_accuracy3,KNN_accuracy3], axis=1)

# %%
df_accuracy
# Out:
#          RF       SVM       KNN
# 1  0.666667  0.777778  0.666667
# 2  0.923077  0.923077  0.923077
# 3  0.764706  0.882353  0.823529
# 4  0.809524  0.761905  0.619048
# 5  0.760000  0.880000  0.680000
# 6  0.862069  0.896552  0.793103
# 7  0.727273  0.878788  0.757576
# 8  0.815789  1.000000  0.763158
# 9  0.809524  0.928571  0.761905

# %%
df_accuracy2
# Out:
#          RF       SVM       KNN
# 1  0.750000  0.875000  0.875000
# 2  0.833333  0.916667  1.000000
# 3  1.000000  1.000000  0.937500
# 4  0.800000  0.950000  0.700000
# 5  0.958333  0.833333  0.916667
# 6  0.862069  0.793103  0.862069
# 7  0.909091  0.909091  0.969697
# 8  0.864865  0.891892  0.972973
# 9  0.926829  0.951220  0.902439

# %%
df_accuracy3
# Out:
#          RF       SVM       KNN
# 1  0.941176  1.000000  1.000000
# 2  0.600000  0.680000  0.800000
# 3  0.848485  0.727273  0.878788
# 4  0.658537  0.731707  0.804878
# 5  0.734694  0.673469  0.775510
# 6  0.827586  0.810345  0.810345
# 7  0.772727  0.818182  0.893939
# 8  0.797297  0.810811  0.891892
# 9  0.833333  0.928571  0.761905

# %%
df_accuracy.to_csv(r'human_walking_direction_df_accuracy_421&422_amplitudes_80%_v2_increasing_number_volunteers_room1.csv')

# %%
df_accuracy2.to_csv(r'human_walking_direction_df_accuracy_421&422_amplitudes_80%_v2_increasing_number_volunteers_room2.csv')

# %%
df_accuracy3.to_csv(r'human_walking_direction_df_accuracy_421&422_amplitudes_80%_v2_increasing_number_volunteers_room1&room2.csv')

# %%
plt.plot(df_accuracy['RF'], label='Random Forest')
plt.plot(df_accuracy['SVM'], label='SVM')
plt.plot(df_accuracy['KNN'], label='KNN')

plt.title("Accuracy with different number of volunteers and classifiers at room lab1")
plt.xlabel("Number of volunteers")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
plt.plot(df_accuracy2['RF'], label='Random Forest')
plt.plot(df_accuracy2['SVM'], label='SVM')
plt.plot(df_accuracy2['KNN'], label='KNN')

plt.title("Accuracy with different number of volunteers and classifiers at room lab2")
plt.xlabel("Number of volunteers")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
plt.plot(df_accuracy3['RF'], label='Random Forest')
plt.plot(df_accuracy3['SVM'], label='SVM')
plt.plot(df_accuracy3['KNN'], label='KNN')

plt.title("Accuracy with different number of volunteers and classifiers at room lab1 & room lab2")
plt.xlabel("Number of volunteers")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
