# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#using 2 antennas
dataset1 = pd.read_csv('human_walking_direction_amir_421.csv').drop('Unnamed: 0',axis=1)
dataset2 = pd.read_csv('human_walking_direction_irina_421.csv').drop('Unnamed: 0',axis=1)
dataset3 = pd.read_csv('human_walking_direction_mohamed_421.csv').drop('Unnamed: 0',axis=1)
dataset4 = pd.read_csv('human_walking_direction_alaa_421.csv').drop('Unnamed: 0',axis=1)
dataset5 = pd.read_csv('human_walking_direction_abdelrahman_421.csv').drop('Unnamed: 0',axis=1)
dataset6 = pd.read_csv('human_walking_direction_elbatanony_421.csv').drop('Unnamed: 0',axis=1)
dataset7 = pd.read_csv('human_walking_direction_fahima_421.csv').drop('Unnamed: 0',axis=1)
dataset8 = pd.read_csv('human_walking_direction_belal_421.csv').drop('Unnamed: 0',axis=1)
dataset9 = pd.read_csv('human_walking_direction_odilbek_421.csv').drop('Unnamed: 0',axis=1)

# %%
dataset1.head()
# Out:
#    amplitude antenna1_1:0  amplitude antenna1_1:1  amplitude antenna1_1:2  \
# 0              118.821378              112.822911              106.837022
# 1              148.483371              144.639285              148.567575
# 2              109.886172              145.986950              138.764032
# 3              155.667170              154.183109              153.547271
# 4              150.309929              119.433062              112.872474
#
#    amplitude antenna1_1:3  amplitude antenna1_1:4  amplitude antenna1_1:5  \
# 0              109.709404              124.425956              129.814456
# 1              149.388417              147.388802              146.997656
# 2              136.643491              135.532147              132.000261
# 3              153.346520              154.359047              153.636943
# 4              108.606127              108.489992              116.570441
#
#    amplitude antenna1_1:6  amplitude antenna1_1:7  amplitude antenna1_1:8  \
# 0              126.797810              119.930096              117.196770
# 1              148.275791              146.360987              142.007667
# 2              130.647803              129.475652              128.704237
# 3              150.047910              150.574210              154.526000
# 4              118.229584              114.287015              112.234404
#
#    amplitude antenna1_1:9  ...  amplitude antenna2_2:391  \
# 0              114.168474  ...                260.982187
# 1              140.340542  ...                303.175812
# 2              129.522509  ...                257.770177
# 3              154.037910  ...                261.582014
# 4              115.601707  ...                237.623183
#
#    amplitude antenna2_2:392  amplitude antenna2_2:393  \
# 0                248.405897                271.785227
# 1                306.907971                252.539859
# 2                261.624711                225.476551
# 3                208.216395                217.126015
# 4                245.841104                240.516457
#
#    amplitude antenna2_2:394  amplitude antenna2_2:395  \
# 0                216.380495                270.216582
# 1                237.521352                231.228450
# 2                240.387051                246.959182
# 3                261.569895                276.736132
# 4                265.369686                218.832746
#
#    amplitude antenna2_2:396  amplitude antenna2_2:397  \
# 0                247.522049                241.290118
# 1                329.046828                234.711023
# 2                236.618733                251.806461
# 3                260.463912                252.665487
# 4                242.325116                250.150103
#
#    amplitude antenna2_2:398  amplitude antenna2_2:399           label
# 0                248.066975                248.092250  left_direction
# 1                222.658874                202.857197  left_direction
# 2                222.935550                240.722710  left_direction
# 3                251.993815                251.069136  left_direction
# 4                234.971160                248.541567  left_direction
#
# [5 rows x 1601 columns]

# %%
#using 2 antennas
dataset12 = pd.read_csv('human_walking_direction_amir_422.csv').drop('Unnamed: 0',axis=1)
dataset22 = pd.read_csv('human_walking_direction_irina_422.csv').drop('Unnamed: 0',axis=1)
dataset32 = pd.read_csv('human_walking_direction_mohamed_422.csv').drop('Unnamed: 0',axis=1)
dataset42 = pd.read_csv('human_walking_direction_alaa_422.csv').drop('Unnamed: 0',axis=1)
dataset52 = pd.read_csv('human_walking_direction_abdelrahman_422.csv').drop('Unnamed: 0',axis=1)
dataset62 = pd.read_csv('human_walking_direction_elbatanony_422.csv').drop('Unnamed: 0',axis=1)
dataset72 = pd.read_csv('human_walking_direction_fahima_422.csv').drop('Unnamed: 0',axis=1)
dataset82 = pd.read_csv('human_walking_direction_belal_422.csv').drop('Unnamed: 0',axis=1)
dataset92 = pd.read_csv('human_walking_direction_odilbek_422.csv').drop('Unnamed: 0',axis=1)

# %%
dataset1.shape,dataset2.shape,dataset3.shape,dataset4.shape,dataset5.shape,dataset6.shape,dataset7.shape,dataset8.shape,dataset9.shape
# Out:
# ((42, 1601),
#  (40, 1601),
#  (40, 1601),
#  (40, 1601),
#  (40, 1601),
#  (42, 1601),
#  (41, 1601),
#  (41, 1601),
#  (40, 1601))

# %%
dataset12.shape,dataset22.shape,dataset32.shape,dataset42.shape,dataset52.shape,dataset62.shape,dataset72.shape,dataset82.shape,dataset92.shape
# Out:
# ((40, 1601),
#  (40, 1601),
#  (40, 1601),
#  (40, 1601),
#  (40, 1601),
#  (42, 1601),
#  (40, 1601),
#  (40, 1601),
#  (40, 1601))

# %%
datasets1=[]
datasets1.append(dataset1)
datasets1.append(dataset2)
datasets1.append(dataset3)
datasets1.append(dataset4)
datasets1.append(dataset5)
datasets1.append(dataset6)
datasets1.append(dataset7)
datasets1.append(dataset8)
datasets1.append(dataset9)

# %%
datasets2=[]
datasets2.append(dataset12)
datasets2.append(dataset22)
datasets2.append(dataset32)
datasets2.append(dataset42)
datasets2.append(dataset52)
datasets2.append(dataset62)
datasets2.append(dataset72)
datasets2.append(dataset82)
datasets2.append(dataset92)

# %%
label = 'No_person'
for i in range(len(datasets1)):
    selected_rows_no_person1 = datasets1[i].loc[datasets1[i]['label'] == label]
    if i==0:
        selected_rows_no_person1.to_csv(f"No_person_data_421_amplitudes.csv", index=False)
    datasets1[i] = datasets1[i].drop(selected_rows_no_person1.index)
    print(datasets1[i].shape)
# Out:
# (22, 1601)
# (20, 1601)
# (20, 1601)
# (20, 1601)
# (20, 1601)
# (22, 1601)
# (21, 1601)
# (21, 1601)
# (20, 1601)

# %%
label = 'No_person'
for i in range(len(datasets2)):
    selected_rows_no_person2 = datasets2[i].loc[datasets2[i]['label'] == label]
    if i==0:
        selected_rows_no_person2.to_csv(f"No_person_data_422_amplitudes.csv", index=False)
    datasets2[i] = datasets2[i].drop(selected_rows_no_person2.index)
    print(datasets2[i].shape)
# Out:
# (20, 1601)
# (20, 1601)
# (20, 1601)
# (20, 1601)
# (20, 1601)
# (22, 1601)
# (20, 1601)
# (20, 1601)
# (20, 1601)

# %%
selected_rows_no_person1
# Out:
#     amplitude antenna1_1:0  amplitude antenna1_1:1  amplitude antenna1_1:2  \
# 20              169.807449              167.697563              163.167068
# 21              156.608358              167.925743              144.281351
# 22              153.845851              153.956437              159.831766
# 23              159.048246              155.892607              155.093766
# 24              148.583782              181.044455              154.058066
# 25              164.549052              144.257100              154.765438
# 26              131.714200              135.445130              139.074644
# 27              125.306956              124.276932              121.198427
# 28              121.369769              121.943878              127.655757
# 29              120.095463              120.817488              120.507466
# 30              127.995375              120.635038              125.563837
# 31              106.700950              109.835588              123.927446
# 32              126.353318              126.980540              128.439486
# 33              131.347634              124.362446              125.209176
# 34              117.208199              118.989827              118.552303
# 35              119.822745              115.848086              107.103210
# 36              130.822551              130.467753              131.474847
# 37              129.830570              145.995953              122.149555
# 38              108.180462              111.231152              122.680022
# 39              124.585471              126.516226              124.650383
#
#     amplitude antenna1_1:3  amplitude antenna1_1:4  amplitude antenna1_1:5  \
#
#
#     amplitude antenna2_2:398  amplitude antenna2_2:399      label
# 0                  28.868929                 29.857102  No_person
# 1                  29.315265                 28.846728  No_person
# 2                  25.114625                 26.401354  No_person
# 3                  30.952147                 26.086503  No_person
# 4                  29.125622                 28.171754  No_person
# 5                  24.796990                 26.253893  No_person
# 6                  20.814814                 25.769272  No_person
# 7                  28.238163                 32.899204  No_person
# 8                  34.099515                 35.318307  No_person
# 9                  22.889538                 21.785285  No_person
# 10                 55.157916                 51.408625  No_person
# 11                 30.686785                 27.982477  No_person
# 12                 21.581352                 21.252498  No_person
# 13                 27.197165                 31.521308  No_person
# 14                 26.083331                 22.561077  No_person
# 15                 26.809068                 29.034294  No_person
# 16                 18.167685                 20.565953  No_person
# 17                 47.224459                 15.388519  No_person
# 18                 27.640162                 26.416127  No_person
# 19                 43.046831                 46.573865  No_person
#
# [20 rows x 1601 columns]

# %%
df_1 = pd.concat([datasets1[0],no_activity1], axis=0)
df_2 = pd.concat([datasets1[0],datasets1[1],no_activity1], axis=0)
df_3 = pd.concat([datasets1[0],datasets1[1],datasets1[2],no_activity1], axis=0)
df_4 = pd.concat([datasets1[0],datasets1[1],datasets1[2],datasets1[3],no_activity1], axis=0)
df_5 = pd.concat([datasets1[0],datasets1[1],datasets1[2],datasets1[3],datasets1[4],no_activity1], axis=0)
df_6 = pd.concat([datasets1[0],datasets1[1],datasets1[2],datasets1[3],datasets1[4],datasets1[5],no_activity1], axis=0)
df_7 = pd.concat([datasets1[0],datasets1[1],datasets1[2],datasets1[3],datasets1[4],datasets1[5],datasets1[6],no_activity1], axis=0)
df_8 = pd.concat([datasets1[0],datasets1[1],datasets1[2],datasets1[3],datasets1[4],datasets1[5],datasets1[6],datasets1[7],no_activity1], axis=0)
df_9_all1 = pd.concat([datasets1[0],datasets1[1],datasets1[2],datasets1[3],datasets1[4],datasets1[5],datasets1[6],datasets1[7],datasets1[8],no_activity1], axis=0)

# %%
df_12 = pd.concat([datasets2[0],no_activity2], axis=0)
df_22 = pd.concat([datasets2[0],datasets2[1],no_activity2], axis=0)
df_32 = pd.concat([datasets2[0],datasets2[1],datasets2[2],no_activity2], axis=0)
df_42 = pd.concat([datasets2[0],datasets2[1],datasets2[2],datasets2[3],no_activity2], axis=0)
df_52 = pd.concat([datasets2[0],datasets2[1],datasets2[2],datasets2[3],datasets2[4],no_activity2], axis=0)
df_62 = pd.concat([datasets2[0],datasets2[1],datasets2[2],datasets2[3],datasets2[4],datasets2[5],no_activity2], axis=0)
df_72 = pd.concat([datasets2[0],datasets2[1],datasets2[2],datasets2[3],datasets2[4],datasets2[5],datasets2[6],no_activity2], axis=0)
df_82 = pd.concat([datasets2[0],datasets2[1],datasets2[2],datasets2[3],datasets2[4],datasets2[5],datasets2[6],datasets2[7],no_activity2], axis=0)
df_9_all2 = pd.concat([datasets2[0],datasets2[1],datasets2[2],datasets2[3],datasets2[4],datasets2[5],datasets2[6],datasets2[7],datasets2[8],no_activity2], axis=0)

# %%
df_9_all = pd.concat([df_9_all1,df_9_all2], axis=0)

# %%
df_9_all1.to_csv(r'df_9_all_users_421_amplitudes.csv')

# %%
df_9_all2.to_csv(r'df_9_all_users_422_amplitudes.csv')

# %%
df_9_all.to_csv(r'df_9_all_users_421&422_amplitudes.csv')

# %%
#using 2 antennas
dataset1 = pd.read_csv('df_9_all_users_421_amplitudes.csv').drop('Unnamed: 0',axis=1)
dataset1
# Out:
#      amplitude antenna1_1:0  amplitude antenna1_1:1  amplitude antenna1_1:2  \
# 0                118.821378              112.822911              106.837022
# 1                148.483371              144.639285              148.567575
# 2                109.886172              145.986950              138.764032
# 3                155.667170              154.183109              153.547271
# 4                150.309929              119.433062              112.872474
# ..                      ...                     ...                     ...
# 201              119.822745              115.848086              107.103210
# 202              130.822551              130.467753              131.474847
# 203              129.830570              145.995953              122.149555
# 204              108.180462              111.231152              122.680022
# 205              124.585471              126.516226              124.650383
#
#      amplitude antenna1_1:3  amplitude antenna1_1:4  amplitude antenna1_1:5  \
# 0                109.709404              124.425956              129.814456
# 1                149.388417              147.388802              146.997656
# 2                136.643491              135.532147              132.000261
# 3                153.346520              154.359047              153.636943
# 4                108.606127              108.489992              116.570441
# ..                      ...                     ...                     ...
# 201              114.114483              122.588401              143.257543
# 202              130.660140              121.165138              126.764349
# 203              104.717766              124.318335              124.755619
# 204              126.003870              119.249934              115.904951
# 205              132.167936              129.719064              129.014249
#
#      amplitude antenna1_1:6  amplitude antenna1_1:7  amplitude antenna1_1:8  \
# 0                126.797810              119.930096              117.196770
# 1                148.275791              146.360987              142.007667
# 2                130.647803              129.475652              128.704237
# 3                150.047910              150.574210              154.526000
# 4                118.229584              114.287015              112.234404
# ..                      ...                     ...                     ...
# 201              107.270344              104.065145              105.983889
# 202              121.598982              129.358944              110.458527
# 203              117.504266              127.015677              134.890825
# 204              115.122357              115.881879              116.787715
# 205              129.452649              127.351632              123.480417
#
#      amplitude antenna1_1:9  ...  amplitude antenna2_2:391  \
# 0                114.168474  ...                260.982187
# 1                140.340542  ...                303.175812
# 2                129.522509  ...                257.770177
# 3                154.037910  ...                261.582014
# 4                115.601707  ...                237.623183
# ..                      ...  ...                       ...
# 201              113.021336  ...                112.501904
# 202              132.946514  ...                108.030693
# 203              108.816994  ...                117.731205
# 204              117.548732  ...                117.329073
# 205              120.674202  ...                105.167511
#
#      amplitude antenna2_2:392  amplitude antenna2_2:393  \
# 0                  248.405897                271.785227
# 1                  306.907971                252.539859
# 2                  261.624711                225.476551
# 3                  208.216395                217.126015
# 4                  245.841104                240.516457
# ..                        ...                       ...
# 201                110.589557                112.647937
# 202                106.760828                107.759985
# 203                117.456355                116.056066
# 204                112.384063                106.980809
# 205                104.506254                104.874542
#
#      amplitude antenna2_2:394  amplitude antenna2_2:395  \
# 0                  216.380495                270.216582
# 1                  237.521352                231.228450
# 2                  240.387051                246.959182
# 3                  261.569895                276.736132
# 4                  265.369686                218.832746
# ..                        ...                       ...
# 201                 80.604189                129.192685
# 202                108.423449                112.660554
# 203                113.502140                107.595113
# 204                103.728076                101.175683
# 205                106.313186                110.318858
#
#      amplitude antenna2_2:396  amplitude antenna2_2:397  \
# 0                  247.522049                241.290118
# 1                  329.046828                234.711023
# 2                  236.618733                251.806461
# 3                  260.463912                252.665487
# 4                  242.325116                250.150103
# ..                        ...                       ...
# 201                134.858990                132.710053
# 202                 95.293538                124.517142
# 203                 93.713686                 91.400018
# 204                 99.934748                 99.588092
# 205                116.971156                122.297004
#
#      amplitude antenna2_2:398  amplitude antenna2_2:399           label
# 0                  248.066975                248.092250  left_direction
# 1                  222.658874                202.857197  left_direction
# 2                  222.935550                240.722710  left_direction
# 3                  251.993815                251.069136  left_direction
# 4                  234.971160                248.541567  left_direction
# ..                        ...                       ...             ...
# 201                 91.606057                154.398785       No_person
# 202                113.070225                109.403697       No_person
# 203                 77.215401                 93.611409       No_person
# 204                 97.760210                102.077648       No_person
# 205                125.926902                127.297005       No_person
#
# [206 rows x 1601 columns]

# %%
#using 2 antennas
dataset2 = pd.read_csv('df_9_all_users_422_amplitudes.csv').drop('Unnamed: 0',axis=1)
dataset2
# Out:
#      amplitude antenna1_1:0  amplitude antenna1_1:1  amplitude antenna1_1:2  \
# 0                255.408448              256.845062              238.869712
# 1                246.146937              244.973766              220.851457
# 2                231.136582              232.687284              235.453669
# 3                242.896318              233.410750              230.610184
# 4                247.620151              250.812291              242.338649
# ..                      ...                     ...                     ...
# 197              110.336113              129.431256              115.405279
# 198              113.620494              112.924386              112.890615
# 199              119.174574              120.724285               97.623426
# 200              107.880961               92.716946               90.803476
# 201              101.579223              103.215816              109.695713
#
#      amplitude antenna1_1:3  amplitude antenna1_1:4  amplitude antenna1_1:5  \
# 0                245.692967              248.616090              235.114531
# 1                216.538726              235.143090              244.435189
# 2                235.834520              221.107084              216.739403
# 3                233.457734              234.620198              248.138665
# 4                241.080150              244.163769              246.027683
# ..                      ...                     ...                     ...
# 197              110.728790              113.759130              114.104332
# 198              114.321272              119.961851              119.140606
# 199              127.535314              115.775696               98.944364
# 200              118.136064              102.561845               98.428585
# 201              107.712787               95.803784               96.938774
#
#      amplitude antenna1_1:6  amplitude antenna1_1:7  amplitude antenna1_1:8  \
# 0                253.614301              230.071366              233.833652
# 1                250.616794              244.497788              243.929262
# 2                239.408848              244.231174              243.633197
# 3                210.291412              264.944862              238.630337
# 4                246.353721              249.347121              249.227465
# ..                      ...                     ...                     ...
# 197              114.826326              116.985119              121.431964
# 198              121.046536              118.480435              122.449916
# 199              115.820071              107.088093              111.741011
# 200              107.427184              100.333119              104.324007
# 201              103.591434              134.859966              112.224224
#
#      amplitude antenna1_1:9  ...  amplitude antenna2_2:391  \
# 0                241.812226  ...                 79.073040
# 1                240.269599  ...                 26.056692
# 2                225.027699  ...                 26.951550
# 3                231.731246  ...                 38.844831
# 4                256.503926  ...                 35.450876
# ..                      ...  ...                       ...
# 197              123.288307  ...                 16.388363
# 198              107.269632  ...                 33.458494
# 199               98.031489  ...                 27.113029
# 200              105.833784  ...                 25.614224
# 201              103.897964  ...                 56.368953
#
#      amplitude antenna2_2:392  amplitude antenna2_2:393  \
# 0                   50.923193                 42.422509
# 1                   42.065915                 43.786773
# 2                   32.573049                 34.198438
# 3                   39.089935                 36.110127
# 4                   46.509854                 19.797308
# ..                        ...                       ...
# 197                 30.326240                 20.580986
# 198                 22.036272                 34.774322
# 199                 34.153478                 39.734207
# 200                 15.191254                 16.556746
# 201                 40.948511                 38.701788
#
#      amplitude antenna2_2:394  amplitude antenna2_2:395  \
# 0                   68.749601                 46.563997
# 1                   43.592459                 33.628190
# 2                   35.972309                 33.540087
# 3                   34.721301                 29.489745
# 4                   16.504525                 26.095412
# ..                        ...                       ...
# 197                 27.110424                 30.024164
# 198                 21.828746                 17.895070
# 199                 41.965758                 41.864011
# 200                 30.471688                 37.538552
# 201                 47.156254                 46.092144
#
#      amplitude antenna2_2:396  amplitude antenna2_2:397  \
# 0                   44.263693                 42.225703
# 1                   38.524684                 39.307416
# 2                   32.491019                 37.299232
# 3                   42.512271                 15.093741
# 4                   52.656013                 60.149618
# ..                        ...                       ...
# 197                 21.714571                 30.680311
# 198                 20.594100                 20.295000
# 199                 27.617822                 33.061787
# 200                 30.111146                 35.743305
# 201                 39.091108                 38.495307
#
#      amplitude antenna2_2:398  amplitude antenna2_2:399           label
# 0                   45.072881                 41.867235  left_direction
# 1                   37.372163                 36.743526  left_direction
# 2                   34.946902                 34.618806  left_direction
# 3                   22.296752                 25.674929  left_direction
# 4                   13.570666                 34.639400  left_direction
# ..                        ...                       ...             ...
# 197                 26.809068                 29.034294       No_person
# 198                 18.167685                 20.565953       No_person
# 199                 47.224459                 15.388519       No_person
# 200                 27.640162                 26.416127       No_person
# 201                 43.046831                 46.573865       No_person
#
# [202 rows x 1601 columns]

# %% [markdown]
# # Train the dataset

# %%
#Data encoding: to convert categorical features to numberical
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# %%
dataset1['label']=label_encoder.fit_transform(dataset1['label'])
dataset1
# Out:
#      amplitude antenna1_1:0  amplitude antenna1_1:1  amplitude antenna1_1:2  \
# 0                118.821378              112.822911              106.837022
# 1                148.483371              144.639285              148.567575
# 2                109.886172              145.986950              138.764032
# 3                155.667170              154.183109              153.547271
# 4                150.309929              119.433062              112.872474
# ..                      ...                     ...                     ...
# 201              119.822745              115.848086              107.103210
# 202              130.822551              130.467753              131.474847
# 203              129.830570              145.995953              122.149555
# 204              108.180462              111.231152              122.680022
# 205              124.585471              126.516226              124.650383
#
#      amplitude antenna1_1:3  amplitude antenna1_1:4  amplitude antenna1_1:5  \
# 0
#
#      amplitude antenna1_1:3  amplitude antenna1_1:4  amplitude antenna1_1:5  \
# 0                245.692967              248.616090              235.114531
# 1                216.538726              235.143090              244.435189
# 2                235.834520              221.107084              216.739403
# 3                233.457734              234.620198              248.138665
# 4                241.080150              244.163769              246.027683
# ..                      ...                     ...                     ...
# 197              110.728790              113.759130              114.104332
# 198              114.321272              119.961851              119.140606
# 199              127.535314              115.775696               98.944364
# 200              118.136064              102.561845               98.428585
# 201              107.712787               95.803784               96.938774
#
#      amplitude antenna1_1:6  amplitude antenna1_1:7  amplitude antenna1_1:8  \
# 0                253.614301              230.071366              233.833652
# 1                250.616794              244.497788              243.929262
# 2                239.408848              244.231174              243.633197
# 3                210.291412              264.944862              238.630337
# 4                246.353721              249.347121              249.227465
# ..                      ...                     ...                     ...
# 197              114.826326              116.985119              121.431964
# 198              121.046536              118.480435              122.449916
# 199              115.820071              107.088093              111.741011
# 200              107.427184              100.333119              104.324007
# 201              103.591434              134.859966              112.224224
#
#      amplitude antenna1_1:9  ...  amplitude antenna2_2:391  \
# 0                241.812226  ...                 79.073040
# 1                240.269599  ...                 26.056692
# 2                225.027699  ...                 26.951550
# 3                231.731246  ...                 38.844831
# 4                256.503926  ...                 35.450876
# ..                      ...  ...                       ...
# 197              123.288307  ...                 16.388363
# 198              107.269632  ...                 33.458494
# 199               98.031489  ...                 27.113029
# 200              105.833784  ...                 25.614224
# 201              103.897964  ...                 56.368953
#
#      amplitude antenna2_2:392  amplitude antenna2_2:393  \
# 0                   50.923193                 42.422509
# 1                   42.065915                 43.786773
# 2                   32.573049                 34.198438
# 3                   39.089935                 36.110127
# 4                   46.509854                 19.797308
# ..                        ...                       ...
# 197                 30.326240                 20.580986
# 198                 22.036272                 34.774322
# 199                 34.153478                 39.734207
# 200                 15.191254                 16.556746
# 201                 40.948511                 38.701788
#
#      amplitude antenna2_2:394  amplitude antenna2_2:395  \
# 0                   68.749601                 46.563997
# 1                   43.592459                 33.628190
# 2                   35.972309                 33.540087
# 3                   34.721301                 29.489745
# 4                   16.504525                 26.095412
# ..                        ...                       ...
# 197                 27.110424                 30.024164
# 198                 21.828746                 17.895070
# 199                 41.965758                 41.864011
# 200                 30.471688                 37.538552
# 201                 47.156254                 46.092144
#
#      amplitude antenna2_2:396  amplitude antenna2_2:397  \
# 0                   44.263693                 42.225703
# 1                   38.524684                 39.307416
# 2                   32.491019                 37.299232
# 3                   42.512271                 15.093741
# 4                   52.656013                 60.149618
# ..                        ...                       ...
# 197                 21.714571                 30.680311
# 198                 20.594100                 20.295000
# 199                 27.617822                 33.061787
# 200                 30.111146                 35.743305
# 201                 39.091108                 38.495307
#
#      amplitude antenna2_2:398  amplitude antenna2_2:399  label
# 0                   45.072881                 41.867235      2
# 1                   37.372163                 36.743526      2
# 2                   34.946902                 34.618806      2
# 3                   22.296752                 25.674929      2
# 4                   13.570666                 34.639400      2
# ..                        ...                       ...    ...
# 197                 26.809068                 29.034294      0
# 198                 18.167685                 20.565953      0
# 199                 47.224459                 15.388519      0
# 200                 27.640162                 26.416127      0
# 201                 43.046831                 46.573865      0
#
# [202 rows x 1601 columns]

# %%
dataset = pd.read_csv('df_9_all_users_421&422_amplitudes.csv').drop('Unnamed: 0',axis=1)
dataset['label']=label_encoder.fit_transform(dataset['label'])
dataset
# Out:
#      amplitude antenna1_1:0  amplitude antenna1_1:1  amplitude antenna1_1:2  \
# 0                118.821378              112.822911              106.837022
# 1                148.483371              144.639285              148.567575
# 2                109.886172              145.986950              138.764032
# 3                155.667170              154.183109              153.547271
# 4                150.309929              119.433062              112.872474
# ..                      ...                     ...                     ...
# 403              110.336113              129.431256              115.405279
# 404              113.620494              112.924386              112.890615
# 405              119.174574              120.724285               97.623426
# 406              107.880961               92.716946               90.803476
# 407              101.579223              103.215816              109.695713
#
#      amplitude antenna1_1:3  amplitude antenna1_1:4  amplitude antenna1_1:5  \
# 0                109.709404              124.425956              129.814456
# 1                149.388417              147.388802              146.997656
# 2                136.643491              135.532147              132.000261
# 3                153.346520              154.359047              153.636943
# 4                108.606127              108.489992              116.570441
# ..                      ...                     ...                     ...
# 403              110.728790              113.759130              114.104332
# 404              114.321272              119.961851              119.140606
# 405              127.535314              115.775696               98.944364
# 406              118.136064              102.561845               98.428585
# 407              107.712787               95.803784               96.938774
#
#      amplitude antenna1_1:6  amplitude antenna1_1:7  amplitude antenna1_1:8  \
# 0                126.797810              119.930096              117.196770
# 1                148.275791              146.360987              142.007667
# 2                130.647803              129.475652              128.704237
# 3                150.047910              150.574210              154.526000
# 4                118.229584              114.287015              112.234404
# ..                      ...                     ...                     ...
# 403              114.826326              116.985119              121.431964
# 404              121.046536              118.480435              122.449916
# 405              115.820071              107.088093              111.741011
# 406              107.427184              100.333119              104.324007
# 407              103.591434              134.859966              112.224224
#
#      amplitude antenna1_1:9  ...  amplitude antenna2_2:391  \
# 0                114.168474  ...                260.982187
# 1                140.340542  ...                303.175812
# 2                129.522509  ...                257.770177
# 3                154.037910  ...                261.582014
# 4                115.601707  ...                237.623183
# ..                      ...  ...                       ...
# 403              123.288307  ...                 16.388363
# 404              107.269632  ...                 33.458494
# 405               98.031489  ...                 27.113029
# 406              105.833784  ...                 25.614224
# 407              103.897964  ...                 56.368953
#
#      amplitude antenna2_2:392  amplitude antenna2_2:393  \
# 0                  248.405897                271.785227
# 1                  306.907971                252.539859
# 2                  261.624711                225.476551
# 3                  208.216395                217.126015
# 4                  245.841104                240.516457
# ..                        ...                       ...
# 403                 30.326240                 20.580986
# 404                 22.036272                 34.774322
# 405                 34.153478                 39.734207
# 406                 15.191254                 16.556746
# 407                 40.948511                 38.701788
#
#      amplitude antenna2_2:394  amplitude antenna2_2:395  \
# 0                  216.380495                270.216582
# 1                  237.521352                231.228450
# 2                  240.387051                246.959182
# 3                  261.569895                276.736132
# 4                  265.369686                218.832746
# ..                        ...                       ...
# 403                 27.110424                 30.024164
# 404                 21.828746                 17.895070
# 405                 41.965758                 41.864011
# 406                 30.471688                 37.538552
# 407                 47.156254                 46.092144
#
#      amplitude antenna2_2:396  amplitude antenna2_2:397  \
# 0                  247.522049                241.290118
# 1                  329.046828                234.711023
# 2                  236.618733                251.806461
# 3                  260.463912                252.665487
# 4                  242.325116                250.150103
# ..                        ...                       ...
# 403                 21.714571                 30.680311
# 404                 20.594100                 20.295000
# 405                 27.617822                 33.061787
# 406                 30.111146                 35.743305
# 407                 39.091108                 38.495307
#
#      amplitude antenna2_2:398  amplitude antenna2_2:399  label
# 0                  248.066975                248.092250      2
# 1                  222.658874                202.857197      2
# 2                  222.935550                240.722710      2
# 3                  251.993815                251.069136      2
# 4                  234.971160                248.541567      2
# ..                        ...                       ...    ...
# 403                 26.809068                 29.034294      0
# 404                 18.167685                 20.565953      0
# 405                 47.224459                 15.388519      0
# 406                 27.640162                 26.416127      0
# 407                 43.046831                 46.573865      0
#
# [408 rows x 1601 columns]

# %%
y_1=dataset1['label']
X_1=dataset1.drop('label',axis=1)

# %%
y_2=dataset2['label']
X_2=dataset2.drop('label',axis=1)

# %%
y=dataset['label']
X=dataset.drop('label',axis=1)

# %%
#Trainset Splitting
from sklearn.model_selection import train_test_split
X_train_1, X_test_1, y_train_1, y_test_1= train_test_split(X_1, y_1, test_size=0.2,random_state=123)
X_train_2, X_test_2, y_train_2, y_test_2= train_test_split(X_2, y_2, test_size=0.2,random_state=123)
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.2,random_state=123)

# %%
X_train.shape,X_train_1.shape,X_train_2.shape
# Out:
# ((326, 1600), (164, 1600), (161, 1600))

# %%
X_test.shape,X_test_1.shape,X_test_2.shape
# Out:
# ((82, 1600), (42, 1600), (41, 1600))

# %%
np.unique(y_train)
# Out:
# array([0, 1, 2, 3, 4])

# %% [markdown]
#  2      3     4    1    0:
# left   right  up  down  No

# %% [markdown]
# # Deep Learning algorithms

# %%
X_train.shape[0]
# Out:
# 326

# %% [markdown]
# # 1.1.3 Room Lab1 & Lab2

# %% [markdown]
# # LSTM

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy

# Assuming X_train and X_test have shapes (326, 1600) and (82, 1600), respectively

# Reshape X_train and X_test to match the assumed input shape of the model
X_train_reshaped = np.reshape(X_train.values, (X_train.shape[0], 1600, 1))
X_test_reshaped = np.reshape(X_test.values, (X_test.shape[0], 1600, 1))
#print(X_train_reshaped)
#print(X_test_reshaped)

# Define the model
model = Sequential()

# Add a Bidirectional LSTM layer
model.add(Bidirectional(LSTM(256), input_shape=(1600, 1)))

# Add dense layers
model.add(Dense(512, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))

# Output layer with 5 classes (assuming 5 different activities)
model.add(Dense(5, activation='softmax'))

# Compile the model with run_eagerly=True
model.compile(optimizer=Adam(), loss=SparseCategoricalCrossentropy(), metrics=['accuracy'], run_eagerly=True)

# Print model summary
model.summary()

# Train the model
history=model.fit(X_train_reshaped, y_train.values, epochs=100, batch_size=128, validation_data=(X_test_reshaped, y_test.values))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 512)              528384
#  l)
#
#  dense (Dense)               (None, 512)               262656
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 955,909
# Trainable params: 955,909
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 3/3 [==============================] - 569s 245s/step - loss: 1.6521 - accuracy: 0.1810 - val_loss: 1.6472 - val_accuracy: 0.2073
# Epoch 2/100
# 3/3 [==============================] - 697s 254s/step - loss: 1.5766 - accuracy: 0.2761 - val_loss: 1.6367 - val_accuracy: 0.1829
# Epoch 3/100
# 3/3 [==============================] - 749s 269s/step - loss: 1.5773 - accuracy: 0.2699 - val_loss: 1.5803 - val_accuracy: 0.2439
# Epoch 4/100
# 3/3 [==============================] - 789s 282s/step - loss: 1.5297 - accuracy: 0.2822 - val_loss: 1.5391 - val_accuracy: 0.2927
# Epoch 5/100
# 3/3 [==============================] - 824s 294s/step - loss: 1.5300 - accuracy: 0.2638 - val_loss: 1.5182 - val_accuracy: 0.2439
# Epoch 6/100
# 3/3 [==============================] - 846s 297s/step - loss: 1.4879 - accuracy: 0.2975 - val_loss: 1.4444 - val_accuracy: 0.3537
# Epoch 7/100
# 3/3 [==============================] - 863s 304s/step - loss: 1.4520 - accuracy: 0.3129 - val_loss: 1.4255 - val_accuracy: 0.2927
# Epoch 8/100
# 3/3 [==============================] - 901s 314s/step - loss: 1.4133 - accuracy: 0.3466 - val_loss: 1.3649 - val_accuracy: 0.3537
# Epoch 9/100
# 3/3 [==============================] - 926s 323s/step - loss: 1.3697 - accuracy: 0.3896 - val_loss: 1.3822 - val_accuracy: 0.3537
# Epoch 10/100
# 3/3 [==============================] - 937s 325s/step - loss: 1.3590 - accuracy: 0.4080 - val_loss: 1.2703 - val_accuracy: 0.4268
# Epoch 11/100
# 3/3 [==============================] - 1043s 375s/step - loss: 1.3113 - accuracy: 0.4080 - val_loss: 1.2633 - val_accuracy: 0.4512
# Epoch 12/100
# 3/3 [==============================] - 968s 335s/step - loss: 1.2315 - accuracy: 0.4540 - val_loss: 1.1578 - val_accuracy: 0.4878
# Epoch 13/100
# 3/3 [==============================] - 976s 334s/step - loss: 1.1935 - accuracy: 0.5031 - val_loss: 1.1569 - val_accuracy: 0.4024
# Epoch 14/100
# 3/3 [==============================] - 665s 219s/step - loss: 1.1267 - accuracy: 0.4908 - val_loss: 1.0815 - val_accuracy: 0.4756
# Epoch 15/100
# 3/3 [==============================] - 667s 237s/step - loss: 1.0990 - accuracy: 0.5368 - val_loss: 1.1823 - val_accuracy: 0.4268
# Epoch 16/100
# 3/3 [==============================] - 2029s 627s/step - loss: 0.2564 - accuracy: 0.9049 - val_loss: 0.6503 - val_accuracy: 0.7073
# Epoch 96/100
# 3/3 [==============================] - 2286s 686s/step - loss: 0.2475 - accuracy: 0.8926 - val_loss: 0.7213 - val_accuracy: 0.6585
# Epoch 97/100
# 3/3 [==============================] - 2233s 656s/step - loss: 0.2544 - accuracy: 0.9080 - val_loss: 0.6908 - val_accuracy: 0.7073
# Epoch 98/100
# 3/3 [==============================] - 1946s 557s/step - loss: 0.2562 - accuracy: 0.8957 - val_loss: 1.0513 - val_accuracy: 0.6220
# Epoch 99/100
# 3/3 [==============================] - 1918s 570s/step - loss: 0.3043 - accuracy: 0.8865 - val_loss: 0.7515 - val_accuracy: 0.6951
# Epoch 100/100
# 3/3 [==============================] - 2125s 672s/step - loss: 0.3230 - accuracy: 0.8804 - val_loss: 0.9834 - val_accuracy: 0.6585

# %%
# Extract losses
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Plot the training and validation losses
epochs = range(1, len(train_loss) + 1)
plt.plot(epochs, train_loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
training_history = pd.DataFrame(history.history)

# %%
training_history
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   1.652057  0.180982  1.647234      0.207317
# 1   1.576606  0.276074  1.636745      0.182927
# 2   1.577307  0.269939  1.580292      0.243902
# 3   1.529678  0.282209  1.539147      0.292683
# 4   1.529999  0.263804  1.518178      0.243902
# ..       ...       ...       ...           ...
# 95  0.247521  0.892638  0.721280      0.658537
# 96  0.254441  0.907975  0.690765      0.707317
# 97  0.256198  0.895706  1.051261      0.621951
# 98  0.304299  0.886503  0.751483      0.695122
# 99  0.322971  0.880368  0.983376      0.658537
#
# [100 rows x 4 columns]

# %%
training_history.to_csv("history_room1_room2-lstm.csv", index=False)

# %% [markdown]
# # 1.2.3 1D cnn

# %%
from sklearn.preprocessing import StandardScaler

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from sklearn.preprocessing import StandardScaler  
from sklearn.preprocessing import StandardScaler

# Assuming X_train and X_test have shapes (326, 1600) and (82, 1600), respectively

# Reshape X_train and X_test to match the assumed input shape of the model
#X_train_reshaped = np.reshape(X_train.values, (X_train.shape[0], 1600, 1))
#X_test_reshaped = np.reshape(X_test.values, (X_test.shape[0], 1600, 1))
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train.values.reshape(X_train.shape[0], -1))
X_test_scaled = scaler.transform(X_test.values.reshape(X_test.shape[0], -1))

X_train_reshaped = np.reshape(X_train_scaled, (X_train.shape[0], 1600, 1))
X_test_reshaped = np.reshape(X_test_scaled, (X_test.shape[0], 1600, 1))

# Define the model
model_cnn = Sequential()

# Add a 1D Convolutional layer
model_cnn.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(1600, 1)))
model_cnn.add(MaxPooling1D(pool_size=2))
model_cnn.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model_cnn.add(MaxPooling1D(pool_size=2))
model_cnn.add(Flatten())  # Flatten the output for the dense layers

# Add dense layers
model_cnn.add(Dense(512, activation='relu'))
model_cnn.add(Dense(256, activation='relu'))
model_cnn.add(Dense(128, activation='relu'))

# Output layer with 5 classes (assuming 5 different activities)
model_cnn.add(Dense(5, activation='softmax'))

# Compile the model with run_eagerly=True
model_cnn.compile(optimizer=Adam(), loss=SparseCategoricalCrossentropy(), metrics=['accuracy'], run_eagerly=True)

# Print model summary
model_cnn.summary()

# Train the model
history_cnn = model_cnn.fit(X_train_reshaped, y_train.values, epochs=100, batch_size=128, validation_data=(X_test_reshaped, y_test.values))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 1598, 32)          128
#
#  max_pooling1d (MaxPooling1D  (None, 799, 32)          0
#  )
#
#  conv1d_1 (Conv1D)           (None, 797, 64)           6208
#
#  max_pooling1d_1 (MaxPooling  (None, 398, 64)          0
#  1D)
#
#  flatten (Flatten)           (None, 25472)             0
#
#  dense (Dense)               (None, 512)               13042176
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 13,213,381
# Trainable params: 13,213,381
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 3/3 [==============================] - 1s 321ms/step - loss: 2.3248 - accuracy: 0.2117 - val_loss: 3.7871 - val_accuracy: 0.2317
# Epoch 2/100
# 3/3 [==============================] - 1s 303ms/step - loss: 2.3548 - accuracy: 0.2945 - val_loss: 1.6229 - val_accuracy: 0.3171
# Epoch 3/100
# 3/3 [==============================] - 1s 258ms/step - loss: 1.5570 - accuracy: 0.2914 - val_loss: 1.4394 - val_accuracy: 0.4024
# Epoch 4/100
# 3/3 [==============================] - 1s 290ms/step - loss: 1.3266 - accuracy: 0.5429 - val_loss: 1.2596 - val_accuracy: 0.5488
# Epoch 5/100
# 3/3 [==============================] - 1s 277ms/step - loss: 1.1967 - accuracy: 0.5245 - val_loss: 1.1487 - val_accuracy: 0.5366
# Epoch 6/100
# 3/3 [==============================] - 1s 244ms/step - loss: 1.0952 - accuracy: 0.5982 - val_loss: 1.1041 - val_accuracy: 0.5854
# Epoch 7/100
# 3/3 [==============================] - 1s 262ms/step - loss: 0.9649 - accuracy: 0.6994 - val_loss: 0.9911 - val_accuracy: 0.6220
# Epoch 8/100
# 3/3 [==============================] - 1s 279ms/step - loss: 0.8260 - accuracy: 0.7761 - val_loss: 0.8458 - val_accuracy: 0.7439
# Epoch 9/100
# 3/3 [==============================] - 1s 295ms/step - loss: 0.6852 - accuracy: 0.8589 - val_loss: 0.7701 - val_accuracy: 0.7073
# Epoch 10/100
- accuracy: 1.0000 - val_loss: 0.4486 - val_accuracy: 0.8415
# Epoch 83/100
# 3/3 [==============================] - 1s 329ms/step - loss: 3.1297e-04 - accuracy: 1.0000 - val_loss: 0.4491 - val_accuracy: 0.8415
# Epoch 84/100
# 3/3 [==============================] - 1s 313ms/step - loss: 3.0618e-04 - accuracy: 1.0000 - val_loss: 0.4502 - val_accuracy: 0.8415
# Epoch 85/100
# 3/3 [==============================] - 1s 313ms/step - loss: 2.9862e-04 - accuracy: 1.0000 - val_loss: 0.4523 - val_accuracy: 0.8415
# Epoch 86/100
# 3/3 [==============================] - 1s 333ms/step - loss: 2.9180e-04 - accuracy: 1.0000 - val_loss: 0.4534 - val_accuracy: 0.8415
# Epoch 87/100
# 3/3 [==============================] - 1s 291ms/step - loss: 2.8500e-04 - accuracy: 1.0000 - val_loss: 0.4537 - val_accuracy: 0.8415
# Epoch 88/100
# 3/3 [==============================] - 1s 295ms/step - loss: 2.7818e-04 - accuracy: 1.0000 - val_loss: 0.4537 - val_accuracy: 0.8415
# Epoch 89/100
# 3/3 [==============================] - 1s 320ms/step - loss: 2.7211e-04 - accuracy: 1.0000 - val_loss: 0.4552 - val_accuracy: 0.8415
# Epoch 90/100
# 3/3 [==============================] - 1s 306ms/step - loss: 2.6589e-04 - accuracy: 1.0000 - val_loss: 0.4566 - val_accuracy: 0.8415
# Epoch 91/100
# 3/3 [==============================] - 1s 332ms/step - loss: 2.5987e-04 - accuracy: 1.0000 - val_loss: 0.4570 - val_accuracy: 0.8415
# Epoch 92/100
# 3/3 [==============================] - 1s 298ms/step - loss: 2.5405e-04 - accuracy: 1.0000 - val_loss: 0.4571 - val_accuracy: 0.8415
# Epoch 93/100
# 3/3 [==============================] - 1s 246ms/step - loss: 2.4845e-04 - accuracy: 1.0000 - val_loss: 0.4565 - val_accuracy: 0.8415
# Epoch 94/100
# 3/3 [==============================] - 1s 257ms/step - loss: 2.4273e-04 - accuracy: 1.0000 - val_loss: 0.4557 - val_accuracy: 0.8415
# Epoch 95/100
# 3/3 [==============================] - 1s 279ms/step - loss: 2.3763e-04 - accuracy: 1.0000 - val_loss: 0.4577 - val_accuracy: 0.8415
# Epoch 96/100
# 3/3 [==============================] - 1s 281ms/step - loss: 2.3240e-04 - accuracy: 1.0000 - val_loss: 0.4596 - val_accuracy: 0.8415
# Epoch 97/100
# 3/3 [==============================] - 1s 281ms/step - loss: 2.2746e-04 - accuracy: 1.0000 - val_loss: 0.4609 - val_accuracy: 0.8415
# Epoch 98/100
# 3/3 [==============================] - 1s 271ms/step - loss: 2.2305e-04 - accuracy: 1.0000 - val_loss: 0.4607 - val_accuracy: 0.8415
# Epoch 99/100
# 3/3 [==============================] - 1s 309ms/step - loss: 2.1752e-04 - accuracy: 1.0000 - val_loss: 0.4615 - val_accuracy: 0.8415
# Epoch 100/100
# 3/3 [==============================] - 1s 288ms/step - loss: 2.1259e-04 - accuracy: 1.0000 - val_loss: 0.4608 - val_accuracy: 0.8415

# %%
# Extract losses
train_loss_cnn = history_cnn.history['loss']
val_loss_cnn = history_cnn.history['val_loss']

# Plot the training and validation losses
epochs_cnn = range(1, len(train_loss_cnn) + 1)
plt.plot(epochs_cnn, train_loss_cnn, 'bo', label='Training Loss')
plt.plot(epochs_cnn, val_loss_cnn, 'b', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
training_history_cnn = pd.DataFrame(history_cnn.history)
training_history_cnn.to_csv("history_room1_room2_cnn.csv", index=False)

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming your model is named 'model_cnn' and you have trained it

# Get predictions on the test set
y_pred = model_cnn.predict(X_test_reshaped)
# Convert continuous predictions to discrete class labels
y_pred_labels = np.argmax(y_pred, axis=1)

cm_model_cnn = confusion_matrix(y_test, y_pred_labels, normalize='true')
class_names = ["Empty", "Down", "Left", "Right", "Up"]

# Plot confusion matrix as heatmap
sns.heatmap(cm_model_cnn, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1, xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.savefig("confusion_matrix_lab1&lab2_1D-CNN_amplitudes.pdf", format="pdf")

plt.show()
# Out:
# 3/3 [==============================] - 0s 33ms/step

# %% [markdown]
# # 1.1.1 Room1

# %% [markdown]
# # LSTM

# %%
# Reshape X_train and X_test to match the assumed input shape of the model
X_train_1_reshaped = np.reshape(X_train_1.values, (X_train_1.shape[0], 1600, 1))
X_test_1_reshaped = np.reshape(X_test_1.values, (X_test_1.shape[0], 1600, 1))
#print(X_train_reshaped)
#print(X_test_reshaped)

# Define the model
model1 = Sequential()

# Add a Bidirectional LSTM layer
model1.add(Bidirectional(LSTM(256), input_shape=(1600, 1)))

# Add dense layers
model1.add(Dense(512, activation='relu'))
model1.add(Dense(256, activation='relu'))
model1.add(Dense(128, activation='relu'))

# Output layer with 5 classes (assuming 5 different activities)
model1.add(Dense(5, activation='softmax'))

# Compile the model with run_eagerly=True
#model1.compile(optimizer=Adam(), loss=SparseCategoricalCrossentropy(), metrics=['accuracy'], run_eagerly=True)
model1.compile(optimizer=Adam(), loss=SparseCategoricalCrossentropy(), metrics=['accuracy'])
# Print model summary
model1.summary()

# Train the model
history1=model1.fit(X_train_1_reshaped, y_train_1.values, epochs=100, batch_size=128, validation_data=(X_test_1_reshaped, y_test_1.values))
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirectio  (None, 512)              528384
#  nal)
#
#  dense_68 (Dense)            (None, 512)               262656
#
#  dense_69 (Dense)            (None, 256)               131328
#
#  dense_70 (Dense)            (None, 128)               32896
#
#  dense_71 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 955,909
# Trainable params: 955,909
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 2/2 [==============================] - 1338s 488s/step - loss: 1.6404 - accuracy: 0.2378 - val_loss: 1.6028 - val_accuracy: 0.2381
# Epoch 2/100
# 2/2 [==============================] - 1717s 736s/step - loss: 1.5940 - accuracy: 0.2134 - val_loss: 1.5514 - val_accuracy: 0.2381
# Epoch 3/100
# 2/2 [==============================] - 1961s 743s/step - loss: 1.5593 - accuracy: 0.2378 - val_loss: 1.5155 - val_accuracy: 0.2857
# Epoch 4/100
# 2/2 [==============================] - 1958s 731s/step - loss: 1.5152 - accuracy: 0.2744 - val_loss: 1.4453 - val_accuracy: 0.3333
# Epoch 5/100
# 2/2 [==============================] - 1967s 760s/step - loss: 1.4604 - accuracy: 0.3598 - val_loss: 1.3951 - val_accuracy: 0.3095
# Epoch 6/100
# 2/2 [==============================] - 1957s 749s/step - loss: 1.4145 - accuracy: 0.3171 - val_loss: 1.3562 - val_accuracy: 0.4286
# Epoch 7/100
# 2/2 [==============================] - 1978s 766s/step - loss: 1.3918 - accuracy: 0.3780 - val_loss: 1.2917 - val_accuracy: 0.3571
# Epoch 8/100
# 2/2 [==============================] - 1956s 747s/step - loss: 1.3113 - accuracy: 0.3902 - val_loss: 1.2389 - val_accuracy: 0.4048
# Epoch 9/100
# 2/2 [==============================] - 1958s 748s/step - loss: 1.2493 - accuracy: 0.4329 - val_loss: 1.2167 - val_accuracy: 0.4048
# Epoch 10/100
# 2/2 [==============================] - 1941s 738s/step - loss: 1.2087 - accuracy: 0.4573 - val_loss: 1.1983 - val_accuracy: 0.3810
# Epoch 11/100
# 2/2 [==============================] - 1984s 764s/step - loss: 1.1789 - accuracy: 0.4878 - val_loss: 1.2359 - val_accuracy: 0.4524
# Epoch 12/100
# 2/2 [==============================] - 1974s 754s/step - loss: 1.1890 - accuracy: 0.4878 - val_loss: 1.2006 - val_accuracy: 0.4524
# Epoch 13/100
# Epoch 33/100
# 2/2 [==============================] - 1401s 531s/step - loss: 0.9714 - accuracy: 0.5793 - val_loss: 1.0600 - val_accuracy: 0.4524
# Epoch 34/100
# 2/2 [==============================] - 1783s 563s/step - loss: 0.9569 - accuracy: 0.5000 - val_loss: 1.0582 - val_accuracy: 0.5476
# Epoch 35/100
# 2/2 [==============================] - 1334s 519s/step - loss: 0.9126 - accuracy: 0.5793 - val_loss: 1.1106 - val_accuracy: 0.4048
# Epoch 36/100
# 2/2 [==============================] - 1327s 467s/step - loss: 0.9192 - accuracy: 0.5854 - val_loss: 1.1168 - val_accuracy: 0.4762
# Epoch 37/100
# 2/2 [==============================] - 1807s 868s/step - loss: 0.8775 - accuracy: 0.6037 - val_loss: 1.0986 - val_accuracy: 0.5000
# Epoch 38/100
# 2/2 [==============================] - 2246s 892s/step - loss: 0.9080 - accuracy: 0.6098 - val_loss: 0.9946 - val_accuracy: 0.5238
# Epoch 39/100
# 2/2 [==============================] - 2210s 829s/step - loss: 0.8858 - accuracy: 0.5915 - val_loss: 0.9513 - val_accuracy: 0.5238
# Epoch 40/100
# 2/2 [==============================] - 2152s 867s/step - loss: 0.8623 - accuracy: 0.5793 - val_loss: 1.0067 - val_accuracy: 0.5000
# Epoch 41/100
# 2/2 [==============================] - 2080s 836s/step - loss: 0.8366 - accuracy: 0.5854 - val_loss: 1.0620 - val_accuracy: 0.5000
# Epoch 42/100
# 1/2 [==============>...............] - ETA: 21:41 - loss: 0.7869 - accuracy: 0.6328

# %%
# Extract losses for history1
train_loss_1 = history1.history['loss']
val_loss_1 = history1.history['val_loss']

# Plot the training and validation losses for history1
epochs_1 = range(1, len(train_loss_1) + 1)
plt.plot(epochs_1, train_loss_1, 'ro', label='Model Training Loss')
plt.plot(epochs_1, val_loss_1, 'r', label='Model Validation Loss')
plt.title('Training and Validation Loss for Model')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
training_history1 = pd.DataFrame(history1.history)
training_history1.to_csv("history_room1_lstm.csv", index=False)

# %% [markdown]
# # 1.2.1

# %% [markdown]
# # 1D-CNN

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy

# Assuming X_train and X_test have shapes (326, 1600) and (82, 1600), respectively

# Reshape X_train and X_test to match the assumed input shape of the model
scaler1 = StandardScaler()
X_train_scaled1 = scaler1.fit_transform(X_train_1.values.reshape(X_train_1.shape[0], -1))
X_test_scaled1 = scaler1.transform(X_test_1.values.reshape(X_test_1.shape[0], -1))

X_train_1_reshaped = np.reshape(X_train_scaled1, (X_train_1.shape[0], 1600, 1))
X_test_1_reshaped = np.reshape(X_test_scaled1, (X_test_1.shape[0], 1600, 1))

#X_train_1_reshaped = np.reshape(X_train_scaled1.values, (X_train_1.shape[0], 1600, 1))
#X_test_1_reshaped = np.reshape(X_test_scaled1.values, (X_test_1.shape[0], 1600, 1))

# Define the model
model1_cnn = Sequential()

# Add a 1D Convolutional layer
model1_cnn.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(1600, 1)))
model1_cnn.add(MaxPooling1D(pool_size=2))
model1_cnn.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model1_cnn.add(MaxPooling1D(pool_size=2))
model1_cnn.add(Flatten())  # Flatten the output for the dense layers

# Add dense layers
model1_cnn.add(Dense(512, activation='relu'))
model1_cnn.add(Dense(256, activation='relu'))
model1_cnn.add(Dense(128, activation='relu'))

# Output layer with 5 classes (assuming 5 different activities)
model1_cnn.add(Dense(5, activation='softmax'))

# Compile the model with run_eagerly=True
model1_cnn.compile(optimizer=Adam(), loss=SparseCategoricalCrossentropy(), metrics=['accuracy'], run_eagerly=True)

# Print model summary
model1_cnn.summary()

# Train the model
history1_cnn = model1_cnn.fit(X_train_1_reshaped, y_train_1.values, epochs=100, batch_size=128, validation_data=(X_test_1_reshaped, y_test_1.values))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 1598, 32)          128
#
#  max_pooling1d_2 (MaxPooling  (None, 799, 32)          0
#  1D)
#
#  conv1d_3 (Conv1D)           (None, 797, 64)           6208
#
#  max_pooling1d_3 (MaxPooling  (None, 398, 64)          0
#  1D)
#
#  flatten_1 (Flatten)         (None, 25472)             0
#
#  dense_4 (Dense)             (None, 512)               13042176
#
#  dense_5 (Dense)             (None, 256)               131328
#
#  dense_6 (Dense)             (None, 128)               32896
#
#  dense_7 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 13,213,381
# Trainable params: 13,213,381
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 2/2 [==============================] - 1s 274ms/step - loss: 1.7169 - accuracy: 0.1524 - val_loss: 1.4853 - val_accuracy: 0.3333
# Epoch 2/100
# 2/2 [==============================] - 1s 254ms/step - loss: 1.4708 - accuracy: 0.3110 - val_loss: 1.5043 - val_accuracy: 0.3095
# Epoch 3/100
# 2/2 [==============================] - 0s 192ms/step - loss: 1.3565 - accuracy: 0.3720 - val_loss: 0.9016 - val_accuracy: 0.5952
# Epoch 4/100
# 2/2 [==============================] - 0s 255ms/step - loss: 0.8843 - accuracy: 0.7012 - val_loss: 0.9082 - val_accuracy: 0.5714
# Epoch 5/100
# 2/2 [==============================] - 1s 248ms/step - loss: 0.8063 - accuracy: 0.6220 - val_loss: 0.7476 - val_accuracy: 0.6905
# Epoch 6/100
# 2/2 [==============================] - 1s 290ms/step - loss: 0.6438 - accuracy: 0.7073 - val_loss: 0.6753 - val_accuracy: 0.6667
# Epoch 7/100
# 2/2 [==============================] - 1s 308ms/step - loss: 0.5027 - accuracy: 0.8720 - val_loss: 0.5662 - val_accuracy: 0.7381
# Epoch 8/100
# 2/2 [==============================] - 0s 202ms/step - loss: 0.3678 - accuracy: 0.8537 - val_loss: 0.6061 - val_accuracy: 0.7143
# Epoch 9/100
# 2/2 [==============================] - 0s 186ms/step - loss: 0.3445 - accuracy: 0.8841 - val_loss: 0.4122 - val_accuracy: 0.7619
# Epoch 10/100
# 2/2 [==============================] - 0s 229ms/step - loss: 0.2247 - accuracy: 0.9634 - val_loss: 0.5747 - val_accuracy: 0.7143
# Epoch 11/100
# 2/2 [==============================] - 0s 198ms/step - loss: 0.2354 - accuracy: 0.8841 - val_loss: 0.3971 - val_accuracy: 0.7857
# Epoch 12/100
# 2/2 [==============================] - 0s 261ms/step - loss: 0.1640 - accuracy: 0.9329 - val_loss: 0.4664 - val_accuracy: 0.7619
# Epoch 13/100
# 2/2 [==============================] - 1s 237ms/step - loss: 0.1326 - accuracy: 0.9634 - val_loss: 0.5849 - val_accuracy: 0.7381
# Epoch 14/100
# 2/2 [==============================] - 1s 277ms/step - loss: 0.1116 - accuracy: 0.9756 - val_loss: 0.4826 - val_accuracy: 0.7619
# Epoch 15/100
# 2/2 [==============================] - 0s 218ms/step - loss: 0.0582 - accuracy: 0.9939 - val_loss: 0.4051 - val_accuracy: 0.8333
# Epoch 16/100
# 2/2 [==============================] - 1s 237ms/step - loss: 0.0479 - accuracy: 0.9939 - val_loss: 0.4143 - val_accuracy: 0.8810
# Epoch 17/100
# 2/2 [==============================] - 1s 301ms/step - loss: 0.0325 - accuracy: 1.0000 - val_loss: 0.4354 - val_accuracy: 0.8333
# Epoch 18/100
# 2/2 [==============================] - 1s 314ms/step - loss: 0.0230 - accuracy: 1.0000 - val_loss: 0.3977 - val_accuracy: 0.8095
# Epoch 19/100
# 2/2 [==============================] - 1s 280ms/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.4152 - val_accuracy: 0.7857
# Epoch 20/100
# 2/2 [==============================] - 1s 276ms/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.4617 - val_accuracy: 0.7857
# Epoch 21/100
# 2/2 [==============================] - 1s 261ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.5481 - val_accuracy: 0.7857
# Epoch 22/100
# 2/2 [==============================] - 1s 279ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.4881 - val_accuracy: 0.7857
# Epoch 23/100
# 2/2 [==============================] - 1s 292ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.3703 - val_accuracy: 0.7857
# Epoch 24/100
# 2/2 [==============================] - 1s 293ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.3412 - val_accuracy: 0.8095
# Epoch 25/100
# 2/2 [==============================] - 1s 295ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.3486 - val_accuracy: 0.8571
# Epoch 26/100
# 2/2 [==============================] - 1s 277ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.4051 - val_accuracy: 0.8810
# Epoch 27/100
# 2/2 [==============================] - 1s 290ms/step - loss: 9.7263e-04 - accuracy: 1.0000 - val_loss: 0.4800 - val_accuracy: 0.8095
# Epoch 28/100
# 2/2 [==============================] - 1s 308ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5211 - val_accuracy: 0.8095
# Epoch 29/100
# 2/2 [==============================] - 0s 215ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.5029 - val_accuracy: 0.8095
# Epoch 30/100
# 2/2 [==============================] - 0s 217ms/step - loss: 7.3066e-04 - accuracy: 1.0000 - val_loss: 0.4594 - val_accuracy: 0.8333
# Epoch 31/100
# 2/2 [==============================] - 1s 295ms/step - loss: 4.9950e-04 - accuracy: 1.0000 - val_loss: 0.4199 - val_accuracy: 0.8571
# Epoch 32/100
# 2/2 [==============================] - 1s 315ms/step - loss: 4.1507e-04 - accuracy: 1.0000 - val_loss: 0.4009 - val_accuracy: 0.8571
# Epoch 33/100
# 2/2 [==============================] - 1s 284ms/step - loss: 3.8200e-04 - accuracy: 1.0000 - val_loss: 0.3988 - val_accuracy: 0.8333
# Epoch 34/100
# 2/2 [==============================] - 1s 300ms/step - loss: 3.7330e-04 - accuracy: 1.0000 - val_loss: 0.4084 - val_accuracy: 0.8333
# Epoch 35/100
# 2/2 [==============================] - 1s 272ms/step - loss: 3.3218e-04 - accuracy: 1.0000 - val_loss: 0.4307 - val_accuracy: 0.8095
# Epoch 36/100
# 2/2 [==============================] - 1s 248ms/step - loss: 2.6612e-04 - accuracy: 1.0000 - val_loss: 0.4618 - val_accuracy: 0.8095
# Epoch 37/100
# 2/2 [==============================] - 0s 222ms/step - loss: 2.2647e-04 - accuracy: 1.0000 - val_loss: 0.4991 - val_accuracy: 0.8333
# Epoch 38/100
# 2/2 [==============================] - 0s 195ms/step - loss: 2.1156e-04 - accuracy: 1.0000 - val_loss: 0.5220 - val_accuracy: 0.8095
# Epoch 39/100
# 2/2 [==============================] - 0s 191ms/step - loss: 1.9909e-04 - accuracy: 1.0000 - val_loss: 0.5197 - val_accuracy: 0.8095
# Epoch 40/100
# 2/2 [==============================] - 0s 198ms/step - loss: 1.8075e-04 - accuracy: 1.0000 - val_loss: 0.5005 - val_accuracy: 0.8333
# Epoch 41/100
# 2/2 [==============================] - 0s 214ms/step - loss: 1.6530e-04 - accuracy: 1.0000 - val_loss: 0.4819 - val_accuracy: 0.8333
# Epoch 42/100
# 2/2 [==============================] - 0s 213ms/step - loss: 1.5347e-04 - accuracy: 1.0000 - val_loss: 0.4706 - val_accuracy: 0.8571
# Epoch 43/100
# 2/2 [==============================] - 0s 197ms/step - loss: 1.4504e-04 - accuracy: 1.0000 - val_loss: 0.4634 - val_accuracy: 0.8571
# Epoch 44/100
# 2/2 [==============================] - 1s 236ms/step - loss: 1.3883e-04 - accuracy: 1.0000 - val_loss: 0.4592 - val_accuracy: 0.8571
# Epoch 45/100
# 2/2 [==============================] - 0s 215ms/step - loss: 1.3228e-04 - accuracy: 1.0000 - val_loss: 0.4562 - val_accuracy: 0.8810
# Epoch 46/100
# 2/2 [==============================] - 0s 224ms/step - loss: 1.2637e-04 - accuracy: 1.0000 - val_loss: 0.4555 - val_accuracy: 0.8810
# Epoch 47/100
# 2/2 [==============================] - 0s 268ms/step - loss: 1.2177e-04 - accuracy: 1.0000 - val_loss: 0.4558 - val_accuracy: 0.8810
# Epoch 48/100
# 2/2 [==============================] - 1s 239ms/step - loss: 1.1713e-04 - accuracy: 1.0000 - val_loss: 0.4559 - val_accuracy: 0.8810
# Epoch 49/100
# 2/2 [==============================] - 1s 298ms/step - loss: 1.1282e-04 - accuracy: 1.0000 - val_loss: 0.4592 - val_accuracy: 0.8810
# Epoch 50/100
# 2/2 [==============================] - 1s 275ms/step - loss: 1.0888e-04 - accuracy: 1.0000 - val_loss: 0.4643 - val_accuracy: 0.8810
# Epoch 51/100
# 2/2 [==============================] - 1s 231ms/step - loss: 1.0503e-04 - accuracy: 1.0000 - val_loss: 0.4699 - val_accuracy: 0.8810
# Epoch 52/100
# 2/2 [==============================] - 1s 299ms/step - loss: 1.0108e-04 - accuracy: 1.0000 - val_loss: 0.4747 - val_accuracy: 0.8810
# Epoch 53/100
# 2/2 [==============================] - 1s 325ms/step - loss: 9.7735e-05 - accuracy: 1.0000 - val_loss: 0.4793 - val_accuracy: 0.8810
# Epoch 54/100
# 2/2 [==============================] - 1s 239ms/step - loss: 9.4216e-05 - accuracy: 1.0000 - val_loss: 0.4841 - val_accuracy: 0.8810
# Epoch 55/100
# 2/2 [==============================] - 1s 265ms/step - loss: 9.0912e-05 - accuracy: 1.0000 - val_loss: 0.4883 - val_accuracy: 0.8810
# Epoch 56/100
# 2/2 [==============================] - 1s 258ms/step - loss: 8.7711e-05 - accuracy: 1.0000 - val_loss: 0.4925 - val_accuracy: 0.8810
# Epoch 57/100
# 2/2 [==============================] - 1s 257ms/step - loss: 8.4553e-05 - accuracy: 1.0000 - val_loss: 0.4959 - val_accuracy: 0.8571
# Epoch 58/100
# 2/2 [==============================] - 1s 297ms/step - loss: 8.1494e-05 - accuracy: 1.0000 - val_loss: 0.4947 - val_accuracy: 0.8810
# Epoch 59/100
# 2/2 [==============================] - 1s 260ms/step - loss: 7.8211e-05 - accuracy: 1.0000 - val_loss: 0.4933 - val_accuracy: 0.8810
# Epoch 60/100
# 2/2 [==============================] - 1s 329ms/step - loss: 7.4934e-05 - accuracy: 1.0000 - val_loss: 0.4918 - val_accuracy: 0.8810
# Epoch 61/100
# 2/2 [==============================] - 1s 283ms/step - loss: 7.1863e-05 - accuracy: 1.0000 - val_loss: 0.4891 - val_accuracy: 0.8810
# Epoch 62/100
# 2/2 [==============================] - 1s 296ms/step - loss: 6.8941e-05 - accuracy: 1.0000 - val_loss: 0.4882 - val_accuracy: 0.8810
# Epoch 63/100
# 2/2 [==============================] - 1s 287ms/step - loss: 6.5895e-05 - accuracy: 1.0000 - val_loss: 0.4853 - val_accuracy: 0.8810
# Epoch 64/100
# 2/2 [==============================] - 1s 244ms/step - loss: 6.3411e-05 - accuracy: 1.0000 - val_loss: 0.4853 - val_accuracy: 0.8810
# Epoch 65/100
# 2/2 [==============================] - 1s 251ms/step - loss: 6.0497e-05 - accuracy: 1.0000 - val_loss: 0.4915 - val_accuracy: 0.8810
# Epoch 66/100
# 2/2 [==============================] - 1s 302ms/step - loss: 5.7751e-05 - accuracy: 1.0000 - val_loss: 0.4959 - val_accuracy: 0.8810
# Epoch 67/100
# 2/2 [==============================] - 0s 199ms/step - loss: 5.5112e-05 - accuracy: 1.0000 - val_loss: 0.5014 - val_accuracy: 0.8810
# Epoch 68/100
uracy: 1.0000 - val_loss: 0.5239 - val_accuracy: 0.8810
# Epoch 91/100
# 2/2 [==============================] - 1s 242ms/step - loss: 2.1905e-05 - accuracy: 1.0000 - val_loss: 0.5338 - val_accuracy: 0.8810
# Epoch 92/100
# 2/2 [==============================] - 1s 314ms/step - loss: 2.1405e-05 - accuracy: 1.0000 - val_loss: 0.5395 - val_accuracy: 0.8810
# Epoch 93/100
# 2/2 [==============================] - 1s 273ms/step - loss: 2.0941e-05 - accuracy: 1.0000 - val_loss: 0.5391 - val_accuracy: 0.8810
# Epoch 94/100
# 2/2 [==============================] - 0s 193ms/step - loss: 2.0361e-05 - accuracy: 1.0000 - val_loss: 0.5343 - val_accuracy: 0.8810
# Epoch 95/100
# 2/2 [==============================] - 1s 275ms/step - loss: 1.9718e-05 - accuracy: 1.0000 - val_loss: 0.5271 - val_accuracy: 0.8810
# Epoch 96/100
# 2/2 [==============================] - 0s 231ms/step - loss: 1.9201e-05 - accuracy: 1.0000 - val_loss: 0.5172 - val_accuracy: 0.8810
# Epoch 97/100
# 2/2 [==============================] - 0s 193ms/step - loss: 1.8946e-05 - accuracy: 1.0000 - val_loss: 0.5139 - val_accuracy: 0.8810
# Epoch 98/100
# 2/2 [==============================] - 0s 195ms/step - loss: 1.8481e-05 - accuracy: 1.0000 - val_loss: 0.5206 - val_accuracy: 0.8810
# Epoch 99/100
# 2/2 [==============================] - 0s 179ms/step - loss: 1.8012e-05 - accuracy: 1.0000 - val_loss: 0.5282 - val_accuracy: 0.8810
# Epoch 100/100
# 2/2 [==============================] - 0s 244ms/step - loss: 1.7503e-05 - accuracy: 1.0000 - val_loss: 0.5327 - val_accuracy: 0.8810

# %%
# Extract losses for history1
train_loss_1_cnn = history1_cnn.history['loss']
val_loss_1_cnn = history1_cnn.history['val_loss']

# Plot the training and validation losses for history1
epochs_1_cnn = range(1, len(train_loss_1_cnn) + 1)
plt.plot(epochs_1_cnn, train_loss_1_cnn, 'ro', label='Model Training Loss')
plt.plot(epochs_1_cnn, val_loss_1_cnn, 'r', label='Model Validation Loss')
plt.title('Training and Validation Loss for Model')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
training_history1_cnn = pd.DataFrame(history1_cnn.history)
training_history1_cnn.to_csv("history_room1_cnn.csv", index=False)

# %%
# Get predictions on the test set
y_pred_1 = model1_cnn.predict(X_test_1_reshaped)
# Convert continuous predictions to discrete class labels
y_pred_labels_1 = np.argmax(y_pred_1, axis=1)

cm_model1_cnn = confusion_matrix(y_test_1, y_pred_labels_1, normalize='true')
class_names = ["Empty", "Down", "Left", "Right", "Up"]

# Plot confusion matrix as heatmap
sns.heatmap(cm_model1_cnn, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1, xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.savefig("confusion_matrix_lab1_1D-CNN_amplitudes.pdf", format="pdf")

plt.show()
# Out:
# 2/2 [==============================] - 0s 29ms/step

# %% [markdown]
# # 1.1.2 Room2

# %% [markdown]
# # LSTM

# %%
# Reshape X_train and X_test to match the assumed input shape of the model
X_train_2_reshaped = np.reshape(X_train_2.values, (X_train_2.shape[0], 1600, 1))
X_test_2_reshaped = np.reshape(X_test_2.values, (X_test_2.shape[0], 1600, 1))
#print(X_train_reshaped)
#print(X_test_reshaped)

# Define the model
model2 = Sequential()

# Add a Bidirectional LSTM layer
model2.add(Bidirectional(LSTM(256), input_shape=(1600, 1)))

# Add dense layers
model2.add(Dense(512, activation='relu'))
model2.add(Dense(256, activation='relu'))
model2.add(Dense(128, activation='relu'))

# Output layer with 5 classes (assuming 5 different activities)
model2.add(Dense(5, activation='softmax'))

# Compile the model with run_eagerly=True
model2.compile(optimizer=Adam(), loss=SparseCategoricalCrossentropy(), metrics=['accuracy'], run_eagerly=True)

# Print model summary
model2.summary()

# Train the model
history2=model2.fit(X_train_2_reshaped, y_train_2.values, epochs=100, batch_size=128, validation_data=(X_test_2_reshaped, y_test_2.values))

# %%
# Extract losses for history2
train_loss_2 = history2.history['loss']
val_loss_2 = history2.history['val_loss']

# Plot the training and validation losses for history2
epochs_2 = range(1, len(train_loss_2) + 1)
plt.plot(epochs_2, train_loss_2, 'ro', label='Model2 Training Loss')
plt.plot(epochs_2, val_loss_2, 'r', label='Model2 Validation Loss')
plt.title('Training and Validation Loss for Model2')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
training_history2 = pd.DataFrame(history2.history)
training_history2.to_csv("history_room2_lstm.csv", index=False)

# %% [markdown]
# # 1.2.2

# %% [markdown]
# # 1D-CNN

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy

# Assuming X_train and X_test have shapes (326, 1600) and (82, 1600), respectively

# Reshape X_train and X_test to match the assumed input shape of the model
scaler2 = StandardScaler()
X_train_scaled2 = scaler2.fit_transform(X_train_2.values.reshape(X_train_2.shape[0], -1))
X_test_scaled2 = scaler2.transform(X_test_2.values.reshape(X_test_2.shape[0], -1))

X_train_2_reshaped = np.reshape(X_train_scaled2, (X_train_2.shape[0], 1600, 1))
X_test_2_reshaped = np.reshape(X_test_scaled2, (X_test_2.shape[0], 1600, 1))

#X_train_2_reshaped = np.reshape(X_train_scaled2.values, (X_train_2.shape[0], 1600, 1))
#X_test_2_reshaped = np.reshape(X_test_scaled2.values, (X_test_2.shape[0], 1600, 1))

# Define the model
model2_cnn = Sequential()

# Add a 1D Convolutional layer
model2_cnn.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(1600, 1)))
model2_cnn.add(MaxPooling1D(pool_size=2))
model2_cnn.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model2_cnn.add(MaxPooling1D(pool_size=2))
model2_cnn.add(Flatten())  # Flatten the output for the dense layers

# Add dense layers
model2_cnn.add(Dense(512, activation='relu'))
model2_cnn.add(Dense(256, activation='relu'))
model2_cnn.add(Dense(128, activation='relu'))

# Output layer with 5 classes (assuming 5 different activities)
model2_cnn.add(Dense(5, activation='softmax'))

# Compile the model with run_eagerly=True
model2_cnn.compile(optimizer=Adam(), loss=SparseCategoricalCrossentropy(), metrics=['accuracy'], run_eagerly=True)

# Print model summary
model2_cnn.summary()

# Train the model
history2_cnn = model2_cnn.fit(X_train_2_reshaped, y_train_2.values, epochs=100, batch_size=128, validation_data=(X_test_2_reshaped, y_test_2.values))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 1598, 32)          128
#
#  max_pooling1d_4 (MaxPooling  (None, 799, 32)          0
#  1D)
#
#  conv1d_5 (Conv1D)           (None, 797, 64)           6208
#
#  max_pooling1d_5 (MaxPooling  (None, 398, 64)          0
#  1D)
#
#  flatten_2 (Flatten)         (None, 25472)             0
#
#  dense_8 (Dense)             (None, 512)               13042176
#
#  dense_9 (Dense)             (None, 256)               131328
#
#  dense_10 (Dense)            (None, 128)               32896
#
#  dense_11 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 13,213,381
# Trainable params: 13,213,381
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 2/2 [==============================] - 1s 317ms/step - loss: 1.6291 - accuracy: 0.3106 - val_loss: 1.0174 - val_accuracy: 0.6098
# Epoch 2/100
# 2/2 [==============================] - 1s 239ms/step - loss: 1.0315 - accuracy: 0.5155 - val_loss: 1.0330 - val_accuracy: 0.5122
# Epoch 3/100
# 2/2 [==============================] - 0s 221ms/step - loss: 0.7237 - accuracy: 0.6584 - val_loss: 0.5004 - val_accuracy: 0.8293
# Epoch 4/100
# 2/2 [==============================] - 1s 223ms/step - loss: 0.3878 - accuracy: 0.8571 - val_loss: 0.3447 - val_accuracy: 0.9024
# Epoch 5/100
- accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 55/100
# 2/2 [==============================] - 1s 270ms/step - loss: 1.5838e-05 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 56/100
# 2/2 [==============================] - 0s 255ms/step - loss: 1.5575e-05 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 57/100
# 2/2 [==============================] - 0s 223ms/step - loss: 1.5316e-05 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 58/100
# 2/2 [==============================] - 0s 207ms/step - loss: 1.5034e-05 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 1.0000
# Epoch 59/100
# 2/2 [==============================] - 0s 194ms/step - loss: 1.4834e-05 - accuracy: 1.0000 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 60/100
# 2/2 [==============================] - 0s 206ms/step - loss: 1.4619e-05 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 1.0000
# Epoch 61/100
# 2/2 [==============================] - 1s 256ms/step - loss: 1.4414e-05 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 1.0000
# Epoch 62/100
# 2/2 [==============================] - 0s 211ms/step - loss: 1.4227e-05 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 63/100
# 2/2 [==============================] - 0s 223ms/step - loss: 1.4041e-05 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 1.0000
# Epoch 64/100
# 2/2 [==============================] - 0s 195ms/step - loss: 1.3844e-05 - accuracy: 1.0000 - val_loss: 0.0076 - val_accuracy: 1.0000
# Epoch 65/100
# 2/2 [==============================] - 0s 203ms/step - loss: 1.3653e-05 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 66/100
# 2/2 [==============================] - 0s 213ms/step - loss: 1.3473e-05 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000
# Epoch 67/100
# 2/2 [==============================] - 1s 287ms/step - loss: 1.3282e-05 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 68/100
# 2/2 [==============================] - 1s 283ms/step - loss: 1.3111e-05 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 69/100
# 2/2 [==============================] - 1s 248ms/step - loss: 1.2898e-05 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 70/100
# 2/2 [==============================] - 1s 301ms/step - loss: 1.2718e-05 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 71/100
# 2/2 [==============================] - 1s 275ms/step - loss: 1.2534e-05 - accuracy: 1.0000 - val_loss: 0.0090 - val_accuracy: 1.0000
# Epoch 72/100
# 2/2 [==============================] - 1s 300ms/step - loss: 1.2345e-05 - accuracy: 1.0000 - val_loss: 0.0092 - val_accuracy: 1.0000
# Epoch 73/100
# 2/2 [==============================] - 1s 283ms/step - loss: 1.2177e-05 - accuracy: 1.0000 - val_loss: 0.0093 - val_accuracy: 1.0000
# Epoch 74/100
# 2/2 [==============================] - 1s 312ms/step - loss: 1.2011e-05 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 75/100
# 2/2 [==============================] - 1s 231ms/step - loss: 1.1857e-05 - accuracy: 1.0000 - val_loss: 0.0097 - val_accuracy: 1.0000
# Epoch 76/100
# 2/2 [==============================] - 1s 213ms/step - loss: 1.1669e-05 - accuracy: 1.0000 - val_loss: 0.0100 - val_accuracy: 1.0000
# Epoch 77/100
# 2/2 [==============================] - 1s 284ms/step - loss: 1.1527e-05 - accuracy: 1.0000 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 78/100
# 2/2 [==============================] - 1s 299ms/step - loss: 1.1336e-05 - accuracy: 1.0000 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 79/100
# 2/2 [==============================] - 1s 250ms/step - loss: 1.1162e-05 - accuracy: 1.0000 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 80/100
# 2/2 [==============================] - 1s 278ms/step - loss: 1.1009e-05 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 1.0000
# Epoch 81/100
# 2/2 [==============================] - 1s 287ms/step - loss: 1.0847e-05 - accuracy: 1.0000 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 82/100
# 2/2 [==============================] - 1s 300ms/step - loss: 1.0682e-05 - accuracy: 1.0000 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 83/100
# 2/2 [==============================] - 1s 266ms/step - loss: 1.0540e-05 - accuracy: 1.0000 - val_loss: 0.0121 - val_accuracy: 1.0000
# Epoch 84/100
# 2/2 [==============================] - 1s 287ms/step - loss: 1.0374e-05 - accuracy: 1.0000 - val_loss: 0.0125 - val_accuracy: 1.0000
# Epoch 85/100
# 2/2 [==============================] - 0s 212ms/step - loss: 1.0252e-05 - accuracy: 1.0000 - val_loss: 0.0128 - val_accuracy: 1.0000
# Epoch 86/100
# 2/2 [==============================] - 0s 205ms/step - loss: 1.0088e-05 - accuracy: 1.0000 - val_loss: 0.0130 - val_accuracy: 1.0000
# Epoch 87/100
# 2/2 [==============================] - 0s 226ms/step - loss: 9.9281e-06 - accuracy: 1.0000 - val_loss: 0.0133 - val_accuracy: 1.0000
# Epoch 88/100
# 2/2 [==============================] - 0s 210ms/step - loss: 9.7889e-06 - accuracy: 1.0000 - val_loss: 0.0135 - val_accuracy: 1.0000
# Epoch 89/100
# 2/2 [==============================] - 0s 218ms/step - loss: 9.6349e-06 - accuracy: 1.0000 - val_loss: 0.0139 - val_accuracy: 1.0000
# Epoch 90/100
# 2/2 [==============================] - 1s 249ms/step - loss: 9.4935e-06 - accuracy: 1.0000 - val_loss: 0.0142 - val_accuracy: 1.0000
# Epoch 91/100
# 2/2 [==============================] - 1s 232ms/step - loss: 9.3557e-06 - accuracy: 1.0000 - val_loss: 0.0144 - val_accuracy: 1.0000
# Epoch 92/100
# 2/2 [==============================] - 1s 230ms/step - loss: 9.2151e-06 - accuracy: 1.0000 - val_loss: 0.0146 - val_accuracy: 1.0000
# Epoch 93/100
# 2/2 [==============================] - 1s 243ms/step - loss: 9.0692e-06 - accuracy: 1.0000 - val_loss: 0.0149 - val_accuracy: 1.0000
# Epoch 94/100
# 2/2 [==============================] - 1s 310ms/step - loss: 8.9397e-06 - accuracy: 1.0000 - val_loss: 0.0151 - val_accuracy: 1.0000
# Epoch 95/100
# 2/2 [==============================] - 1s 289ms/step - loss: 8.8101e-06 - accuracy: 1.0000 - val_loss: 0.0154 - val_accuracy: 1.0000
# Epoch 96/100
# 2/2 [==============================] - 1s 263ms/step - loss: 8.7013e-06 - accuracy: 1.0000 - val_loss: 0.0156 - val_accuracy: 1.0000
# Epoch 97/100
# 2/2 [==============================] - 1s 260ms/step - loss: 8.5643e-06 - accuracy: 1.0000 - val_loss: 0.0158 - val_accuracy: 1.0000
# Epoch 98/100
# 2/2 [==============================] - 1s 264ms/step - loss: 8.4562e-06 - accuracy: 1.0000 - val_loss: 0.0161 - val_accuracy: 1.0000
# Epoch 99/100
# 2/2 [==============================] - 0s 214ms/step - loss: 8.3348e-06 - accuracy: 1.0000 - val_loss: 0.0164 - val_accuracy: 1.0000
# Epoch 100/100
# 2/2 [==============================] - 0s 213ms/step - loss: 8.2274e-06 - accuracy: 1.0000 - val_loss: 0.0167 - val_accuracy: 1.0000

# %%
# Extract losses for history1
train_loss_2_cnn = history2_cnn.history['loss']
val_loss_2_cnn = history2_cnn.history['val_loss']

# Plot the training and validation losses for history1
epochs_2_cnn = range(1, len(train_loss_2_cnn) + 1)
plt.plot(epochs_2_cnn, train_loss_2_cnn, 'ro', label='Model Training Loss')
plt.plot(epochs_2_cnn, val_loss_2_cnn, 'r', label='Model Validation Loss')
plt.title('Training and Validation Loss for Model')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
training_history2_cnn = pd.DataFrame(history2_cnn.history)
training_history2_cnn.to_csv("history_room2_cnn.csv", index=False)

# %%
# Get predictions on the test set
y_pred_2 = model2_cnn.predict(X_test_2_reshaped)
# Convert continuous predictions to discrete class labels
y_pred_labels_2 = np.argmax(y_pred_2, axis=1)

cm_model2_cnn = confusion_matrix(y_test_2, y_pred_labels_2, normalize='true')
class_names = ["Empty", "Down", "Left", "Right", "Up"]

# Plot confusion matrix as heatmap
sns.heatmap(cm_model2_cnn, annot=True, cmap="Blues", fmt=".2%", vmin=0, vmax=1, xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.savefig("confusion_matrix_lab2_1D-CNN_amplitudes.pdf", format="pdf")

plt.show()
# Out:
# 2/2 [==============================] - 0s 26ms/step
